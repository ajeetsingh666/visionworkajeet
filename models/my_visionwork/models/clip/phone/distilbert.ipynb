# %%
from transformers import AutoModelForMaskedLM

roberta = AutoModelForMaskedLM.from_pretrained("roberta-large")

print(roberta)
# Out:
# RobertaForMaskedLM(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 1024, padding_idx=1)
#       (position_embeddings): Embedding(514, 1024, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (lm_head): RobertaLMHead(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (decoder): Linear(in_features=1024, out_features=50265, bias=True)
#   )
# )

# %%
from typing import Any
from transformers import AutoModelForMaskedLM

roberta = AutoModelForMaskedLM.from_pretrained("roberta-large")

def visualize_children(
    object : Any,
    level : int = 0,
) -> None:
    """
    Prints the children of (object) and their children too, if there are any.
    Uses the current depth (level) to print things in a ordonnate manner.
    """
    print(f"{'   ' * level}{level}- {type(object).__name__}")
    try:
        for child in object.children():
            visualize_children(child, level + 1)
    except:
        pass

visualize_children(roberta)
# Out:
# 0- RobertaForMaskedLM
#    1- RobertaModel
#       2- RobertaEmbeddings
#          3- Embedding
#          3- Embedding
#          3- Embedding
#          3- LayerNorm
#          3- Dropout
#       2- RobertaEncoder
#          3- ModuleList
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#             4- RobertaLayer
#                5- RobertaAttention
#                   6- RobertaSelfAttention
#                      7- Linear
#                      7- Linear
#                      7- Linear
#                      7- Dropout
#                   6- RobertaSelfOutput
#                      7- Linear
#                      7- LayerNorm
#                      7- Dropout
#                5- RobertaIntermediate
#                   6- Linear
#                   6- GELUActivation
#                5- RobertaOutput
#                   6- Linear
#                   6- LayerNorm
#                   6- Dropout
#    1- RobertaLMHead
#       2- Linear
#       2- LayerNorm
#       2- Linear

# %%
total_params = sum(p.numel() for p in roberta.parameters())
param_size = 4

print(total_params /100000)
total_size = total_params * param_size / (1024 * 1024)
print(f'Model size in memory: {total_size:.2f} MB')
# Out:
# 3554.12057
# Model size in memory: 1355.79 MB

# %%
from transformers.models.roberta.modeling_roberta import RobertaPreTrainedModel, RobertaConfig

def distill_roberta(
    teacher_model : RobertaPreTrainedModel,
) -> RobertaPreTrainedModel:
    """
    Distilates a RoBERTa (teacher_model) like would DistilBERT for a BERT model.
    The student model has the same configuration, except for the number of hidden layers, which is // by 2.
    The student layers are initilized by copying one out of two layers of the teacher, starting with layer 0.
    The head of the teacher is also copied.
    """
    # Get teacher configuration as a dictionnary
    configuration = teacher_model.config.to_dict()
    # Half the number of hidden layer
    configuration['num_hidden_layers'] //= 2
    # Convert the dictionnary to the student configuration
    configuration = RobertaConfig.from_dict(configuration)
    # Create uninitialized student model
    student_model = type(teacher_model)(configuration)
    # Initialize the student's weights
    distill_roberta_weights(teacher=teacher_model, student=student_model)
    # Return the student model
    return student_model

# %%
roberta.state_dict()
# Out:
# OrderedDict([('roberta.embeddings.word_embeddings.weight',
#               tensor([[-0.1406, -0.0096,  0.0391,  ...,  0.0508, -0.0059, -0.0360],
#                       [ 0.0078, -0.0156,  0.0156,  ..., -0.0156,  0.0231,  0.0156],
#                       [-0.0828, -0.0007, -0.1174,  ...,  0.1086,  0.0696, -0.0356],
#                       ...,
#                       [ 0.0393,  0.0031,  0.0465,  ..., -0.0240, -0.0505,  0.0342],
#                       [ 0.0499,  0.0272,  0.0413,  ..., -0.0370, -0.0100,  0.0071],
#                       [-0.0149, -0.0114, -0.0222,  ...,  0.0441,  0.0116, -0.0330]])),
#              ('roberta.embeddings.position_embeddings.weight',
#               tensor([[-0.0038,  0.0253, -0.0092,  ...,  0.0177,  0.0062, -0.0162],
#                       [ 0.0117, -0.0019, -0.0267,  ...,  0.0062, -0.0193,  0.0264],
#                       [ 0.0316,  0.0148, -0.0549,  ..., -0.0717, -0.0460,  0.0468],
#                       ...,
#                       [-0.0209, -0.0052,  0.0484,  ..., -0.0394,  0.0463,  0.0537],
#                       [-0.0274,  0.1172,  0.0470,  ...,  0.0170, -0.1204,  0.0525],
#                       [ 0.0969, -0.0729,  0.0558,  ..., -0.1204, -0.1075,  0.0489]])),
#              ('roberta.embeddings.token_type_embeddings.weight',
#               tensor([[0., 0., 0.,  ..., 0., 0., 0.]])),
#              ('roberta.embeddings.LayerNorm.weight',
#               tensor([0.9346, 0.9233, 0.9126,  ..., 0.9409, 0.9150, 0.9023])),
#              ('roberta.embeddings.LayerNorm.bias',
#               tensor([ 0.0314,  0.0421,  0.1926,  ..., -0.2253, -0.0894,  0.1249])),
#              ('roberta.encoder.layer.0.attention.self.query.weight',
#               tensor([[-0.0042,  0.0347, -0.0016,  ...,  0.0033,  0.0597, -0.0437],
#                       [-0.0249,  0.0521, -0.0166,  ..., -0.0306, -0.0132,  0.0103],
#                       [ 0.0034,  0.0732, -0.0307,  ...,  0.0802,  0.0114, -0.0111],
#                       ...,
#                       [-0.0588,  0.0189, -0.0424,  ..., -0.0325,  0.0049,  0.0689],
#                       [ 0.0419,  0.0228, -0.0643,  ..., -0.0526, -0.0163,  0.0185],
#                       [-0.0199, -0.0427, -0.0098,  ...,  0.0461,  0.0247, -0.0177]])),
#              ('roberta.encoder.layer.0.attention.self.query.bias',
#               tensor([ 0.3108,  0.0559, -0.0737,  ..., -0.0701, -0.0528, -0.0657])),
#              ('roberta.encoder.layer.0.attention.self.key.weight',
#               tensor([[-0.0045, -0.0172, -0.0128,  ..., -0.0050,  0.0072, -0.0141],
#                       [-0.0238, -0.0002,  0.0267,  ...,  0.0393,  0.0430, -0.0210],
#                       [-0.0289, -0.0530, -0.0137,  ..., -0.0343,  0.0066,  0.0190],
#                       ...,
#                       [-0.0704, -0.0226, -0.0191,  ..., -0.0182,  0.0135,  0.1044],
#                       [ 0.0148,  0.0049, -0.0193,  ..., -0.0014, -0.0083,  0.0438],
#                       [-0.0076, -0.0642,  0.0450,  ...,  0.0460,  0.0176, -0.0481]])),
#              ('roberta.encoder.layer.0.attention.self.key.bias',
#               tensor([-0.0041, -0.0033, -0.0012,  ...,  0.0013,  0.0017,  0.0018])),
#              ('roberta.encoder.layer.0.attention.self.value.weight',
#               tensor([[ 0.0324,  0.0018, -0.0231,  ..., -0.0245,  0.0013,  0.0222],
#                       [ 0.0566,  0.0464,  0.0023,  ..., -0.0177,  0.0915, -0.0171],
#                       [-0.0168, -0.0433,  0.0110,  ..., -0.0506,  0.0007,  0.0638],
#                       ...,
#                       [-0.0097,  0.0080, -0.0125,  ...,  0.0354,  0.0260,  0.0143],
#                       [-0.0036, -0.0114, -0.0567,  ...,  0.0374, -0.0321,  0.0308],
#                       [ 0.0022, -0.0065, -0.0113,  ..., -0.0243,  0.0887, -0.0165]])),
#              ('roberta.encoder.layer.0.attention.self.value.bias',
#               tensor([-0.0014,  0.0015, -0.0090,  ..., -0.0231, -0.0206, -0.0350])),
#              ('roberta.encoder.layer.0.attention.output.dense.weight',
#               tensor([[ 0.0034,  0.0416, -0.0175,  ..., -0.0163, -0.0335, -0.0146],
#                       [-0.0356,  0.0113, -0.0142,  ...,  0.0337, -0.0059,  0.0267],
#                       [ 0.0272, -0.0738,  0.0181,  ..., -0.0316, -0.0052,  0.0991],
#                       ...,
#                       [ 0.0261,  0.0025,  0.0229,  ...,  0.0137, -0.0114, -0.0403],
#                       [-0.0065,  0.0527, -0.0471,  ...,  0.0420,  0.0255, -0.0172],
#                       [ 0.0477,  0.0249,  0.0919,  ...,  0.0262,  0.0092,  0.0080]])),
#              ('roberta.encoder.layer.0.attention.output.dense.bias',
#               tensor([-0.0139,  0.0291,  0.0847,  ...,  0.0735, -0.0089,  0.0106])),
#              ('roberta.encoder.layer.0.attention.output.LayerNorm.weight',
#               tensor([0.9800, 0.9888, 0.9741,  ..., 0.9834, 0.9907, 0.9956])),
#              ('roberta.encoder.layer.0.attention.output.LayerNorm.bias',
#               tensor([-0.4314,  0.2761, -0.0082,  ...,  0.0117,  0.3293, -0.2979])),
#              ('roberta.encoder.layer.0.intermediate.dense.weight',
#               tensor([[ 0.0575, -0.0649, -0.0924,  ...,  0.0054,  0.0177, -0.0157],
#                       [ 0.0159, -0.0288,  0.0206,  ...,  0.0146, -0.0403,  0.1211],
#                       [ 0.0371, -0.0655, -0.0027,  ...,  0.0308, -0.0264, -0.0214],
#                       ...,
#                       [ 0.0159, -0.0911,  0.0036,  ...,  0.0337, -0.0490,  0.0005],
#                       [ 0.1338,  0.0505, -0.1335,  ..., -0.1487, -0.0338,  0.0233],
#                       [ 0.0709, -0.0305, -0.0605,  ...,  0.0105, -0.0557, -0.0309]])),
#              ('roberta.encoder.layer.0.intermediate.dense.bias',
#               tensor([-0.0954, -0.0762, -0.0827,  ..., -0.1061, -0.0706, -0.0935])),
#              ('roberta.encoder.layer.0.output.dense.weight',
#               tensor([[ 0.0440,  0.1030,  0.0294,  ..., -0.0545,  0.0581,  0.0656],
#                       [ 0.0179,  0.0095, -0.0106,  ..., -0.0047,  0.0200, -0.0118],
#                       [ 0.0270, -0.0709,  0.0514,  ..., -0.0402, -0.0098,  0.0029],
#                       ...,
#                       [-0.0147, -0.0044,  0.0532,  ...,  0.0102, -0.0615,  0.0132],
#                       [-0.0500,  0.0330, -0.0726,  ...,  0.0566, -0.0357, -0.0030],
#                       [-0.0944, -0.0431, -0.0970,  ..., -0.0548,  0.0547, -0.0312]])),
#              ('roberta.encoder.layer.0.output.dense.bias',
#               tensor([ 0.0639, -0.0394,  0.0420,  ...,  0.0079, -0.0959,  0.0559])),
#              ('roberta.encoder.layer.0.output.LayerNorm.weight',
#               tensor([0.9692, 0.9600, 0.9668,  ..., 0.9717, 0.9692, 0.9492])),
#              ('roberta.encoder.layer.0.output.LayerNorm.bias',
#               tensor([ 0.3965, -0.1881,  0.0423,  ..., -0.0483, -0.2747,  0.2007])),
#              ('roberta.encoder.layer.1.attention.self.query.weight',
#               tensor([[ 2.1683e-02, -1.1279e-01,  1.9333e-02,  ..., -6.5796e-02,
#                        -2.9007e-02, -3.4943e-02],
#                       [ 3.2166e-02, -9.5062e-03,  9.8694e-02,  ..., -2.5238e-02,
#                         2.5101e-02,  1.6699e-01],
#                       [ 1.0048e-02, -4.2664e-02,  3.2776e-02,  ...,  8.3694e-03,
#                         1.6046e-04, -3.9864e-03],
#                       ...,
#                       [ 1.5839e-02,  3.2074e-02,  6.5674e-02,  ...,  4.5624e-02,
#                        -5.2429e-02,  1.0413e-01],
#                       [-1.1688e-01,  7.1594e-02,  6.8054e-02,  ..., -1.3435e-02,
#                        -7.6172e-02,  6.0883e-02],
#                       [ 2.9373e-02, -6.9031e-02,  2.3865e-02,  ...,  6.5063e-02,
#                         1.2312e-03,  5.0087e-03]])),
#              ('roberta.encoder.layer.1.attention.self.query.bias',
#               tensor([ 0.0743,  0.0511, -0.0696,  ...,  0.0821,  0.0454, -0.0778])),
#              ('roberta.encoder.layer.1.attention.self.key.weight',
#               tensor([[-0.0103,  0.0596, -0.0087,  ..., -0.0296,  0.0145, -0.0166],
#                       [-0.0197, -0.0879, -0.0577,  ...,  0.0533, -0.0383,  0.0147],
#                       [-0.0135,  0.0399,  0.0354,  ...,  0.0063,  0.0013, -0.0112],
#                       ...,
#                       [-0.0620, -0.0673,  0.0816,  ...,  0.0229,  0.0219,  0.0021],
#                       [ 0.0475, -0.0484,  0.0353,  ...,  0.0483,  0.0384, -0.0329],
#                       [ 0.0616,  0.0388,  0.0559,  ...,  0.0919,  0.0252,  0.0011]])),
#              ('roberta.encoder.layer.1.attention.self.key.bias',
#               tensor([ 1.3943e-03, -8.1110e-04, -8.1825e-04,  ...,  2.2817e-04,
#                       -7.8976e-05,  1.0090e-03])),
#              ('roberta.encoder.layer.1.attention.self.value.weight',
#               tensor([[-0.0652,  0.0030, -0.0267,  ..., -0.0068,  0.0537,  0.0282],
#                       [-0.0198,  0.0352, -0.0343,  ..., -0.0100,  0.0327, -0.0210],
#                       [ 0.0018,  0.0371,  0.0038,  ...,  0.0246,  0.0854, -0.0176],
#                       ...,
#                       [-0.0037, -0.0809, -0.0334,  ..., -0.0224,  0.0370,  0.0235],
#                       [-0.0616,  0.0683, -0.0165,  ..., -0.0056,  0.0229, -0.0136],
#                       [ 0.0363,  0.0345,  0.0145,  ...,  0.0121,  0.0313, -0.0161]])),
#              ('roberta.encoder.layer.1.attention.self.value.bias',
#               tensor([ 0.0066,  0.0039,  0.0057,  ...,  0.0015, -0.0548, -0.0020])),
#              ('roberta.encoder.layer.1.attention.output.dense.weight',
#               tensor([[-0.0389, -0.0113,  0.0055,  ..., -0.0724, -0.0307,  0.0182],
#                       [ 0.0018, -0.0532, -0.0046,  ..., -0.0745, -0.0389,  0.0057],
#                       [ 0.0433,  0.0118, -0.0229,  ..., -0.0305,  0.0177,  0.0338],
#                       ...,
#                       [-0.0064, -0.0179,  0.0367,  ...,  0.0226, -0.0260,  0.0481],
#                       [-0.0196,  0.0106,  0.0085,  ..., -0.0491, -0.0395, -0.0521],
#                       [ 0.0055, -0.0220,  0.0424,  ...,  0.0079, -0.0465,  0.0259]])),
#              ('roberta.encoder.layer.1.attention.output.dense.bias',
#               tensor([-0.2167,  0.0391, -0.0821,  ..., -0.0754,  0.2332,  0.0728])),
#              ('roberta.encoder.layer.1.attention.output.LayerNorm.weight',
#               tensor([0.9829, 0.9995, 0.9580,  ..., 0.9795, 0.9883, 0.9731])),
#              ('roberta.encoder.layer.1.attention.output.LayerNorm.bias',
#               tensor([-0.3291,  0.1810, -0.0328,  ..., -0.0730,  0.2494, -0.2292])),
#              ('roberta.encoder.layer.1.intermediate.dense.weight',
#               tensor([[ 0.0294, -0.0344, -0.0014,  ..., -0.0199,  0.1002,  0.0521],
#                       [-0.0024, -0.0701, -0.0299,  ...,  0.0352, -0.0020, -0.0547],
#                       [-0.0043,  0.0847,  0.0724,  ...,  0.0141,  0.0217, -0.0074],
#                       ...,
#                       [-0.0388, -0.0439,  0.1240,  ...,  0.0003,  0.0130, -0.0310],
#                       [ 0.0744, -0.0583, -0.1044,  ..., -0.0316,  0.0242, -0.0829],
#                       [ 0.0011,  0.0749,  0.0948,  ..., -0.0186, -0.0264,  0.0312]])),
#              ('roberta.encoder.layer.1.intermediate.dense.bias',
#               tensor([ 0.0954, -0.0535, -0.0536,  ..., -0.0871, -0.0856, -0.0858])),
#              ('roberta.encoder.layer.1.output.dense.weight',
#               tensor([[-0.0212, -0.0177,  0.0631,  ..., -0.0227, -0.0908,  0.0513],
#                       [ 0.0463, -0.0184, -0.0130,  ..., -0.0318, -0.0057, -0.0450],
#                       [ 0.0411,  0.0374,  0.0648,  ..., -0.0264, -0.0519,  0.0962],
#                       ...,
#                       [ 0.0419, -0.0616, -0.0754,  ..., -0.0400,  0.0235,  0.0345],
#                       [ 0.0093,  0.0853,  0.1106,  ...,  0.0648, -0.0422, -0.0220],
#                       [-0.0651,  0.0728,  0.0051,  ..., -0.0348,  0.0692,  0.0396]])),
#              ('roberta.encoder.layer.1.output.dense.bias',
#               tensor([ 0.0104,  0.0057,  0.0673,  ...,  0.0118, -0.0482,  0.0131])),
#              ('roberta.encoder.layer.1.output.LayerNorm.weight',
#               tensor([0.9590, 0.9941, 0.9395,  ..., 0.9688, 0.9673, 0.9390])),
#              ('roberta.encoder.layer.1.output.LayerNorm.bias',
#               tensor([ 0.1896, -0.1931, -0.0493,  ..., -0.0134, -0.2729,  0.1577])),
#              ('roberta.encoder.layer.2.attention.self.query.weight',
#               tensor([[ 0.0037, -0.0497,  0.0443,  ..., -0.0283, -0.0679, -0.0152],
#                       [-0.0826, -0.0897,  0.0353,  ..., -0.0249,  0.0029,  0.0137],
#                       [-0.0217, -0.0073, -0.0402,  ..., -0.0335, -0.0129, -0.0217],
#                       ...,
#                       [ 0.0205, -0.0191, -0.0120,  ..., -0.0353,  0.0823, -0.0728],
#                       [ 0.0316, -0.0968, -0.0501,  ..., -0.0464, -0.0008,  0.0120],
#                       [ 0.0208, -0.0242, -0.0710,  ...,  0.0729, -0.0063,  0.0469]])),
#              ('roberta.encoder.layer.2.attention.self.query.bias',
#               tensor([-0.0626,  0.1261,  0.1142,  ..., -0.1519,  0.0648, -0.1615])),
#              ('roberta.encoder.layer.2.attention.self.key.weight',
#               tensor([[ 0.0140,  0.1364,  0.0394,  ...,  0.0352,  0.0181, -0.0569],
#                       [-0.0002,  0.0158, -0.0162,  ..., -0.0303, -0.0384,  0.0427],
#                       [ 0.0659, -0.0079,  0.0019,  ..., -0.0539,  0.0268, -0.0468],
#                       ...,
#                       [-0.0029, -0.0351, -0.0347,  ..., -0.0019, -0.0549, -0.0683],
#                       [-0.0551, -0.0336,  0.0355,  ...,  0.0027, -0.0502,  0.0192],
#                       [ 0.0318,  0.0149, -0.0259,  ...,  0.0670,  0.0113,  0.0532]])),
#              ('roberta.encoder.layer.2.attention.self.key.bias',
#               tensor([-9.1743e-04, -2.7084e-03, -1.1196e-03,  ..., -7.6890e-05,
#                       -6.1846e-04, -9.4986e-04])),
#              ('roberta.encoder.layer.2.attention.self.value.weight',
#               tensor([[-0.0054,  0.0502,  0.0221,  ...,  0.0291,  0.0287,  0.0009],
#                       [-0.0007,  0.0914, -0.0208,  ..., -0.0035, -0.0303, -0.0043],
#                       [ 0.0202,  0.0468,  0.0071,  ...,  0.0363,  0.0282, -0.0201],
#                       ...,
#                       [-0.0112,  0.0281, -0.0109,  ..., -0.0392, -0.0270,  0.0395],
#                       [ 0.0610,  0.0394, -0.0400,  ..., -0.0234,  0.0649,  0.0303],
#                       [-0.0240, -0.0088,  0.0009,  ..., -0.0116,  0.0122,  0.0531]])),
#              ('roberta.encoder.layer.2.attention.self.value.bias',
#               tensor([-0.0301,  0.0159,  0.0106,  ..., -0.0054,  0.0105, -0.0050])),
#              ('roberta.encoder.layer.2.attention.output.dense.weight',
#               tensor([[-1.3542e-02, -1.6357e-02,  2.1469e-02,  ..., -5.3062e-03,
#                        -1.1940e-02,  2.3575e-02],
#                       [ 3.4885e-03,  1.6861e-02, -1.4534e-02,  ..., -4.6448e-02,
#                        -1.1993e-02, -2.7409e-03],
#                       [ 5.9967e-03,  4.0375e-02, -7.1228e-02,  ..., -1.2650e-02,
#                        -1.3779e-02, -1.5381e-02],
#                       ...,
#                       [-2.9907e-02, -7.3051e-03,  4.8889e-02,  ..., -2.9926e-03,
#                         9.1248e-03, -1.2840e-02],
#                       [-8.0872e-02,  7.3493e-05,  3.3379e-03,  ...,  4.3915e-02,
#                         1.9791e-02, -9.0790e-03],
#                       [ 5.4291e-02,  4.8279e-02,  4.6325e-04,  ...,  5.1231e-03,
#                         5.4657e-02,  2.5986e-02]])),
#              ('roberta.encoder.layer.2.attention.output.dense.bias',
#               tensor([ 0.0610, -0.0594,  0.0323,  ...,  0.0803, -0.0398,  0.0735])),
#              ('roberta.encoder.layer.2.attention.output.LayerNorm.weight',
#               tensor([0.9814, 0.9849, 0.9858,  ..., 0.9629, 0.9565, 0.9712])),
#              ('roberta.encoder.layer.2.attention.output.LayerNorm.bias',
#               tensor([-0.0940, -0.0031, -0.3413,  ..., -0.0275, -0.0715,  0.2152])),
#              ('roberta.encoder.layer.2.intermediate.dense.weight',
#               tensor([[ 0.0228,  0.0859,  0.0685,  ..., -0.0477, -0.0161, -0.0438],
#                       [-0.0249, -0.0678,  0.0927,  ..., -0.0751,  0.0543, -0.0039],
#                       [-0.0729,  0.0043,  0.0925,  ...,  0.0138,  0.0226,  0.0032],
#                       ...,
#                       [-0.0362, -0.0121,  0.0057,  ...,  0.0064, -0.0012,  0.0199],
#                       [-0.0673,  0.0101, -0.0132,  ..., -0.0005,  0.0340, -0.0955],
#                       [ 0.0006,  0.0221,  0.0193,  ..., -0.0164, -0.0526, -0.1001]])),
#              ('roberta.encoder.layer.2.intermediate.dense.bias',
#               tensor([-0.0233, -0.0803, -0.0687,  ...,  0.0582, -0.0864, -0.0893])),
#              ('roberta.encoder.layer.2.output.dense.weight',
#               tensor([[-0.0239,  0.0827,  0.0165,  ..., -0.0398, -0.1088,  0.0011],
#                       [-0.0065,  0.0176, -0.0627,  ...,  0.0477, -0.0254, -0.0119],
#                       [ 0.0536, -0.0567,  0.0587,  ...,  0.0124, -0.0474, -0.0762],
#                       ...,
#                       [ 0.0061, -0.0446,  0.0693,  ...,  0.0141,  0.1027,  0.0016],
#                       [ 0.0486, -0.0089, -0.0314,  ...,  0.0111, -0.0954, -0.0092],
#                       [ 0.0309, -0.0491, -0.0233,  ..., -0.0424,  0.0161,  0.0007]])),
#              ('roberta.encoder.layer.2.output.dense.bias',
#               tensor([-0.0090, -0.0412,  0.0115,  ...,  0.0299,  0.0136,  0.0445])),
#              ('roberta.encoder.layer.2.output.LayerNorm.weight',
#               tensor([0.9653, 0.9683, 0.9536,  ..., 0.9731, 0.9771, 0.9595])),
#              ('roberta.encoder.layer.2.output.LayerNorm.bias',
#               tensor([-0.0324, -0.1078,  0.2080,  ..., -0.0503, -0.0276, -0.2032])),
#              ('roberta.encoder.layer.3.attention.self.query.weight',
#               tensor([[-0.0712,  0.0097,  0.0376,  ...,  0.0291,  0.0526, -0.0108],
#                       [-0.0191, -0.0765, -0.0407,  ...,  0.0356, -0.0146,  0.0311],
#                       [-0.0204, -0.0179,  0.0803,  ...,  0.0351, -0.0190,  0.0064],
#                       ...,
#                       [-0.0564, -0.0120, -0.0109,  ...,  0.0377,  0.0884, -0.0202],
#                       [ 0.0684, -0.0347,  0.0419,  ..., -0.0892,  0.0264, -0.0361],
#                       [ 0.0323,  0.0648, -0.0203,  ..., -0.0419, -0.0321,  0.0206]])),
#              ('roberta.encoder.layer.3.attention.self.query.bias',
#               tensor([-0.0244, -0.0524,  0.0302,  ...,  0.0131,  0.1157, -0.0828])),
#              ('roberta.encoder.layer.3.attention.self.key.weight',
#               tensor([[-0.1331, -0.0380,  0.0011,  ...,  0.0231,  0.0477, -0.0254],
#                       [ 0.0243,  0.1003,  0.0936,  ..., -0.0249,  0.0847, -0.0457],
#                       [ 0.0059, -0.0403,  0.0914,  ..., -0.0175,  0.0155, -0.0206],
#                       ...,
#                       [-0.0251, -0.0050, -0.0037,  ...,  0.0738, -0.0612, -0.0409],
#                       [ 0.0022, -0.0244, -0.0063,  ...,  0.0406, -0.0319,  0.0085],
#                       [ 0.0315,  0.0121,  0.0219,  ...,  0.0159, -0.0307, -0.0179]])),
#              ('roberta.encoder.layer.3.attention.self.key.bias',
#               tensor([-5.9187e-05,  1.0948e-03,  1.8919e-04,  ...,  1.3676e-03,
#                       -7.5769e-04,  4.3488e-04])),
#              ('roberta.encoder.layer.3.attention.self.value.weight',
#               tensor([[ 0.0117, -0.0319, -0.0748,  ...,  0.0300,  0.0969,  0.0223],
#                       [-0.0171,  0.0381,  0.0467,  ..., -0.0291,  0.0078, -0.0063],
#                       [ 0.0394,  0.0378, -0.0704,  ..., -0.0519,  0.0271,  0.0231],
#                       ...,
#                       [ 0.0719,  0.0008,  0.0126,  ...,  0.0225,  0.0311,  0.0434],
#                       [-0.0226,  0.0504, -0.0327,  ..., -0.0040, -0.1065, -0.0126],
#                       [ 0.0267, -0.0087, -0.0442,  ..., -0.0314, -0.0029, -0.0478]])),
#              ('roberta.encoder.layer.3.attention.self.value.bias',
#               tensor([-0.0181, -0.0088, -0.0070,  ...,  0.0067,  0.0059, -0.0009])),
#              ('roberta.encoder.layer.3.attention.output.dense.weight',
#               tensor([[-0.0004,  0.0026,  0.0343,  ...,  0.0010, -0.0266, -0.0284],
#                       [ 0.0110, -0.0084,  0.0408,  ...,  0.0134, -0.0187,  0.0137],
#                       [-0.0790,  0.0118, -0.0061,  ..., -0.0122,  0.0570, -0.0051],
#                       ...,
#                       [ 0.0211, -0.0012, -0.0217,  ...,  0.0223, -0.0326,  0.0138],
#                       [ 0.0132,  0.0420,  0.0026,  ..., -0.0075, -0.0126, -0.0088],
#                       [-0.0280, -0.0183,  0.0176,  ..., -0.0087,  0.0168,  0.0360]])),
#              ('roberta.encoder.layer.3.attention.output.dense.bias',
#               tensor([ 0.0423, -0.0195, -0.0266,  ..., -0.0225,  0.0345, -0.0204])),
#              ('roberta.encoder.layer.3.attention.output.LayerNorm.weight',
#               tensor([0.9863, 0.9819, 0.9771,  ..., 0.9863, 0.9785, 0.9663])),
#              ('roberta.encoder.layer.3.attention.output.LayerNorm.bias',
#               tensor([-0.1804, -0.1191, -0.3018,  ..., -0.0452,  0.1131,  0.0351])),
#              ('roberta.encoder.layer.3.intermediate.dense.weight',
#               tensor([[ 0.0115,  0.0395, -0.0339,  ..., -0.0525, -0.0232, -0.0353],
#                       [ 0.0370,  0.0315,  0.0163,  ...,  0.0240, -0.0438, -0.0146],
#                       [ 0.0343, -0.0618, -0.0168,  ...,  0.0667, -0.1826,  0.0077],
#                       ...,
#                       [-0.0285, -0.0330, -0.0359,  ...,  0.0337, -0.0243, -0.0533],
#                       [ 0.0299, -0.0596, -0.0386,  ..., -0.0016,  0.0213, -0.0295],
#                       [ 0.0002,  0.0047, -0.0463,  ...,  0.0121, -0.0643, -0.0451]])),
#              ('roberta.encoder.layer.3.intermediate.dense.bias',
#               tensor([-0.0911, -0.1101, -0.0567,  ..., -0.1008, -0.0185, -0.0873])),
#              ('roberta.encoder.layer.3.output.dense.weight',
#               tensor([[-0.0193, -0.0331, -0.0232,  ...,  0.0206, -0.0674, -0.0084],
#                       [ 0.0246, -0.0143, -0.0244,  ..., -0.0045, -0.0454, -0.0682],
#                       [-0.0762, -0.0782,  0.0211,  ...,  0.0562, -0.0289, -0.0016],
#                       ...,
#                       [ 0.0081,  0.0290,  0.0782,  ..., -0.0535, -0.0729,  0.0006],
#                       [-0.0964, -0.0807, -0.0590,  ..., -0.0215, -0.0072, -0.1068],
#                       [ 0.1379,  0.0524, -0.0634,  ...,  0.0483, -0.0443,  0.0300]])),
#              ('roberta.encoder.layer.3.output.dense.bias',
#               tensor([-0.0875,  0.0331,  0.0640,  ...,  0.0408, -0.0828,  0.2712])),
#              ('roberta.encoder.layer.3.output.LayerNorm.weight',
#               tensor([0.9751, 0.9917, 0.9678,  ..., 0.9717, 0.9673, 0.9497])),
#              ('roberta.encoder.layer.3.output.LayerNorm.bias',
#               tensor([ 0.0133, -0.0074,  0.1967,  ..., -0.0252, -0.1181, -0.0804])),
#              ('roberta.encoder.layer.4.attention.self.query.weight',
#               tensor([[-0.0065, -0.0140, -0.0589,  ..., -0.0077, -0.0347, -0.0074],
#                       [-0.0023,  0.0019,  0.0432,  ..., -0.0606, -0.0117,  0.0692],
#                       [-0.0847,  0.0070,  0.0154,  ..., -0.0649, -0.0119,  0.0284],
#                       ...,
#                       [ 0.0165,  0.0070, -0.0132,  ...,  0.0207,  0.0043,  0.0014],
#                       [ 0.0171, -0.0274,  0.0376,  ..., -0.0103, -0.0284,  0.0164],
#                       [ 0.0352, -0.1013, -0.0187,  ..., -0.0378, -0.0362, -0.1453]])),
#              ('roberta.encoder.layer.4.attention.self.query.bias',
#               tensor([ 0.2100,  0.0039,  0.2280,  ..., -0.2532, -0.1885,  0.2032])),
#              ('roberta.encoder.layer.4.attention.self.key.weight',
#               tensor([[-0.0186, -0.0761, -0.0492,  ..., -0.0070, -0.0438,  0.0079],
#                       [-0.0532, -0.0105,  0.0205,  ...,  0.0041, -0.0238,  0.0127],
#                       [ 0.0140,  0.0293,  0.0414,  ...,  0.0326,  0.0664, -0.0059],
#                       ...,
#                       [ 0.0372,  0.0804,  0.0374,  ...,  0.0555,  0.0097,  0.0903],
#                       [-0.0149, -0.0255, -0.0283,  ..., -0.0180, -0.0418,  0.0627],
#                       [ 0.0045,  0.0278, -0.0062,  ...,  0.0266, -0.0330,  0.0235]])),
#              ('roberta.encoder.layer.4.attention.self.key.bias',
#               tensor([ 0.0006, -0.0003,  0.0003,  ..., -0.0005, -0.0002, -0.0002])),
#              ('roberta.encoder.layer.4.attention.self.value.weight',
#               tensor([[-0.0093,  0.0007,  0.0084,  ...,  0.0206,  0.0029,  0.0479],
#                       [ 0.0198,  0.0607, -0.0226,  ...,  0.0636, -0.0177, -0.0742],
#                       [ 0.0368,  0.0164,  0.0247,  ...,  0.0519, -0.0342,  0.0644],
#                       ...,
#                       [ 0.0117,  0.0651,  0.0219,  ...,  0.0487, -0.0018,  0.0248],
#                       [ 0.0275,  0.0076,  0.0163,  ...,  0.0290, -0.0032,  0.0635],
#                       [ 0.0088, -0.1032, -0.0013,  ..., -0.0404,  0.0336,  0.0076]])),
#              ('roberta.encoder.layer.4.attention.self.value.bias',
#               tensor([-0.0094, -0.0032,  0.0089,  ..., -0.0073,  0.0025, -0.0005])),
#              ('roberta.encoder.layer.4.attention.output.dense.weight',
#               tensor([[-0.0335, -0.0706, -0.0206,  ..., -0.0066, -0.0078,  0.0664],
#                       [-0.0454, -0.0166, -0.0117,  ...,  0.0456,  0.0285,  0.0088],
#                       [ 0.0059,  0.0088, -0.0098,  ..., -0.0417,  0.0453, -0.0116],
#                       ...,
#                       [ 0.0046,  0.0050,  0.0074,  ...,  0.0126,  0.0025, -0.0157],
#                       [-0.0023,  0.0142, -0.0296,  ...,  0.0532,  0.0049, -0.0253],
#                       [ 0.0175,  0.0455, -0.0144,  ..., -0.0102, -0.0273,  0.0093]])),
#              ('roberta.encoder.layer.4.attention.output.dense.bias',
#               tensor([-0.0074, -0.0126, -0.0088,  ...,  0.0169, -0.0641, -0.0042])),
#              ('roberta.encoder.layer.4.attention.output.LayerNorm.weight',
#               tensor([0.9902, 0.9985, 0.9868,  ..., 0.9873, 0.9971, 0.9585])),
#              ('roberta.encoder.layer.4.attention.output.LayerNorm.bias',
#               tensor([-0.1681,  0.0775, -0.2976,  ...,  0.0609,  0.0173,  0.2048])),
#              ('roberta.encoder.layer.4.intermediate.dense.weight',
#               tensor([[ 0.0026,  0.0550, -0.0331,  ..., -0.0766,  0.0542,  0.0404],
#                       [-0.0143, -0.0167, -0.0072,  ..., -0.0156, -0.0169, -0.0902],
#                       [-0.0327,  0.0142,  0.0496,  ..., -0.0940,  0.0210, -0.0462],
#                       ...,
#                       [-0.0588, -0.0233,  0.0649,  ...,  0.1270,  0.0421, -0.0712],
#                       [-0.0042, -0.0811, -0.0883,  ..., -0.0558, -0.0258,  0.0617],
#                       [-0.0369, -0.0236,  0.0060,  ...,  0.0209,  0.0364, -0.0447]])),
#              ('roberta.encoder.layer.4.intermediate.dense.bias',
#               tensor([-0.0895, -0.0796, -0.0721,  ..., -0.0707, -0.0522, -0.0544])),
#              ('roberta.encoder.layer.4.output.dense.weight',
#               tensor([[-0.0204,  0.0603,  0.0074,  ...,  0.0366, -0.0113, -0.0281],
#                       [-0.0467, -0.0277, -0.0513,  ...,  0.0353, -0.0570,  0.0018],
#                       [ 0.0151,  0.0825,  0.1046,  ...,  0.0023,  0.0529, -0.0290],
#                       ...,
#                       [-0.0349, -0.0451, -0.0652,  ...,  0.1400, -0.0656,  0.0148],
#                       [ 0.0388, -0.0215,  0.0321,  ...,  0.1024, -0.0144,  0.0144],
#                       [ 0.0075, -0.0456, -0.0986,  ..., -0.0384,  0.0642, -0.0393]])),
#              ('roberta.encoder.layer.4.output.dense.bias',
#               tensor([-0.0841, -0.0167,  0.1401,  ...,  0.0091, -0.1005,  0.1653])),
#              ('roberta.encoder.layer.4.output.LayerNorm.weight',
#               tensor([0.9727, 0.9961, 0.9751,  ..., 0.9771, 0.9961, 0.9673])),
#              ('roberta.encoder.layer.4.output.LayerNorm.bias',
#               tensor([ 0.0118, -0.1010,  0.2786,  ..., -0.1054, -0.1014, -0.1643])),
#              ('roberta.encoder.layer.5.attention.self.query.weight',
#               tensor([[ 0.0701, -0.0117,  0.0259,  ..., -0.0172,  0.0208,  0.0345],
#                       [ 0.0538, -0.0120,  0.0066,  ...,  0.0030,  0.0462, -0.1401],
#                       [-0.0547, -0.0127, -0.0211,  ...,  0.0235, -0.0474, -0.0021],
#                       ...,
#                       [-0.0178, -0.0200, -0.0732,  ..., -0.0316,  0.0170,  0.0017],
#                       [ 0.0476, -0.0839,  0.0221,  ...,  0.0347,  0.0223, -0.0324],
#                       [-0.0077,  0.0272,  0.0586,  ...,  0.0086,  0.0671,  0.0533]])),
#              ('roberta.encoder.layer.5.attention.self.query.bias',
#               tensor([ 0.0328, -0.0290, -0.0242,  ...,  0.0297,  0.1254, -0.1331])),
#              ('roberta.encoder.layer.5.attention.self.key.weight',
#               tensor([[ 1.5879e-03,  6.4697e-02, -9.2773e-03,  ..., -4.0405e-02,
#                         5.9929e-03, -1.4702e-02],
#                       [ 3.9032e-02, -2.1317e-02, -3.8635e-02,  ...,  3.6407e-02,
#                         3.1616e-02, -3.7872e-02],
#                       [ 3.5095e-02, -1.6632e-02, -3.3173e-02,  ..., -1.1328e-01,
#                         4.2572e-02,  3.2471e-02],
#                       ...,
#                       [ 2.8229e-02,  7.7188e-05, -4.5624e-03,  ...,  2.7634e-02,
#                         6.5491e-02,  4.1595e-02],
#                       [ 1.7899e-02,  6.6490e-03, -1.3237e-02,  ...,  1.6998e-02,
#                        -1.5038e-02,  1.0391e-02],
#                       [-7.2937e-02,  1.3714e-03,  5.9418e-02,  ..., -5.3040e-02,
#                         1.7471e-02,  3.1319e-03]])),
#              ('roberta.encoder.layer.5.attention.self.key.bias',
#               tensor([ 8.0585e-04, -8.8274e-05, -1.3983e-04,  ...,  1.6794e-03,
#                        8.8596e-04,  4.0960e-04])),
#              ('roberta.encoder.layer.5.attention.self.value.weight',
#               tensor([[-2.1271e-02,  5.2246e-02,  1.2596e-02,  ..., -3.1972e-04,
#                        -6.9771e-03,  5.1422e-02],
#                       [-6.7139e-02, -6.5491e-02, -1.3092e-02,  ...,  2.2369e-02,
#                        -4.3396e-02, -5.9357e-02],
#                       [ 3.8574e-02, -4.2725e-02, -2.9297e-02,  ..., -2.9802e-05,
#                        -1.2581e-02,  3.2257e-02],
#                       ...,
#                       [ 3.0365e-02, -2.0691e-02, -1.3786e-02,  ..., -3.0777e-02,
#                        -9.1705e-03, -3.1525e-02],
#                       [ 5.6519e-02,  2.6764e-02, -9.6985e-02,  ...,  1.2199e-02,
#                        -8.4305e-03,  4.6875e-02],
#                       [-3.5492e-02,  7.0190e-02, -2.3026e-02,  ..., -2.2247e-02,
#                        -2.1133e-02,  2.3499e-02]])),
#              ('roberta.encoder.layer.5.attention.self.value.bias',
#               tensor([ 0.0022, -0.0049, -0.0022,  ...,  0.0084, -0.0059, -0.0095])),
#              ('roberta.encoder.layer.5.attention.output.dense.weight',
#               tensor([[ 0.0295, -0.0094, -0.0190,  ...,  0.0242,  0.0242, -0.0228],
#                       [-0.0983,  0.0297,  0.0096,  ..., -0.0517, -0.0190,  0.0466],
#                       [ 0.0653, -0.0074,  0.0428,  ..., -0.0186, -0.0409, -0.0307],
#                       ...,
#                       [-0.0107, -0.0522, -0.0144,  ..., -0.0068,  0.0210, -0.0367],
#                       [ 0.0008,  0.0127,  0.0365,  ...,  0.0086, -0.0692, -0.0016],
#                       [ 0.0068,  0.0255,  0.0211,  ...,  0.0341, -0.0081, -0.0044]])),
#              ('roberta.encoder.layer.5.attention.output.dense.bias',
#               tensor([ 0.0058,  0.0079, -0.0753,  ..., -0.0275, -0.0629, -0.0144])),
#              ('roberta.encoder.layer.5.attention.output.LayerNorm.weight',
#               tensor([0.9912, 0.9990, 0.9985,  ..., 0.9790, 0.9917, 0.9697])),
#              ('roberta.encoder.layer.5.attention.output.LayerNorm.bias',
#               tensor([-0.1207,  0.0558, -0.2698,  ...,  0.0012, -0.0933,  0.0925])),
#              ('roberta.encoder.layer.5.intermediate.dense.weight',
#               tensor([[-0.0023, -0.0378, -0.0315,  ..., -0.0089, -0.0048, -0.0246],
#                       [-0.0047, -0.0434, -0.0201,  ..., -0.0168,  0.0679, -0.0439],
#                       [ 0.0646,  0.0493,  0.0061,  ..., -0.0126, -0.0359,  0.0527],
#                       ...,
#                       [-0.0152, -0.0545, -0.0124,  ...,  0.0603,  0.0032, -0.0709],
#                       [-0.0238, -0.1223,  0.0007,  ...,  0.0288,  0.0658, -0.0305],
#                       [-0.0576,  0.0427,  0.0489,  ...,  0.0288, -0.0007,  0.0439]])),
#              ('roberta.encoder.layer.5.intermediate.dense.bias',
#               tensor([-0.0727, -0.1107, -0.1094,  ..., -0.0519, -0.1167, -0.1059])),
#              ('roberta.encoder.layer.5.output.dense.weight',
#               tensor([[-0.0307,  0.0609,  0.0028,  ..., -0.0154, -0.0379,  0.0259],
#                       [ 0.0447, -0.0581,  0.0644,  ..., -0.0441, -0.0212, -0.0804],
#                       [ 0.0062,  0.0119, -0.0137,  ..., -0.0322, -0.0124, -0.0699],
#                       ...,
#                       [-0.0677, -0.0647, -0.0333,  ...,  0.0010,  0.1031, -0.0217],
#                       [-0.0117,  0.0200, -0.0771,  ..., -0.0256, -0.0110, -0.0042],
#                       [ 0.0014, -0.0229,  0.0839,  ..., -0.0513,  0.0290, -0.0355]])),
#              ('roberta.encoder.layer.5.output.dense.bias',
#               tensor([-0.1071,  0.0106,  0.1376,  ..., -0.0015, -0.0591,  0.1449])),
#              ('roberta.encoder.layer.5.output.LayerNorm.weight',
#               tensor([0.9727, 0.9937, 0.9907,  ..., 0.9756, 0.9917, 0.9565])),
#              ('roberta.encoder.layer.5.output.LayerNorm.bias',
#               tensor([-0.0165, -0.1136,  0.2712,  ..., -0.1176, -0.0460, -0.1471])),
#              ('roberta.encoder.layer.6.attention.self.query.weight',
#               tensor([[ 0.0198, -0.0261,  0.0551,  ...,  0.0417,  0.0497,  0.0078],
#                       [-0.0055, -0.0328, -0.0066,  ..., -0.0061, -0.0501, -0.0333],
#                       [ 0.0378,  0.1501,  0.0873,  ...,  0.0482,  0.0451,  0.0360],
#                       ...,
#                       [ 0.0099, -0.0024, -0.1047,  ...,  0.0317,  0.0684,  0.0650],
#                       [ 0.0257,  0.0184,  0.0190,  ...,  0.0053,  0.0265,  0.0864],
#                       [-0.0392, -0.0010,  0.0403,  ..., -0.0429,  0.0341, -0.0313]])),
#              ('roberta.encoder.layer.6.attention.self.query.bias',
#               tensor([-0.3074,  0.0543, -0.3076,  ..., -0.0909,  0.0283,  0.0039])),
#              ('roberta.encoder.layer.6.attention.self.key.weight',
#               tensor([[ 2.7771e-02, -3.0380e-02,  6.7505e-02,  ..., -1.1589e-02,
#                        -2.7512e-02, -8.3256e-04],
#                       [-1.6342e-02,  3.0457e-02,  1.9424e-02,  ...,  9.9426e-02,
#                         7.6233e-02,  1.5747e-02],
#                       [ 5.5145e-02,  2.4891e-04,  1.8967e-02,  ..., -1.4679e-02,
#                        -3.5004e-02, -4.1199e-02],
#                       ...,
#                       [-1.8112e-02,  1.6144e-02,  3.8261e-03,  ..., -3.4180e-02,
#                         1.3832e-02, -2.2268e-04],
#                       [-7.5134e-02, -6.3110e-02, -1.2035e-03,  ...,  4.5319e-02,
#                         3.7659e-02, -7.0267e-03],
#                       [ 9.6817e-03,  3.3997e-02,  6.7949e-05,  ...,  5.9082e-02,
#                         3.0640e-02, -8.9188e-03]])),
#              ('roberta.encoder.layer.6.attention.self.key.bias',
#               tensor([ 7.9823e-04, -6.5517e-04,  1.4269e-04,  ...,  7.2896e-05,
#                        2.9230e-04,  2.2483e-04])),
#              ('roberta.encoder.layer.6.attention.self.value.weight',
#               tensor([[ 0.0128,  0.0156, -0.0072,  ..., -0.0307, -0.0132, -0.0014],
#                       [-0.0018,  0.0396,  0.0188,  ..., -0.0561,  0.0386,  0.0136],
#                       [-0.0172, -0.0562,  0.0533,  ...,  0.0457, -0.0023,  0.0233],
#                       ...,
#                       [ 0.0145,  0.0403,  0.0008,  ...,  0.0475, -0.0590,  0.0015],
#                       [ 0.0092, -0.0157, -0.0046,  ..., -0.0295,  0.0175, -0.0145],
#                       [ 0.0117,  0.0240,  0.0225,  ..., -0.0343,  0.1074,  0.0263]])),
#              ('roberta.encoder.layer.6.attention.self.value.bias',
#               tensor([-0.0072, -0.0078, -0.0015,  ..., -0.0179, -0.0083, -0.0025])),
#              ('roberta.encoder.layer.6.attention.output.dense.weight',
#               tensor([[-0.0388,  0.0045, -0.0160,  ...,  0.0404, -0.0314, -0.0048],
#                       [ 0.0188, -0.0354, -0.0397,  ...,  0.0212,  0.0386, -0.0201],
#                       [ 0.0496, -0.0577, -0.0385,  ...,  0.0269,  0.0673, -0.0362],
#                       ...,
#                       [-0.0166,  0.0493,  0.0010,  ..., -0.0426,  0.0055,  0.0208],
#                       [-0.0266,  0.0227,  0.0433,  ...,  0.0251, -0.0196, -0.0406],
#                       [-0.0219,  0.0471,  0.0232,  ...,  0.0600,  0.0048,  0.0190]])),
#              ('roberta.encoder.layer.6.attention.output.dense.bias',
#               tensor([ 0.0075, -0.0111,  0.0319,  ..., -0.0002, -0.0668,  0.0089])),
#              ('roberta.encoder.layer.6.attention.output.LayerNorm.weight',
#               tensor([0.9849, 0.9995, 0.9995,  ..., 0.9829, 0.9795, 0.9517])),
#              ('roberta.encoder.layer.6.attention.output.LayerNorm.bias',
#               tensor([-0.1209,  0.0573, -0.2834,  ..., -0.0227, -0.1025,  0.1007])),
#              ('roberta.encoder.layer.6.intermediate.dense.weight',
#               tensor([[-0.0052, -0.0053, -0.0128,  ..., -0.0038,  0.0404,  0.0694],
#                       [ 0.0060,  0.0058, -0.0009,  ..., -0.0269,  0.0212, -0.0418],
#                       [-0.0605, -0.0773, -0.0483,  ...,  0.0749, -0.0172, -0.0795],
#                       ...,
#                       [-0.0475, -0.0405,  0.0061,  ..., -0.0118,  0.0809, -0.0515],
#                       [ 0.0037,  0.0027,  0.0085,  ...,  0.0124,  0.0114,  0.0080],
#                       [-0.0103, -0.0606,  0.0460,  ..., -0.0205,  0.0188, -0.1267]])),
#              ('roberta.encoder.layer.6.intermediate.dense.bias',
#               tensor([-0.0795, -0.0929, -0.1035,  ..., -0.0771, -0.0702, -0.1737])),
#              ('roberta.encoder.layer.6.output.dense.weight',
#               tensor([[ 0.0271, -0.0347, -0.0198,  ...,  0.0352,  0.0227, -0.0079],
#                       [ 0.0097, -0.0428, -0.0086,  ..., -0.0074,  0.0348,  0.0107],
#                       [ 0.0246, -0.0133, -0.0906,  ...,  0.0432, -0.0434,  0.0382],
#                       ...,
#                       [ 0.0093, -0.0624,  0.0096,  ..., -0.0162,  0.0570, -0.0461],
#                       [ 0.0286,  0.0006, -0.1135,  ..., -0.0179, -0.0282,  0.0639],
#                       [ 0.0405,  0.0091,  0.0193,  ..., -0.0305,  0.0257, -0.0179]])),
#              ('roberta.encoder.layer.6.output.dense.bias',
#               tensor([-0.0679,  0.0312,  0.0668,  ..., -0.0091, -0.0555,  0.0709])),
#              ('roberta.encoder.layer.6.output.LayerNorm.weight',
#               tensor([0.9824, 0.9897, 1.0000,  ..., 0.9795, 0.9751, 0.9609])),
#              ('roberta.encoder.layer.6.output.LayerNorm.bias',
#               tensor([-0.0241, -0.1124,  0.1122,  ..., -0.0810, -0.0277, -0.1335])),
#              ('roberta.encoder.layer.7.attention.self.query.weight',
#               tensor([[ 0.0184, -0.0201,  0.0036,  ...,  0.0256, -0.0393, -0.1075],
#                       [ 0.0565, -0.0805, -0.0152,  ...,  0.0168, -0.0428,  0.0195],
#                       [-0.1337,  0.0188,  0.0227,  ...,  0.0094,  0.0819,  0.0018],
#                       ...,
#                       [-0.0295,  0.1948,  0.0428,  ...,  0.0566,  0.0104,  0.1293],
#                       [ 0.0082,  0.0250, -0.0315,  ...,  0.0128,  0.0742,  0.1000],
#                       [ 0.0170,  0.0125,  0.0275,  ...,  0.0941,  0.1177,  0.0461]])),
#              ('roberta.encoder.layer.7.attention.self.query.bias',
#               tensor([ 0.0159,  0.0128, -0.0539,  ..., -0.2546,  0.1262, -0.2625])),
#              ('roberta.encoder.layer.7.attention.self.key.weight',
#               tensor([[ 0.0045, -0.0021, -0.0544,  ..., -0.0084, -0.0034,  0.0627],
#                       [ 0.0125,  0.0051,  0.0239,  ...,  0.0232, -0.0456,  0.0063],
#                       [-0.0080, -0.0432, -0.0181,  ...,  0.0223, -0.0365,  0.0291],
#                       ...,
#                       [-0.0247,  0.0017,  0.0285,  ..., -0.0513, -0.0775, -0.0425],
#                       [-0.0698,  0.0384,  0.0177,  ..., -0.0067, -0.0243,  0.0805],
#                       [ 0.0225,  0.0233,  0.0276,  ...,  0.0106, -0.0107, -0.0332]])),
#              ('roberta.encoder.layer.7.attention.self.key.bias',
#               tensor([-0.0004, -0.0008, -0.0002,  ...,  0.0003,  0.0006,  0.0002])),
#              ('roberta.encoder.layer.7.attention.self.value.weight',
#               tensor([[ 0.0062, -0.0215,  0.0021,  ...,  0.0200, -0.0024, -0.0427],
#                       [-0.0114, -0.0298, -0.0223,  ..., -0.0180, -0.0340, -0.0479],
#                       [ 0.0233, -0.0204,  0.0246,  ..., -0.0148,  0.0224,  0.0078],
#                       ...,
#                       [-0.0019, -0.0428,  0.0140,  ...,  0.0232,  0.0383,  0.0101],
#                       [-0.0551, -0.0564, -0.0037,  ...,  0.0457,  0.0208,  0.0209],
#                       [ 0.0353, -0.0013, -0.0257,  ...,  0.0329, -0.0365, -0.0166]])),
#              ('roberta.encoder.layer.7.attention.self.value.bias',
#               tensor([ 0.0014,  0.0333, -0.0516,  ...,  0.0141,  0.0035,  0.0053])),
#              ('roberta.encoder.layer.7.attention.output.dense.weight',
#               tensor([[ 0.0013, -0.0080,  0.0293,  ...,  0.0084,  0.0642, -0.0313],
#                       [-0.0392,  0.0024,  0.0165,  ...,  0.0410, -0.0790,  0.0256],
#                       [-0.0339, -0.0198,  0.0130,  ...,  0.0442,  0.0382,  0.0347],
#                       ...,
#                       [ 0.0449,  0.0030,  0.0521,  ...,  0.0071, -0.0655, -0.0060],
#                       [ 0.0102,  0.0133,  0.0110,  ..., -0.0082,  0.0157,  0.0328],
#                       [-0.0123, -0.0276, -0.0095,  ..., -0.0523, -0.0144,  0.0467]])),
#              ('roberta.encoder.layer.7.attention.output.dense.bias',
#               tensor([-0.0173,  0.0161, -0.0387,  ..., -0.0473, -0.0037,  0.0277])),
#              ('roberta.encoder.layer.7.attention.output.LayerNorm.weight',
#               tensor([0.9907, 0.9868, 1.0000,  ..., 0.9810, 0.9590, 0.9746])),
#              ('roberta.encoder.layer.7.attention.output.LayerNorm.bias',
#               tensor([-0.0919,  0.0110, -0.4243,  ..., -0.0744, -0.1014, -0.0009])),
#              ('roberta.encoder.layer.7.intermediate.dense.weight',
#               tensor([[-0.0643,  0.0358,  0.0168,  ...,  0.0629,  0.0051,  0.0346],
#                       [ 0.0648,  0.0390, -0.0084,  ..., -0.0023, -0.0386, -0.0366],
#                       [-0.0376, -0.0243, -0.0010,  ...,  0.0164,  0.0161,  0.0332],
#                       ...,
#                       [ 0.0063,  0.0324,  0.0043,  ..., -0.0392, -0.0227,  0.0073],
#                       [-0.0329, -0.1088,  0.0165,  ..., -0.0867, -0.0081, -0.0115],
#                       [-0.0504, -0.0500,  0.0031,  ...,  0.0442, -0.0249,  0.0342]])),
#              ('roberta.encoder.layer.7.intermediate.dense.bias',
#               tensor([-0.0926, -0.0908, -0.0112,  ...,  0.0072, -0.0848, -0.0317])),
#              ('roberta.encoder.layer.7.output.dense.weight',
#               tensor([[-0.0114,  0.0720, -0.0147,  ...,  0.0148, -0.1044, -0.0399],
#                       [ 0.0326,  0.0779,  0.0047,  ..., -0.0380, -0.0641,  0.0314],
#                       [-0.0134, -0.0088, -0.0089,  ...,  0.0290,  0.0138,  0.0067],
#                       ...,
#                       [-0.0593,  0.0385, -0.0249,  ...,  0.0267, -0.0116,  0.0278],
#                       [-0.0098, -0.0016, -0.0242,  ...,  0.0292,  0.0196,  0.0135],
#                       [ 0.0695, -0.0198,  0.0122,  ..., -0.0290,  0.0178, -0.0433]])),
#              ('roberta.encoder.layer.7.output.dense.bias',
#               tensor([-0.1935,  0.0500,  0.1160,  ..., -0.0164, -0.0422,  0.0584])),
#              ('roberta.encoder.layer.7.output.LayerNorm.weight',
#               tensor([0.9888, 0.9893, 0.9990,  ..., 0.9810, 0.9771, 0.9517])),
#              ('roberta.encoder.layer.7.output.LayerNorm.bias',
#               tensor([-0.0313, -0.0964, -0.0033,  ..., -0.0478, -0.0408, -0.1099])),
#              ('roberta.encoder.layer.8.attention.self.query.weight',
#               tensor([[ 3.5126e-02,  3.3295e-02,  3.0731e-02,  ...,  2.1011e-02,
#                         1.7136e-02,  1.1436e-02],
#                       [-9.0698e-02, -6.7383e-02,  6.7078e-02,  ..., -3.6926e-02,
#                         2.4414e-03,  1.0948e-02],
#                       [-6.6101e-02,  1.0541e-01, -3.0579e-02,  ...,  4.3030e-02,
#                         6.7566e-02, -2.7409e-03],
#                       ...,
#                       [ 6.0822e-02,  4.2175e-02, -2.8477e-03,  ..., -7.7553e-03,
#                         8.5876e-02, -5.7831e-03],
#                       [ 1.1147e-02,  8.0078e-02, -3.1647e-02,  ..., -1.2573e-01,
#                         4.1260e-02,  2.8183e-02],
#                       [-2.8198e-02, -7.9956e-02,  4.7266e-05,  ...,  5.4779e-03,
#                        -1.7303e-02, -4.4373e-02]])),
#              ('roberta.encoder.layer.8.attention.self.query.bias',
#               tensor([-0.0943,  0.1276,  0.0213,  ..., -0.1385, -0.0545,  0.0571])),
#              ('roberta.encoder.layer.8.attention.self.key.weight',
#               tensor([[-0.0713,  0.0465,  0.0005,  ..., -0.1571,  0.0556, -0.0124],
#                       [-0.0549, -0.0030,  0.1162,  ...,  0.0144,  0.0181, -0.0310],
#                       [ 0.0414, -0.0372, -0.0593,  ..., -0.0314,  0.1133, -0.0304],
#                       ...,
#                       [-0.0090,  0.0548, -0.0418,  ...,  0.0569,  0.0009,  0.0328],
#                       [-0.0787,  0.0292, -0.0483,  ...,  0.0121,  0.0411, -0.0278],
#                       [-0.0113, -0.0854,  0.0329,  ...,  0.0147,  0.0084, -0.0656]])),
#              ('roberta.encoder.layer.8.attention.self.key.bias',
#               tensor([ 3.2246e-05,  1.8108e-04, -3.4857e-04,  ...,  7.0214e-05,
#                       -1.5354e-04,  1.8835e-05])),
#              ('roberta.encoder.layer.8.attention.self.value.weight',
#               tensor([[ 0.0437,  0.0020, -0.0155,  ..., -0.0463,  0.0313,  0.0349],
#                       [-0.0494, -0.0345, -0.0009,  ...,  0.0656,  0.0010,  0.0500],
#                       [ 0.0020, -0.0055,  0.0049,  ..., -0.0005, -0.0087, -0.0667],
#                       ...,
#                       [ 0.0032,  0.0339,  0.0179,  ..., -0.0219, -0.0401, -0.0317],
#                       [ 0.0526, -0.0489,  0.0020,  ..., -0.0063, -0.0175, -0.0130],
#                       [-0.0276, -0.0160,  0.0036,  ...,  0.0417, -0.0164, -0.0402]])),
#              ('roberta.encoder.layer.8.attention.self.value.bias',
#               tensor([-0.0069, -0.0147,  0.0093,  ..., -0.0142, -0.0061, -0.0035])),
#              ('roberta.encoder.layer.8.attention.output.dense.weight',
#               tensor([[ 0.0290, -0.0029, -0.0091,  ..., -0.0007,  0.0065, -0.0013],
#                       [ 0.0020, -0.0158,  0.0277,  ..., -0.0002,  0.0400,  0.0616],
#                       [ 0.0497, -0.0378,  0.0262,  ...,  0.0438, -0.0356,  0.0063],
#                       ...,
#                       [-0.0339,  0.0262, -0.0167,  ...,  0.0360, -0.0335, -0.0305],
#                       [-0.0475,  0.0050, -0.0264,  ...,  0.0027,  0.0017,  0.0064],
#                       [ 0.0269, -0.0111,  0.0308,  ...,  0.0231,  0.0037,  0.0472]])),
#              ('roberta.encoder.layer.8.attention.output.dense.bias',
#               tensor([-0.0503,  0.0053,  0.0043,  ...,  0.0089, -0.0961,  0.0549])),
#              ('roberta.encoder.layer.8.attention.output.LayerNorm.weight',
#               tensor([0.9883, 0.9956, 1.0000,  ..., 0.9888, 0.9946, 0.9736])),
#              ('roberta.encoder.layer.8.attention.output.LayerNorm.bias',
#               tensor([-0.1704,  0.0124, -0.4998,  ..., -0.0114, -0.1092, -0.0147])),
#              ('roberta.encoder.layer.8.intermediate.dense.weight',
#               tensor([[-0.0093, -0.0008,  0.0194,  ..., -0.0634,  0.0100, -0.0768],
# ...
#                       -3.6192e-04,  1.0155e-02])),
#              ('roberta.encoder.layer.21.attention.self.value.weight',
#               tensor([[ 0.0294, -0.0317, -0.0536,  ..., -0.0359,  0.0164, -0.0273],
#                       [ 0.0420, -0.0497, -0.0003,  ...,  0.0234, -0.0509,  0.0677],
#                       [ 0.0168, -0.0406, -0.0113,  ...,  0.0034, -0.0381,  0.0265],
#                       ...,
#                       [ 0.0199, -0.0723, -0.0101,  ..., -0.0240, -0.0741, -0.0296],
#                       [ 0.0283, -0.0295, -0.0438,  ...,  0.0670, -0.0156,  0.0249],
#                       [-0.0199, -0.0035,  0.0948,  ..., -0.0341, -0.0218,  0.0224]])),
#              ('roberta.encoder.layer.21.attention.self.value.bias',
#               tensor([ 0.0073, -0.0018, -0.0013,  ..., -0.0114, -0.0259, -0.0122])),
#              ('roberta.encoder.layer.21.attention.output.dense.weight',
#               tensor([[-0.0022,  0.0444, -0.0341,  ..., -0.0173,  0.0066,  0.0372],
#                       [ 0.0344,  0.0151, -0.0345,  ...,  0.0046,  0.0278, -0.0186],
#                       [ 0.0102, -0.0402, -0.0073,  ..., -0.0136,  0.0143, -0.0398],
#                       ...,
#                       [ 0.0198,  0.0447, -0.0041,  ...,  0.0199, -0.0222,  0.0489],
#                       [-0.0536,  0.0704, -0.0666,  ...,  0.0017, -0.0414, -0.0165],
#                       [ 0.0158,  0.0129, -0.0546,  ...,  0.0504, -0.0234, -0.0265]])),
#              ('roberta.encoder.layer.21.attention.output.dense.bias',
#               tensor([-0.0267,  0.0898,  0.0438,  ...,  0.0352,  0.1780,  0.0308])),
#              ('roberta.encoder.layer.21.attention.output.LayerNorm.weight',
#               tensor([0.9712, 0.9922, 1.0000,  ..., 0.9795, 0.9912, 0.9922])),
#              ('roberta.encoder.layer.21.attention.output.LayerNorm.bias',
#               tensor([-0.0457, -0.0585, -0.1334,  ..., -0.0504, -0.1016, -0.0348])),
#              ('roberta.encoder.layer.21.intermediate.dense.weight',
#               tensor([[-0.0166, -0.0317,  0.0371,  ...,  0.0542,  0.0238, -0.0266],
#                       [ 0.0017,  0.0008, -0.0734,  ...,  0.0260,  0.0014,  0.0590],
#                       [ 0.0018,  0.0369, -0.0443,  ..., -0.0052,  0.0096,  0.0010],
#                       ...,
#                       [-0.0090, -0.0185,  0.0259,  ..., -0.0240, -0.0734, -0.0229],
#                       [ 0.0128, -0.0698,  0.0179,  ..., -0.0241,  0.0056, -0.0253],
#                       [ 0.0037,  0.0035,  0.0192,  ..., -0.0109,  0.0282,  0.0379]])),
#              ('roberta.encoder.layer.21.intermediate.dense.bias',
#               tensor([-0.0258, -0.0454,  0.0190,  ..., -0.0300, -0.0034, -0.0152])),
#              ('roberta.encoder.layer.21.output.dense.weight',
#               tensor([[-0.0118,  0.0010, -0.0039,  ...,  0.0360, -0.0206, -0.0352],
#                       [ 0.0027,  0.0124, -0.0349,  ...,  0.0152, -0.0354,  0.0514],
#                       [-0.0181,  0.0005,  0.0018,  ...,  0.0119,  0.0048,  0.0123],
#                       ...,
#                       [-0.0311,  0.0122,  0.0245,  ..., -0.0188, -0.0135, -0.0044],
#                       [-0.0340,  0.0021, -0.0369,  ..., -0.0358, -0.1037,  0.0084],
#                       [-0.0079, -0.0052,  0.0023,  ..., -0.0029, -0.0313,  0.0016]])),
#              ('roberta.encoder.layer.21.output.dense.bias',
#               tensor([-0.0101,  0.0066, -0.0726,  ...,  0.0920, -0.1208,  0.0153])),
#              ('roberta.encoder.layer.21.output.LayerNorm.weight',
#               tensor([0.9697, 0.9912, 0.9961,  ..., 0.9834, 0.9863, 0.9961])),
#              ('roberta.encoder.layer.21.output.LayerNorm.bias',
#               tensor([-0.0435, -0.0139,  0.0396,  ..., -0.0394, -0.0566, -0.0170])),
#              ('roberta.encoder.layer.22.attention.self.query.weight',
#               tensor([[ 0.0033,  0.0378,  0.0875,  ...,  0.0182,  0.0172,  0.0580],
#                       [ 0.0182, -0.0406,  0.0043,  ..., -0.1017,  0.0530,  0.0099],
#                       [ 0.0972, -0.0285,  0.1843,  ...,  0.0121,  0.0566, -0.0079],
#                       ...,
#                       [-0.0077, -0.0126, -0.0793,  ..., -0.0675, -0.0027,  0.0722],
#                       [-0.0414,  0.0721, -0.0108,  ...,  0.0606, -0.0375, -0.0322],
#                       [ 0.0363,  0.0595,  0.0999,  ...,  0.0265, -0.0226, -0.0805]])),
#              ('roberta.encoder.layer.22.attention.self.query.bias',
#               tensor([-0.0051,  0.0072,  0.1514,  ...,  0.0018,  0.0993, -0.0552])),
#              ('roberta.encoder.layer.22.attention.self.key.weight',
#               tensor([[-6.6284e-02, -5.3131e-02,  7.1960e-02,  ...,  4.0665e-03,
#                        -5.8258e-02,  4.7577e-02],
#                       [ 3.0533e-02, -2.7206e-02,  2.3895e-02,  ...,  3.1891e-02,
#                        -1.0452e-02,  1.2917e-02],
#                       [ 2.0981e-03,  3.3142e-02,  9.5581e-02,  ...,  1.7624e-02,
#                        -1.3084e-02,  1.5991e-02],
#                       ...,
#                       [ 7.5378e-02,  7.6652e-05, -9.9060e-02,  ..., -6.1523e-02,
#                        -5.4291e-02, -9.2346e-02],
#                       [ 2.3193e-02,  6.7444e-02, -5.3619e-02,  ...,  3.6560e-02,
#                         3.6591e-02, -3.8757e-02],
#                       [-5.2948e-02,  1.7349e-02, -2.7420e-02,  ..., -1.0078e-02,
#                         1.9791e-02, -8.2245e-03]])),
#              ('roberta.encoder.layer.22.attention.self.key.bias',
#               tensor([ 7.1526e-06, -1.4937e-04,  4.6706e-04,  ..., -2.0421e-04,
#                       -5.9032e-04, -6.9571e-04])),
#              ('roberta.encoder.layer.22.attention.self.value.weight',
#               tensor([[ 0.0254,  0.0334,  0.0428,  ...,  0.0432, -0.0222,  0.0514],
#                       [-0.0437, -0.0137, -0.0157,  ...,  0.0526, -0.0729,  0.0563],
#                       [-0.0193,  0.0346,  0.0061,  ..., -0.0042, -0.0190,  0.0230],
#                       ...,
#                       [-0.0412,  0.0008, -0.0150,  ..., -0.0330,  0.0291, -0.0468],
#                       [ 0.0182,  0.0146,  0.0360,  ...,  0.0062,  0.0050, -0.0352],
#                       [-0.0230, -0.0196, -0.0385,  ..., -0.0251,  0.0119,  0.0231]])),
#              ('roberta.encoder.layer.22.attention.self.value.bias',
#               tensor([ 0.0076, -0.0129,  0.0142,  ..., -0.0120, -0.0048, -0.0074])),
#              ('roberta.encoder.layer.22.attention.output.dense.weight',
#               tensor([[ 0.0420,  0.0490, -0.0052,  ..., -0.0356, -0.0329, -0.0120],
#                       [ 0.0088,  0.0243,  0.0286,  ..., -0.0477,  0.0071,  0.0270],
#                       [ 0.0182,  0.0049, -0.0265,  ..., -0.0233,  0.0509, -0.0038],
#                       ...,
#                       [ 0.0328,  0.0277, -0.0227,  ...,  0.0107, -0.0222, -0.0115],
#                       [ 0.0429, -0.0165,  0.0177,  ..., -0.0161, -0.0071, -0.0428],
#                       [ 0.0327,  0.0400,  0.0391,  ..., -0.0348,  0.0059, -0.0033]])),
#              ('roberta.encoder.layer.22.attention.output.dense.bias',
#               tensor([ 0.0768,  0.0949,  0.0674,  ...,  0.0083,  0.1467, -0.0307])),
#              ('roberta.encoder.layer.22.attention.output.LayerNorm.weight',
#               tensor([0.9541, 0.9883, 0.9966,  ..., 0.9751, 0.9966, 0.9868])),
#              ('roberta.encoder.layer.22.attention.output.LayerNorm.bias',
#               tensor([-0.0478, -0.0132, -0.1199,  ..., -0.0383, -0.1026,  0.0332])),
#              ('roberta.encoder.layer.22.intermediate.dense.weight',
#               tensor([[-0.0018, -0.0679, -0.0494,  ..., -0.0092,  0.0080,  0.0772],
#                       [-0.0171, -0.0195,  0.0640,  ...,  0.0034,  0.0453, -0.0015],
#                       [-0.0293, -0.0692,  0.0753,  ...,  0.0114, -0.0121, -0.0465],
#                       ...,
#                       [-0.0327,  0.0271,  0.0451,  ...,  0.0469,  0.0083,  0.0372],
#                       [ 0.0629,  0.0210,  0.0444,  ...,  0.0233, -0.0061,  0.0048],
#                       [ 0.0040, -0.0736, -0.0578,  ..., -0.0042,  0.0218, -0.0502]])),
#              ('roberta.encoder.layer.22.intermediate.dense.bias',
#               tensor([ 0.0179, -0.0073, -0.0130,  ..., -0.0444,  0.0150, -0.0280])),
#              ('roberta.encoder.layer.22.output.dense.weight',
#               tensor([[-0.0260,  0.0398, -0.0241,  ...,  0.0072, -0.0063, -0.0860],
#                       [ 0.0119, -0.0277,  0.0232,  ..., -0.0092, -0.0304,  0.0136],
#                       [-0.0164, -0.0119, -0.0038,  ...,  0.0016, -0.0003,  0.0111],
#                       ...,
#                       [-0.0134, -0.0316,  0.0100,  ..., -0.0212, -0.0068,  0.0564],
#                       [ 0.0159, -0.0377,  0.0404,  ..., -0.0080, -0.0247, -0.0257],
#                       [-0.0078,  0.0710,  0.0314,  ..., -0.0225,  0.0064, -0.0239]])),
#              ('roberta.encoder.layer.22.output.dense.bias',
#               tensor([ 0.0236,  0.0465, -0.0757,  ...,  0.0240, -0.1323,  0.0455])),
#              ('roberta.encoder.layer.22.output.LayerNorm.weight',
#               tensor([0.9561, 0.9937, 0.9971,  ..., 0.9824, 0.9912, 0.9829])),
#              ('roberta.encoder.layer.22.output.LayerNorm.bias',
#               tensor([-0.0231,  0.0381,  0.0500,  ..., -0.0329, -0.0123,  0.0165])),
#              ('roberta.encoder.layer.23.attention.self.query.weight',
#               tensor([[-0.0344,  0.0238,  0.0925,  ..., -0.0897,  0.0875,  0.0668],
#                       [-0.0428,  0.0215,  0.1016,  ..., -0.0060, -0.0135, -0.0045],
#                       [ 0.0348,  0.0420,  0.0307,  ..., -0.0086, -0.0893, -0.0343],
#                       ...,
#                       [ 0.1002, -0.0528,  0.1249,  ..., -0.0049, -0.0109,  0.0663],
#                       [-0.0479,  0.0012, -0.0022,  ..., -0.0515, -0.0171, -0.0155],
#                       [-0.0127, -0.0463, -0.0592,  ...,  0.0462, -0.0668,  0.0146]])),
#              ('roberta.encoder.layer.23.attention.self.query.bias',
#               tensor([ 0.0780,  0.2722,  0.0301,  ..., -0.2014,  0.1132,  0.0771])),
#              ('roberta.encoder.layer.23.attention.self.key.weight',
#               tensor([[ 0.0584, -0.0312,  0.2179,  ..., -0.0163,  0.0306,  0.0215],
#                       [ 0.0736, -0.0643,  0.0657,  ...,  0.0124, -0.0495,  0.0072],
#                       [-0.1159, -0.0253, -0.0377,  ..., -0.1288,  0.0432, -0.0252],
#                       ...,
#                       [ 0.0532,  0.0073,  0.0698,  ..., -0.0457,  0.0011,  0.0541],
#                       [ 0.0204, -0.0007, -0.0652,  ..., -0.0271,  0.0352,  0.0350],
#                       [-0.0142, -0.0168, -0.0170,  ...,  0.1071,  0.0038,  0.0629]])),
#              ('roberta.encoder.layer.23.attention.self.key.bias',
#               tensor([ 0.0000e+00,  0.0000e+00,  3.7611e-05,  ...,  6.2500e-02,
#                        1.4722e-05, -1.9526e-04])),
#              ('roberta.encoder.layer.23.attention.self.value.weight',
#               tensor([[-0.0672, -0.0675, -0.0098,  ..., -0.0340,  0.0020,  0.0076],
#                       [ 0.0228,  0.0076,  0.0388,  ..., -0.0288,  0.0032, -0.0462],
#                       [-0.0406,  0.0640, -0.0136,  ...,  0.0078, -0.0466, -0.0098],
#                       ...,
#                       [ 0.0501,  0.0296, -0.0295,  ..., -0.0133, -0.0237,  0.0161],
#                       [ 0.0028, -0.0348,  0.0274,  ..., -0.0147, -0.0001,  0.0126],
#                       [ 0.0114, -0.0212,  0.0245,  ..., -0.0004,  0.0173,  0.0146]])),
#              ('roberta.encoder.layer.23.attention.self.value.bias',
#               tensor([-0.0155,  0.0180,  0.0120,  ...,  0.0075,  0.0072,  0.0132])),
#              ('roberta.encoder.layer.23.attention.output.dense.weight',
#               tensor([[-0.0207, -0.0080, -0.0011,  ...,  0.0384, -0.0315,  0.0331],
#                       [-0.0367, -0.0047,  0.0260,  ...,  0.0552, -0.0101, -0.0481],
#                       [-0.0257,  0.0097,  0.0090,  ..., -0.0109,  0.0160, -0.0322],
#                       ...,
#                       [-0.0017, -0.0469, -0.0107,  ..., -0.0216, -0.0013, -0.0090],
#                       [ 0.0173,  0.0432,  0.0164,  ...,  0.0112,  0.0047,  0.0042],
#                       [ 0.0380, -0.0132, -0.0239,  ..., -0.0108,  0.0131,  0.0138]])),
#              ('roberta.encoder.layer.23.attention.output.dense.bias',
#               tensor([ 0.0640,  0.0726, -0.0046,  ...,  0.0315,  0.0211,  0.1617])),
#              ('roberta.encoder.layer.23.attention.output.LayerNorm.weight',
#               tensor([0.9619, 0.9805, 0.9937,  ..., 0.9810, 0.9917, 0.9644])),
#              ('roberta.encoder.layer.23.attention.output.LayerNorm.bias',
#               tensor([-0.1349,  0.0312, -0.1586,  ..., -0.0664, -0.1432, -0.0922])),
#              ('roberta.encoder.layer.23.intermediate.dense.weight',
#               tensor([[-0.0112, -0.0869, -0.0142,  ..., -0.0096,  0.0169, -0.0261],
#                       [-0.0146, -0.0241, -0.0116,  ..., -0.0115,  0.0173, -0.0637],
#                       [ 0.0008, -0.0923, -0.0033,  ...,  0.0326,  0.0343, -0.0215],
#                       ...,
#                       [-0.0409,  0.0268,  0.0119,  ..., -0.0029, -0.0405, -0.0081],
#                       [ 0.0434,  0.0025, -0.0067,  ..., -0.0121,  0.0637,  0.0384],
#                       [ 0.0348, -0.0151, -0.0295,  ...,  0.0524,  0.0290,  0.0393]])),
#              ('roberta.encoder.layer.23.intermediate.dense.bias',
#               tensor([ 0.0085, -0.0684, -0.1255,  ..., -0.0403, -0.0952, -0.0114])),
#              ('roberta.encoder.layer.23.output.dense.weight',
#               tensor([[ 0.0229, -0.0396, -0.0189,  ...,  0.0182,  0.0236, -0.0075],
#                       [ 0.0120,  0.0641, -0.0241,  ..., -0.0137, -0.0395,  0.0267],
#                       [-0.0031, -0.0097,  0.0091,  ...,  0.0130, -0.0261, -0.0145],
#                       ...,
#                       [ 0.0150, -0.0355,  0.0850,  ...,  0.0314, -0.0135,  0.0417],
#                       [ 0.0082, -0.0177,  0.0474,  ...,  0.0078,  0.0259, -0.0064],
#                       [-0.0393,  0.0069,  0.0051,  ...,  0.0363,  0.0073, -0.0131]])),
#              ('roberta.encoder.layer.23.output.dense.bias',
#               tensor([-0.0757, -0.0241, -0.0956,  ...,  0.0764, -0.1582,  0.0786])),
#              ('roberta.encoder.layer.23.output.LayerNorm.weight',
#               tensor([0.9780, 0.9946, 0.9976,  ..., 0.9819, 1.0000, 0.9883])),
#              ('roberta.encoder.layer.23.output.LayerNorm.bias',
#               tensor([-0.0241, -0.0406, -0.0134,  ..., -0.0475,  0.0083, -0.0058])),
#              ('lm_head.bias', tensor([0., 0., 0.,  ..., 0., 0., 0.])),
#              ('lm_head.dense.weight',
#               tensor([[ 0.1624,  0.1058, -0.0062,  ..., -0.0289,  0.1204,  0.0506],
#                       [-0.1910,  0.1462, -0.1040,  ...,  0.0452,  0.0129,  0.0105],
#                       [ 0.1070,  0.1498,  0.0863,  ...,  0.0281,  0.0340,  0.0294],
#                       ...,
#                       [-0.0867,  0.0685,  0.0728,  ...,  0.2253, -0.0117,  0.0271],
#                       [-0.0258,  0.0682,  0.2668,  ...,  0.0004,  0.1016,  0.0442],
#                       [-0.2268,  0.0408, -0.0399,  ...,  0.0407,  0.0566,  0.2603]])),
#              ('lm_head.dense.bias',
#               tensor([ 0.0338,  0.0167, -0.0032,  ...,  0.0117,  0.0044,  0.0405])),
#              ('lm_head.layer_norm.weight',
#               tensor([0.9956, 0.9985, 1.0000,  ..., 1.0000, 0.9995, 1.0000])),
#              ('lm_head.layer_norm.bias',
#               tensor([-0.2489, -0.2495, -0.2534,  ...,  0.1421,  0.1273, -0.2520])),
#              ('lm_head.decoder.weight',
#               tensor([[-0.1406, -0.0096,  0.0391,  ...,  0.0508, -0.0059, -0.0360],
#                       [ 0.0078, -0.0156,  0.0156,  ..., -0.0156,  0.0231,  0.0156],
#                       [-0.0828, -0.0007, -0.1174,  ...,  0.1086,  0.0696, -0.0356],
#                       ...,
#                       [ 0.0393,  0.0031,  0.0465,  ..., -0.0240, -0.0505,  0.0342],
#                       [ 0.0499,  0.0272,  0.0413,  ..., -0.0370, -0.0100,  0.0071],
#                       [-0.0149, -0.0114, -0.0222,  ...,  0.0441,  0.0116, -0.0330]])),
#              ('lm_head.decoder.bias', tensor([0., 0., 0.,  ..., 0., 0., 0.]))])

# %%
type(roberta)
# Out:
# transformers.models.roberta.modeling_roberta.RobertaForMaskedLM

# %%
from transformers.models.roberta.modeling_roberta import RobertaEncoder, RobertaModel
from torch.nn import Module

def distill_roberta_weights(
    teacher : Module,
    student : Module,
) -> None:
    """
    Recursively copies the weights of the (teacher) to the (student).
    This function is meant to be first called on a RobertaFor... model, but is then called on every children of that model recursively.
    The only part that's not fully copied is the encoder, of which only half is copied.
    """
    # If the part is an entire RoBERTa model or a RobertaFor..., unpack and iterate
    if isinstance(teacher, RobertaModel) or type(teacher).__name__.startswith('RobertaFor'):
        for teacher_part, student_part in zip(teacher.children(), student.children()):
            distill_roberta_weights(teacher_part, student_part)
    # Else if the part is an encoder, copy one out of every layer
    elif isinstance(teacher, RobertaEncoder):
            teacher_encoding_layers = [layer for layer in next(teacher.children())]
            student_encoding_layers = [layer for layer in next(student.children())]
            for i in range(len(student_encoding_layers)):
                student_encoding_layers[i].load_state_dict(teacher_encoding_layers[2*i].state_dict())
    # Else the part is a head or something else, copy the state_dict
    else:
        student.load_state_dict(teacher.state_dict())

# %%
student_model = distill_roberta(roberta)

# %%
total_params = sum(p.numel() for p in student.parameters())
param_size = 4

print(total_params /100000)
total_size = total_params * param_size / (1024 * 1024)
print(f'Model size in memory: {total_size:.2f} MB')
# Out:
# 2042.57369
# Model size in memory: 779.18 MB

# %%
import torch
from transformers import AutoTokenizer
from transformers.models.roberta.modeling_roberta import RobertaForMaskedLM

# Assuming you have already defined the distill_roberta function and the distill_roberta_weights function

# Load the teacher model
teacher_model = RobertaForMaskedLM.from_pretrained("roberta-large")

# Create the student model
student_model = distill_roberta(teacher_model)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("roberta-large")

# Prepare the input text with a masked token
input_text = "The capital of France is <mask>."
input_ids = tokenizer.encode(input_text, return_tensors="pt")  # Convert to tensor

# Print the tokenized input IDs and their corresponding tokens
print("Input IDs:", input_ids)
print("Tokens:", tokenizer.convert_ids_to_tokens(input_ids[0]))

# Run the student model
with torch.no_grad():  # Disable gradient calculation for inference
    outputs = student_model(input_ids)
    logits = outputs.logits  # Get the logits (predictions)

# Decode the predictions
# Get the index of the masked token
masked_indices = torch.where(input_ids == tokenizer.mask_token_id)[1]

# Check if any masked tokens were found
if masked_indices.size(0) == 0:
    print("No [MASK] token found in the input.")
else:
    masked_index = masked_indices.item()

    # Get the predicted token logits for the masked position
    predicted_logits = logits[0, masked_index]  # logits for the masked position

    # Get the top predicted token (word) for the masked position
    top_k = 5  # Get top 5 predictions
    top_k_indices = predicted_logits.topk(top_k).indices.tolist()
    predicted_tokens = tokenizer.convert_ids_to_tokens(top_k_indices)

    # Print the predictions
    print(f"Input Text: {input_text}")
    print("Top Predictions for [MASK]:")
    for token in predicted_tokens:
        print(token)
# Out:
# Input IDs: tensor([[    0,   133,   812,     9,  1470,    16, 50264,     4,     2]])
# Tokens: ['<s>', 'The', 'Ġcapital', 'Ġof', 'ĠFrance', 'Ġis', '<mask>', '.', '</s>']
# Input Text: The capital of France is <mask>.
# Top Predictions for [MASK]:
# Ġexemplary
# Ġundeniable
# ĠColumbus
# ĠWaterloo
# Ġnoteworthy

# %%
import torch
from transformers import AutoTokenizer, RobertaForMaskedLM

# Step 1: Load the teacher model
teacher_model = RobertaForMaskedLM.from_pretrained("roberta-large")

# Step 2: Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("roberta-large")

# Step 3: Prepare the input text with the correct mask token
input_text = "The capital of France is <mask>."
input_ids = tokenizer.encode(input_text, return_tensors="pt")  # Convert to tensor

# Print the tokenized input IDs and their corresponding tokens
print("Input IDs:", input_ids)
print("Tokens:", tokenizer.convert_ids_to_tokens(input_ids[0]))

# Step 4: Run the teacher model
with torch.no_grad():  # Disable gradient calculation for inference
    outputs = teacher_model(input_ids)
    logits = outputs.logits  # Get the logits (predictions)

# Step 5: Decode the predictions
# Get the index of the masked token
masked_indices = torch.where(input_ids == tokenizer.mask_token_id)[1]

# Check if any masked tokens were found
if masked_indices.size(0) == 0:
    print("No <mask> token found in the input.")
else:
    masked_index = masked_indices.item()

    # Get the predicted token logits for the masked position
    predicted_logits = logits[0, masked_index]  # logits for the masked position

    # Get the top predicted token (word) for the masked position
    top_k = 5  # Get top 5 predictions
    top_k_indices = predicted_logits.topk(top_k).indices.tolist()
    predicted_tokens = tokenizer.convert_ids_to_tokens(top_k_indices)

    # Print the predictions
    print(f"Input Text: {input_text}")
    print("Top Predictions for <mask>:")
    for token in predicted_tokens:
        print(token)
# Out:
# Input IDs: tensor([[    0,   133,   812,     9,  1470,    16, 50264,     4,     2]])
# Tokens: ['<s>', 'The', 'Ġcapital', 'Ġof', 'ĠFrance', 'Ġis', '<mask>', '.', '</s>']
# Input Text: The capital of France is <mask>.
# Top Predictions for <mask>:
# ĠParis
# ĠLyon
# ĠFrance
# ĠNice
# ĠLondon

# %%
from transformers import AutoTokenizer

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("roberta-large")

# Get the tokenizer size (vocabulary size)
tokenizer_size = tokenizer.vocab_size

# Print the tokenizer size
print("Tokenizer Size:", tokenizer_size)
# Out:
# Tokenizer Size: 50265

# %%
import sys
sys.getsizeof(tokenizer)
# Out:
# 48

# %%
tokenizer
# Out:
# RobertaTokenizerFast(name_or_path='roberta-large', vocab_size=50265, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': '<mask>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	1: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	3: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# 	50264: AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=False, special=True),
# }

# %%
from transformers import AutoTokenizer

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("roberta-large")

# Example text
text = "The capital of France is <mask>."

# Tokenize the input text
tokens = tokenizer.tokenize(text)
token_ids = tokenizer.encode(text, return_tensors='pt')  # Convert to tensor

# Print results
print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Tokens: ['The', 'Ġcapital', 'Ġof', 'ĠFrance', 'Ġis', ' <mask>', '.']
# Token IDs: tensor([[    0,   133,   812,     9,  1470,    16, 50264,     4,     2]])

# %%
import torch.nn as nn

class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.layer1 = nn.Linear(10, 20)
        self.layer2 = nn.ReLU()
        self.layer3 = nn.Sequential(
            nn.Linear(20, 30),
            nn.ReLU()
        )
    
    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        return x

model = SimpleModel()
for child in model.children():
    print(child)
# Out:
# Linear(in_features=10, out_features=20, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=20, out_features=30, bias=True)
#   (1): ReLU()
# )

# %%
model.state_dict()
# Out:
# OrderedDict([('layer1.weight',
#               tensor([[ 0.2710,  0.2512,  0.1177, -0.2401, -0.1383, -0.1342, -0.1413,  0.0147,
#                        -0.2559,  0.2947],
#                       [ 0.1203, -0.0462,  0.2431,  0.2607,  0.2085, -0.0728,  0.2010, -0.0268,
#                         0.0496, -0.1994],
#                       [-0.2354,  0.1857,  0.1835,  0.1257, -0.2048,  0.2469,  0.2793, -0.2880,
#                         0.2274,  0.2749],
#                       [ 0.0772, -0.1103,  0.0012, -0.2032,  0.2379, -0.1303,  0.2110, -0.2235,
#                        -0.2647, -0.0288],
#                       [ 0.0209,  0.1875,  0.2497, -0.1036, -0.0693,  0.2917,  0.1314, -0.2609,
#                         0.0766, -0.2290],
#                       [ 0.0724,  0.0066,  0.1293, -0.2194, -0.1749,  0.2121, -0.0355, -0.1464,
#                        -0.0912, -0.0704],
#                       [-0.2104, -0.1687, -0.2671,  0.2304, -0.1537, -0.2162, -0.2994, -0.0780,
#                         0.1128,  0.0612],
#                       [-0.2622,  0.1203,  0.0109,  0.0411, -0.1319,  0.3085,  0.0624, -0.1246,
#                         0.2533, -0.1039],
#                       [ 0.2429,  0.0899,  0.2645,  0.3023,  0.0671, -0.0612,  0.0261,  0.2367,
#                         0.2217, -0.2554],
#                       [-0.2922, -0.1912,  0.0516, -0.1910,  0.2355, -0.2605,  0.1800, -0.2654,
#                         0.2427,  0.2062],
#                       [ 0.1175, -0.2587,  0.1336, -0.2122,  0.1165,  0.2938, -0.2085, -0.0125,
#                        -0.0260,  0.2904],
#                       [ 0.2841, -0.2743,  0.2973, -0.2210,  0.0215, -0.1989,  0.1082, -0.1170,
#                         0.2993,  0.1600],
#                       [-0.0292, -0.1527, -0.1175,  0.2695,  0.2443, -0.2427, -0.2738,  0.2438,
#                        -0.0453, -0.2791],
#                       [ 0.1191,  0.2867, -0.2099,  0.0505,  0.0054, -0.0903,  0.1903, -0.0631,
#                        -0.0476, -0.3061],
#                       [-0.0234,  0.1258, -0.2936,  0.1318,  0.1317,  0.1697, -0.2274,  0.2190,
#                        -0.1338,  0.0299],
#                       [-0.0242, -0.1219, -0.1829, -0.0643, -0.0630, -0.2251,  0.0123, -0.3023,
#                        -0.0749,  0.0314],
#                       [-0.0189,  0.1354,  0.1184,  0.2860, -0.2163, -0.0299,  0.2758,  0.2927,
#                         0.2445,  0.1656],
#                       [ 0.1401, -0.0156,  0.1541,  0.2530,  0.1833,  0.1868, -0.3003, -0.2089,
#                         0.1505,  0.2774],
#                       [-0.0248,  0.1229, -0.3142, -0.1320, -0.2392, -0.2224,  0.1812,  0.1666,
#                         0.0268, -0.0135],
#                       [-0.0275, -0.2945, -0.1150,  0.1439,  0.0448, -0.1536,  0.1899,  0.2083,
#                         0.2948,  0.2712]])),
#              ('layer1.bias',
#               tensor([ 0.3128, -0.1163,  0.2547,  0.2307,  0.2610, -0.0818,  0.1760,  0.2509,
#                        0.1021, -0.1216, -0.2004,  0.2921,  0.0914, -0.1303, -0.1687,  0.1461,
#                       -0.0997,  0.3123,  0.0715, -0.1039])),
#              ('layer3.0.weight',
#               tensor([[ 9.5427e-03, -6.7327e-02,  2.2342e-01,  1.0510e-01, -2.1517e-01,
#                         6.4437e-02,  1.2456e-01, -1.6353e-01,  1.3321e-01, -6.0480e-02,
#                         5.1264e-02,  1.7208e-01, -2.0411e-01,  9.7752e-02, -7.9005e-03,
#                         9.5457e-02,  1.9289e-01, -1.9254e-01, -1.9659e-01, -2.0501e-02],
#                       [ 8.9281e-02,  1.6493e-01,  7.8441e-02, -1.7154e-01,  1.6761e-01,
#                        -1.4749e-01,  5.7712e-02,  2.9872e-02,  1.9004e-01, -1.2165e-01,
#                         6.4547e-02, -8.1712e-02,  1.3209e-01, -1.7171e-01,  9.5781e-02,
#                        -1.4396e-01,  1.7675e-01,  1.4856e-01, -1.4506e-01,  1.3161e-01],
#                       [-1.3009e-01, -2.0321e-02,  8.6589e-02, -1.6295e-01, -7.0199e-02,
#                        -2.0102e-01,  1.7371e-01, -1.7636e-01, -4.1770e-02, -8.3477e-02,
#                         1.7677e-01,  1.7848e-01, -6.0041e-02,  8.7586e-02,  9.3456e-02,
#                        -1.2390e-01,  1.3865e-01,  8.3327e-02,  6.1117e-02, -1.4770e-01],
#                       [ 3.5098e-02,  8.9008e-02,  1.5541e-01,  4.1551e-02,  1.4444e-01,
#                         6.8353e-02, -2.6162e-02,  9.9753e-02, -5.8357e-02, -6.7179e-03,
#                         5.8706e-02,  4.0298e-02,  1.6055e-01, -1.3538e-01,  2.2309e-02,
#                         6.6463e-02,  1.8887e-01, -1.2486e-01, -1.5858e-01, -1.3196e-01],
#                       [-1.3814e-01, -2.0336e-01, -1.2641e-01, -2.0643e-01,  2.0322e-01,
#                         6.0874e-02,  1.6577e-01, -8.6739e-02,  4.8661e-02, -2.1972e-01,
#                        -7.2305e-03, -1.3908e-01, -1.7127e-01,  3.8171e-02,  1.2477e-01,
#                        -2.0925e-01, -8.0474e-02, -2.7233e-02,  1.5129e-02, -1.3618e-01],
#                       [-2.0913e-02, -2.0197e-01, -1.3352e-01, -1.5553e-01, -1.4369e-01,
#                        -9.6491e-02, -2.1466e-01,  1.0335e-01,  1.6773e-02,  9.6080e-02,
#                         4.8181e-02,  1.3718e-01,  8.4296e-02,  1.1138e-01,  9.0516e-02,
#                         6.2336e-02,  1.4318e-01,  2.5555e-02,  7.8068e-02,  2.0052e-01],
#                       [-8.4910e-02, -1.5846e-01,  5.8086e-02,  1.7421e-01,  1.6379e-01,
#                        -6.7586e-02, -9.4167e-03,  2.1926e-02, -1.0150e-02, -9.4381e-02,
#                        -1.8629e-01,  2.1817e-01, -3.2766e-02,  1.5128e-01,  7.1625e-02,
#                         8.0583e-02,  7.9055e-02,  1.0480e-01,  5.4329e-02, -4.1963e-02],
#                       [-9.7030e-03,  2.9942e-02, -4.8124e-03, -2.0270e-01, -2.4241e-03,
#                        -1.1192e-01, -8.9002e-02, -1.6343e-04,  1.9542e-01,  9.2095e-02,
#                        -1.8163e-01, -1.2979e-01,  9.0557e-02,  1.4708e-01,  9.6428e-02,
#                         1.0330e-01,  1.3867e-01, -6.3829e-02,  1.8496e-01, -2.0597e-02],
#                       [ 4.3242e-02,  2.2117e-01,  1.0434e-02, -1.3446e-01,  6.6377e-02,
#                        -3.8312e-02,  1.1310e-01, -8.2974e-02,  1.4101e-01, -9.2399e-03,
#                         1.5248e-01, -1.3209e-01,  2.1965e-01, -2.0341e-01,  1.2072e-01,
#                         3.6803e-02, -4.1319e-02,  1.8242e-01, -6.6222e-02,  1.7689e-02],
#                       [ 1.8879e-01, -5.8582e-02,  3.0550e-02,  9.6409e-02,  1.6422e-02,
#                         2.0703e-01,  1.6063e-04,  1.5894e-01,  2.9904e-03, -1.5718e-01,
#                         1.7234e-01, -1.7237e-01,  2.0195e-01,  9.1947e-02, -1.2124e-01,
#                        -1.2820e-01,  2.1360e-01,  1.1344e-01,  1.4035e-01,  4.3661e-02],
#                       [ 1.2788e-01, -6.3561e-02,  4.3051e-02, -1.7805e-01, -1.5714e-02,
#                         1.7959e-01, -7.8308e-02, -1.6416e-01,  2.1720e-01, -1.8484e-01,
#                         3.0029e-02, -1.4350e-01,  1.7945e-01, -7.4081e-02, -3.5322e-02,
#                         1.1009e-01,  2.1758e-01,  1.3745e-01, -1.0872e-01, -1.7306e-01],
#                       [ 1.6985e-01, -1.4135e-01,  8.5187e-02,  1.9863e-01, -9.3568e-02,
#                        -1.5443e-01, -5.0839e-02, -2.1347e-01, -1.7288e-01,  1.0854e-01,
#                         2.1568e-01, -1.4306e-01,  3.8360e-02,  1.1624e-02, -2.1332e-01,
#                        -9.9387e-02,  1.2545e-01, -1.5791e-01,  2.1071e-02,  9.2360e-02],
#                       [ 2.1026e-01,  1.7119e-01, -1.6966e-01, -1.9688e-01, -2.1091e-02,
#                        -6.0585e-02,  1.9883e-01,  1.2270e-03, -4.5590e-02, -3.5899e-02,
#                         1.4868e-01,  3.5455e-02, -8.3948e-02,  7.1781e-03,  2.0144e-01,
#                         1.7079e-01,  1.4326e-01, -4.3098e-02, -2.1347e-01,  2.0695e-01],
#                       [ 1.9146e-01,  2.1898e-01,  2.4764e-02,  1.2611e-01,  8.1677e-02,
#                         3.5846e-02, -5.5154e-02,  1.2548e-02,  1.5804e-01,  1.0508e-01,
#                         9.9920e-02, -1.1392e-01,  1.3943e-01, -4.7481e-02,  1.6812e-01,
#                        -4.5839e-02, -1.0932e-01,  8.0896e-02,  1.5725e-01, -1.8519e-01],
#                       [-1.3575e-01, -1.8374e-01, -1.7341e-01, -3.2859e-02,  2.0814e-01,
#                        -1.5577e-01,  1.2165e-01, -1.2690e-01, -3.1999e-02,  1.5670e-01,
#                         1.9714e-01, -1.2255e-02, -3.2493e-02,  6.0851e-02,  2.2350e-02,
#                        -1.7940e-01,  7.3341e-02, -5.5051e-02, -2.6665e-02,  1.0608e-01],
#                       [-1.7443e-01,  7.8949e-02, -7.5424e-02, -1.8087e-01,  1.4922e-01,
#                        -8.5123e-04,  7.7955e-02, -1.9988e-01,  1.5398e-01, -1.0405e-01,
#                        -1.4699e-01,  1.6900e-01,  9.0099e-02,  1.1239e-01, -8.0565e-04,
#                        -9.0194e-02,  2.1645e-01,  7.7312e-02, -1.1700e-01,  1.1662e-01],
#                       [-7.4635e-02,  9.2250e-02,  7.1684e-02,  2.2107e-01,  1.4829e-01,
#                         4.1248e-02, -5.3157e-02,  5.6425e-02,  1.6875e-01,  3.7904e-02,
#                         1.0475e-02,  6.2456e-02,  1.9019e-01,  1.3101e-01, -8.7970e-02,
#                        -1.1483e-01,  1.7659e-01,  7.0522e-02, -1.6324e-01, -2.0120e-01],
#                       [-1.4051e-01,  2.4332e-02, -3.3379e-02, -3.9865e-02, -1.9910e-01,
#                        -6.9035e-02, -2.0330e-01,  1.9584e-01,  1.4314e-01,  1.5503e-01,
#                         1.5632e-01,  1.7327e-01, -3.0280e-03, -4.4658e-02, -1.7919e-01,
#                        -1.9480e-02, -2.0707e-01, -1.4648e-01,  8.1710e-02,  1.7411e-01],
#                       [ 4.3584e-02, -1.1618e-01,  8.3866e-02, -1.8693e-01, -1.5921e-02,
#                         1.0582e-01,  4.9375e-02,  3.9367e-02,  9.9437e-03,  6.3989e-02,
#                         1.9858e-01,  1.1195e-01, -1.0803e-01, -8.5094e-02, -1.0318e-01,
#                        -5.6671e-05,  6.0882e-02,  1.7052e-01, -9.6141e-02,  1.2534e-03],
#                       [ 2.1044e-01, -2.3156e-02,  5.7787e-03,  2.0201e-01, -5.7982e-02,
#                         1.0893e-01,  1.2531e-01,  1.9395e-01, -2.1422e-01, -1.6370e-01,
#                         1.5684e-01,  1.4420e-01,  1.7829e-01,  2.0758e-01, -6.2830e-02,
#                        -1.8497e-01, -1.0205e-01,  6.5521e-02, -6.7881e-02, -2.0903e-01],
#                       [ 1.1909e-01,  1.6212e-01,  2.1808e-01,  3.1604e-02, -1.1353e-01,
#                        -1.0079e-01, -1.5520e-01,  9.3007e-02, -5.5893e-02, -1.3566e-01,
#                         3.7298e-02, -5.6492e-02,  1.2600e-01, -1.3894e-01,  1.5095e-01,
#                        -1.2937e-01,  1.9078e-01, -2.1552e-01, -1.4091e-01,  1.4240e-01],
#                       [-6.1963e-02, -2.1722e-01, -3.3709e-02,  9.6027e-02, -7.6756e-02,
#                        -6.3379e-02, -1.0985e-01, -1.6790e-01, -4.5038e-03, -1.8935e-01,
#                        -1.2712e-01,  1.3589e-02, -2.1147e-02, -1.4934e-01, -5.3483e-02,
#                         9.9460e-02,  1.7814e-01, -1.3859e-01,  3.5531e-02, -1.0531e-01],
#                       [-9.9324e-02,  8.3831e-02, -2.4436e-02, -1.4290e-01,  1.0483e-01,
#                         2.1592e-01, -1.7569e-01, -1.8460e-01, -1.1339e-01,  1.1973e-01,
#                        -1.1164e-01,  7.8795e-03,  3.5756e-02, -1.0832e-01,  1.2667e-01,
#                        -1.3151e-01, -9.5198e-02,  1.9687e-01,  1.6561e-01, -1.6822e-01],
#                       [ 7.9356e-02, -1.4353e-01,  6.5876e-02, -1.4916e-01, -1.8136e-01,
#                         1.7906e-01, -4.8492e-02, -1.5440e-01,  1.2304e-01, -2.7571e-02,
#                         7.1966e-02, -2.0087e-02, -1.7302e-01, -9.2238e-02,  7.6359e-02,
#                        -1.7285e-01,  1.6139e-01,  1.2501e-01, -2.1935e-01,  1.8108e-01],
#                       [ 4.7005e-02,  1.9205e-01,  1.1744e-01, -2.9498e-02,  1.4299e-01,
#                         2.0696e-01, -1.1225e-01, -1.8752e-01, -1.6679e-01,  1.5145e-01,
#                        -2.0911e-01, -1.1498e-01,  2.1114e-01,  1.6537e-01,  9.3777e-02,
#                         1.5818e-02,  2.9142e-02,  5.8758e-02, -1.0508e-01, -1.2219e-01],
#                       [ 2.0362e-01, -4.8434e-02, -8.2114e-02, -1.5045e-01,  2.1250e-02,
#                        -9.3231e-02,  1.1280e-01, -8.6977e-02, -1.8675e-01, -2.0278e-01,
#                        -6.4960e-02,  1.4706e-01, -8.0882e-02,  1.5277e-01,  8.2401e-02,
#                        -1.5327e-01,  1.2083e-01, -2.2123e-01, -1.6140e-01,  6.1290e-02],
#                       [-3.1675e-02,  1.6423e-01,  6.6646e-02, -1.9448e-01,  1.3445e-01,
#                         3.6608e-02,  5.6568e-02,  1.1020e-01,  1.5587e-01, -1.4955e-01,
#                         1.3611e-01, -4.8875e-03, -2.1794e-01,  1.1819e-01,  1.5840e-02,
#                         7.5873e-02,  8.9135e-02, -1.0014e-01, -7.0789e-02, -8.6321e-02],
#                       [ 2.0540e-01, -6.6533e-02, -1.9123e-01, -1.1113e-01, -2.1605e-01,
#                        -2.1410e-01, -1.7170e-02, -1.8781e-01,  5.3228e-02, -1.5046e-01,
#                        -2.0183e-01,  1.7867e-01, -1.2853e-01, -4.2071e-02,  1.4823e-01,
#                         1.2745e-01,  1.1980e-01,  9.2681e-02, -8.4912e-02,  1.2437e-01],
#                       [ 1.0192e-01,  1.6813e-01, -1.4140e-01, -2.3483e-02, -1.4250e-01,
#                        -1.9250e-01, -2.5910e-02,  2.1357e-02,  8.0659e-02, -1.6364e-01,
#                         1.2550e-01,  9.4676e-02,  2.0302e-01, -4.9968e-02,  1.2568e-01,
#                        -6.2362e-02,  1.6636e-01, -1.2693e-01,  1.4676e-01,  1.7029e-01],
#                       [-1.9227e-01, -5.7881e-03, -8.3326e-02, -3.2156e-02, -1.7589e-01,
#                         1.9254e-01,  4.4179e-02, -1.1992e-01,  1.8260e-01, -8.0038e-02,
#                         1.0725e-01, -1.9194e-01, -3.2524e-03, -3.3661e-02,  2.1052e-01,
#                         1.5794e-02,  3.3831e-02,  1.5473e-01,  2.0946e-01,  1.3961e-01]])),
#              ('layer3.0.bias',
#               tensor([ 0.2153,  0.1580,  0.1936, -0.0361,  0.1173, -0.0122, -0.0522,  0.0941,
#                        0.0891,  0.0191, -0.0605, -0.1178,  0.1380,  0.1860, -0.0757,  0.1272,
#                        0.0892,  0.1933,  0.0398, -0.2232,  0.0594, -0.0115, -0.1945,  0.1660,
#                        0.0813,  0.1138, -0.2047, -0.1486, -0.0332, -0.1709]))])

# %%
next(model.children())
# Out:
# Linear(in_features=10, out_features=20, bias=True)

# %%
next(model.children())
# Out:
# Linear(in_features=10, out_features=20, bias=True)
