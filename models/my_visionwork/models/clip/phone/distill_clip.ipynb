# %%
# import torch
# from transformers import CLIPModel, CLIPProcessor
# import torch.nn as nn
# from torch.optim import Adam

# # Load Teacher CLIP Model
# teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
# teacher_model.eval()

# # Define a smaller student model by reducing the layers and hidden dimensions
# class StudentCLIPModel(nn.Module):
#     def __init__(self):
#         super(StudentCLIPModel, self).__init__()
#         # A smaller version of CLIP with fewer transformer layers and smaller hidden size
#         self.text_projection = nn.Linear(256, 128)
#         self.vision_projection = nn.Linear(384, 128)

#     def forward(self, text_features, vision_features):
#         # Forward pass through the projection layers
#         text_proj = self.text_projection(text_features)
#         vision_proj = self.vision_projection(vision_features)
#         return text_proj, vision_proj

# # Initialize Student Model
# student_model = StudentCLIPModel()

# %%
import os
import torch
from transformers import CLIPProcessor, CLIPModel
from datasets import load_dataset
from PIL import Image


def load_data(data_dir):
    images = []
    labels = []

    for label, folder in enumerate(['no_cell_phones', 'cell_phones']):
        folder_path = os.path.join(data_dir, folder)
        for filename in os.listdir(folder_path):
            if filename.endswith(('jpg', 'jpeg')):
                images.append(os.path.join(folder_path, filename))
                labels.append(label)

    return images, labels

images, labels = load_data('/home/ajeet/codework/datasets/train_clip/testing/')
dataset = {'image': images, 'label': labels}


from torch.utils.data import Dataset

class ImageLabelDataset(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels
        self.processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert("RGB")
        label = self.labels[idx]
        # encoding = self.processor(images=image, return_tensors="pt")
        inputs = self.processor(text=["no cell phone", "a cell phone"], images=image, return_tensors="pt", padding=True)
        return inputs, label

custom_dataset = ImageLabelDataset(images, labels)
print(custom_dataset)


model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
model.train()  # Set model to training mode


from torch.utils.data import DataLoader

dataloader = DataLoader(custom_dataset, batch_size=16, shuffle=True)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

num_epochs = 5

for epoch in range(num_epochs):
    for batch in dataloader:
        inputs, labels = batch
        optimizer.zero_grad()

        # Initialize the total loss for the batch
        total_loss = 0.0

        # Process each image in the batch
        for i in range(inputs['pixel_values'].shape[0]):  # Assuming 'pixel_values' holds your images
            # single_image_input = {k: v[i:i+1] for k, v in inputs.items()}  # Take a single image from the batch
            single_image_input = {k: v[i:i+1] if v.ndim == 4 else v[i] for k, v in inputs.items()}  # Ensure the correct shape
            
            label = labels[i:i+1]  # Get the corresponding label
            
            # Forward pass
            outputs = model(**single_image_input)
            logits_per_image = outputs.logits_per_image  # Similarity scores
            
            # Calculate the loss for the single image
            loss = torch.nn.functional.cross_entropy(logits_per_image, label)

            # Accumulate the loss
            total_loss += loss

        # Average the loss over the batch
        total_loss /= inputs['pixel_values'].shape[0]

        # Backward pass and optimization
        total_loss.backward()
        optimizer.step()

        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {total_loss.item():.4f}")



# for epoch in range(num_epochs):
#     for batch in dataloader:
#         inputs, labels = batch
#         optimizer.zero_grad()

#         # Forward pass
#         outputs = model(**inputs)
#         logits_per_image = outputs.logits_per_image  # Similarity scores
#         loss = torch.nn.functional.cross_entropy(logits_per_image, labels)

#         # Backward pass and optimization
#         loss.backward()
#         optimizer.step()

#         print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}")
# Out:
# <__main__.ImageLabelDataset object at 0x7f400a6bffd0>
# Epoch [1/5], Loss: 0.4878
# Epoch [2/5], Loss: 0.0861
# Epoch [3/5], Loss: 0.0000
# Epoch [4/5], Loss: 0.0002
# Epoch [5/5], Loss: 0.0023

# %%
# student_model

from PIL import Image
from transformers import CLIPModel, CLIPConfig, AutoProcessor

image = Image.open("/home/ajeet/codework/datasets/train_clip/testing/no_cell_phones/0_2.jpg")
text = ["no cell phone", "a cell phone"]
# text = ["a cell phone", "no cell phone"]

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

inputs = processor(text=text, images=image, return_tensors="pt", padding=True)

with torch.no_grad():
    outputs = model(**inputs)

logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)
print(probs)
# Out:
# tensor([[1.0000e+00, 1.2831e-10]])

# %%
from transformers import CLIPModel, CLIPConfig
import torch

def reduce_clip_layers(teacher_model: CLIPModel, num_text_layers: int, num_vision_layers: int) -> CLIPModel:
    config = teacher_model.config.to_dict()
    config['text_config']['num_hidden_layers'] = num_text_layers
    config['vision_config']['num_hidden_layers'] = num_vision_layers

    config['text_config']['intermediate_size'] = 512
    config['vision_config']['intermediate_size'] = 512

    config['text_config']['num_attention_heads'] = 2
    config['vision_config']['num_attention_heads'] = 2

    config['text_config']['hidden_size'] = 256
    config['vision_config']['hidden_size'] = 256
    
    student_config = CLIPConfig.from_dict(config)
    student_model = CLIPModel(student_config)
    
    return student_model

teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")

num_text_layers = 1
num_vision_layers = 1

student_model = reduce_clip_layers(teacher_model, num_text_layers, num_vision_layers)

without_fine_tune = student_model

# torch.save(student_model.state_dict(), "student_clip_model.pth")
# print(f"Reduced student model with {num_text_layers} text layers and {num_vision_layers} vision layers created.")

# %%
import os
import torch
from transformers import CLIPProcessor, CLIPModel
from datasets import load_dataset
from PIL import Image


def load_data(data_dir):
    images = []
    labels = []

    for label, folder in enumerate(['no_cell_phone', 'cell_phone']):
        folder_path = os.path.join(data_dir, folder)
        for filename in os.listdir(folder_path):
            if filename.endswith(('jpg', 'jpeg')):
                images.append(os.path.join(folder_path, filename))
                labels.append(label)

    return images, labels

images, labels = load_data('/home/ajeet/codework/datasets/train_clip/')
dataset = {'image': images, 'label': labels}

val_images, val_labels = load_data('/home/ajeet/codework/datasets/val_clip/')  # Load validation dataset
val_dataset = {'image': val_images, 'label': val_labels}


from torch.utils.data import Dataset

class ImageLabelDataset(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels
        self.processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch16")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert("RGB")
        label = self.labels[idx]
        # encoding = self.processor(images=image, return_tensors="pt")
        inputs = self.processor(text=["no cell phone", "a cell phone"], images=image, return_tensors="pt", padding=True)
        return inputs, label

custom_dataset = ImageLabelDataset(images, labels)
print(custom_dataset)


# model = CLIPModel.from_pretrained("openai/clip-vit-base-patch16")
model = student_model
model.train()  # Set model to training mode


from torch.utils.data import DataLoader

dataloader = DataLoader(custom_dataset, batch_size=16, shuffle=True)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

num_epochs = 2

for epoch in range(num_epochs):
    model.train()
    for batch in dataloader:
        inputs, labels = batch
        optimizer.zero_grad()

        # Initialize the total loss for the batch
        total_loss = 0.0

        # Process each image in the batch
        for i in range(inputs['pixel_values'].shape[0]):  # Assuming 'pixel_values' holds your images
            # single_image_input = {k: v[i:i+1] for k, v in inputs.items()}  # Take a single image from the batch
            single_image_input = {k: v[i:i+1] if v.ndim == 4 else v[i] for k, v in inputs.items()}  # Ensure the correct shape
            
            label = labels[i:i+1]  # Get the corresponding label
            
            # Forward pass
            outputs = model(**single_image_input)
            logits_per_image = outputs.logits_per_image  # Similarity scores
            
            # Calculate the loss for the single image
            loss = torch.nn.functional.cross_entropy(logits_per_image, label)

            # Accumulate the loss
            total_loss += loss

        # Average the loss over the batch
        total_loss /= inputs['pixel_values'].shape[0]

        # Backward pass and optimization
        total_loss.backward()
        optimizer.step()

        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {total_loss.item():.4f}")

    # Validation phase
    model.eval()  # Set model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():  # Disable gradient calculation
        for val_batch in val_dataloader:
            val_inputs, val_labels = val_batch
            val_outputs = model(**val_inputs)
            val_logits_per_image = val_outputs.logits_per_image

            # Get predictions
            _, predicted = torch.max(val_logits_per_image, 1)
            total += val_labels.size(0)  # Number of samples in this batch
            correct += (predicted == val_labels).sum().item()  # Count correct predictions

    accuracy = correct / total * 100  # Calculate accuracy as a percentage
    print(f"Epoch [{epoch + 1}/{num_epochs}], Validation Accuracy: {accuracy:.2f}%")


# for epoch in range(num_epochs):
#     for batch in dataloader:
#         inputs, labels = batch
#         optimizer.zero_grad()

#         # Forward pass
#         outputs = model(**inputs)
#         logits_per_image = outputs.logits_per_image  # Similarity scores
#         loss = torch.nn.functional.cross_entropy(logits_per_image, labels)

#         # Backward pass and optimization
#         loss.backward()
#         optimizer.step()

#         print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}")
# Out:
# <__main__.ImageLabelDataset object at 0x7f400a3bc160>
# Epoch [1/2], Loss: 0.6746
# Epoch [1/2], Loss: 0.6276
# Epoch [1/2], Loss: 0.6168
# Epoch [1/2], Loss: 0.5853
# Epoch [1/2], Loss: 0.5254
# Epoch [1/2], Loss: 0.5417
# Epoch [1/2], Loss: 0.5847
# Epoch [1/2], Loss: 0.4891
# Epoch [1/2], Loss: 0.4704
# Epoch [1/2], Loss: 0.5068
# Epoch [1/2], Loss: 0.5623
# Epoch [1/2], Loss: 0.5191
# Epoch [1/2], Loss: 0.5949
# Epoch [1/2], Loss: 0.4043
# Epoch [1/2], Loss: 0.2761
# Epoch [1/2], Loss: 0.6601
# Epoch [1/2], Loss: 0.6240
# Epoch [1/2], Loss: 0.4881
# Epoch [1/2], Loss: 0.2672
# Epoch [1/2], Loss: 0.3640
# Epoch [1/2], Loss: 0.5205
# Epoch [1/2], Loss: 0.4776
# Epoch [1/2], Loss: 0.4811
# Epoch [1/2], Loss: 0.3984
# Epoch [1/2], Loss: 0.3199
# Epoch [1/2], Loss: 0.3285
# Epoch [1/2], Loss: 0.2825
# Epoch [1/2], Loss: 0.3992
# Epoch [1/2], Loss: 0.4582
# Epoch [1/2], Loss: 0.3545
# Epoch [1/2], Loss: 0.4635
# Epoch [1/2], Loss: 0.4438
# Epoch [1/2], Loss: 0.2570
# Epoch [1/2], Loss: 0.3242
# Epoch [1/2], Loss: 0.5414
# Epoch [1/2], Loss: 0.4147
# Epoch [1/2], Loss: 0.2659
# Epoch [1/2], Loss: 0.3781
# Epoch [1/2], Loss: 0.5442
# Epoch [1/2], Loss: 0.3525
# Epoch [1/2], Loss: 0.3593
# Epoch [1/2], Loss: 0.2714
# Epoch [1/2], Loss: 0.3740
# Epoch [1/2], Loss: 0.2584
# Epoch [1/2], Loss: 0.3912
# Epoch [1/2], Loss: 0.3723
# Epoch [1/2], Loss: 0.2919
# Epoch [1/2], Loss: 0.3852
# Epoch [1/2], Loss: 0.1327
# Epoch [1/2], Loss: 0.3152
# Epoch [1/2], Loss: 0.3300
# Epoch [1/2], Loss: 0.5149
# Epoch [1/2], Loss: 0.1891
# Epoch [1/2], Loss: 0.0958
# Epoch [1/2], Loss: 0.2647
# Epoch [1/2], Loss: 0.3672
# Epoch [1/2], Loss: 0.1946
# Epoch [1/2], Loss: 0.4250
# Epoch [1/2], Loss: 0.2621
# Epoch [1/2], Loss: 0.1828
# Epoch [1/2], Loss: 0.1592
# Epoch [1/2], Loss: 0.2269
# Epoch [1/2], Loss: 0.1277
# Epoch [1/2], Loss: 0.1979
# Epoch [1/2], Loss: 0.2093
# Epoch [1/2], Loss: 0.3141
# Epoch [1/2], Loss: 0.1493
# Epoch [1/2], Loss: 0.2669
# Epoch [1/2], Loss: 0.1451
# Epoch [1/2], Loss: 0.2778
# Epoch [1/2], Loss: 0.4203
# Epoch [1/2], Loss: 0.2339
# Epoch [1/2], Loss: 0.1435
# Epoch [1/2], Loss: 0.0829
# Epoch [1/2], Loss: 0.2514
# Epoch [1/2], Loss: 0.2044
# Epoch [1/2], Loss: 0.1503
# Epoch [1/2], Loss: 0.1715
# Epoch [1/2], Loss: 0.3940
# Epoch [1/2], Loss: 0.2184
# Epoch [1/2], Loss: 0.1762
# Epoch [1/2], Loss: 0.1223
# Epoch [1/2], Loss: 0.0494
# Epoch [1/2], Loss: 0.1237
# Epoch [1/2], Loss: 0.0332
# Epoch [1/2], Loss: 0.3411
# Epoch [1/2], Loss: 0.0535
# Epoch [1/2], Loss: 0.0654
# Epoch [1/2], Loss: 0.0370
# Epoch [1/2], Loss: 0.1219
# Epoch [1/2], Loss: 0.0428
# Epoch [1/2], Loss: 0.0713
# Epoch [1/2], Loss: 0.0812
# Epoch [1/2], Loss: 0.1595
# Epoch [1/2], Loss: 0.0827
# Epoch [1/2], Loss: 0.0978
# Epoch [1/2], Loss: 0.0218
# Epoch [1/2], Loss: 0.1098
# Epoch [1/2], Loss: 0.0790
# Epoch [1/2], Loss: 0.2381
# Epoch [1/2], Loss: 0.0797
# Epoch [1/2], Loss: 0.0489
# Epoch [1/2], Loss: 0.3051
# Epoch [1/2], Loss: 0.0705
# Epoch [1/2], Loss: 0.1078
# Epoch [1/2], Loss: 0.3517
# Epoch [1/2], Loss: 0.1841
# Epoch [1/2], Loss: 0.0692
# Epoch [1/2], Loss: 0.1480
# Epoch [1/2], Loss: 0.1073
# Epoch [1/2], Loss: 0.0276
# Epoch [1/2], Loss: 0.0685
# Epoch [1/2], Loss: 0.0642
# Epoch [1/2], Loss: 0.3466
# Epoch [1/2], Loss: 0.1211
# Epoch [1/2], Loss: 0.0517
# Epoch [1/2], Loss: 0.0280
# Epoch [1/2], Loss: 0.1608
# Epoch [1/2], Loss: 0.1167
# Epoch [1/2], Loss: 0.2422
# Epoch [1/2], Loss: 0.4043
# Epoch [1/2], Loss: 0.1986
# Epoch [1/2], Loss: 0.0739
# Epoch [1/2], Loss: 0.2690
# Epoch [1/2], Loss: 0.3783
# Epoch [1/2], Loss: 0.0181
# Epoch [1/2], Loss: 0.1753
# Epoch [1/2], Loss: 0.0839
# Epoch [1/2], Loss: 0.0536
# Epoch [1/2], Loss: 0.0182
# Epoch [1/2], Loss: 0.1183
# Epoch [1/2], Loss: 0.0177
# Epoch [1/2], Loss: 0.0941
# Epoch [1/2], Loss: 0.0274
# Epoch [1/2], Loss: 0.0341
# Epoch [1/2], Loss: 0.0119
# Epoch [1/2], Loss: 0.2084
# Epoch [1/2], Loss: 0.0220
# Epoch [1/2], Loss: 0.0990
# Epoch [1/2], Loss: 0.0512
# Epoch [1/2], Loss: 0.0111
# Epoch [1/2], Loss: 0.0347
# Epoch [1/2], Loss: 0.1543
# Epoch [1/2], Loss: 0.1395
# Epoch [1/2], Loss: 0.0641
# Epoch [1/2], Loss: 0.1231
# Epoch [1/2], Loss: 0.0239
# Epoch [1/2], Loss: 0.0369
# Epoch [1/2], Loss: 0.1394
# Epoch [1/2], Loss: 0.0722
# Epoch [1/2], Loss: 0.0311
# Epoch [1/2], Loss: 0.0361
# Epoch [1/2], Loss: 0.1371
# Epoch [1/2], Loss: 0.0220
# Epoch [1/2], Loss: 0.0262
# Epoch [1/2], Loss: 0.0138
# Epoch [1/2], Loss: 0.1882
# Epoch [1/2], Loss: 0.1364
# Epoch [1/2], Loss: 0.0590
# Epoch [1/2], Loss: 0.0538
# Epoch [1/2], Loss: 0.1877
# Epoch [1/2], Loss: 0.0186
# Epoch [1/2], Loss: 0.0204
# Epoch [1/2], Loss: 0.0274
# Epoch [1/2], Loss: 0.0453
# Epoch [1/2], Loss: 0.0211
# Epoch [1/2], Loss: 0.0903
# Epoch [1/2], Loss: 0.1645
# Epoch [1/2], Loss: 0.0370
# Epoch [1/2], Loss: 0.0240
# Epoch [1/2], Loss: 0.0177
# Epoch [1/2], Loss: 0.0094
# Epoch [1/2], Loss: 0.0152
# Epoch [1/2], Loss: 0.0190
# Epoch [1/2], Loss: 0.0244
# Epoch [1/2], Loss: 0.2584
# Epoch [1/2], Loss: 0.1242
# Epoch [1/2], Loss: 0.1282
# Epoch [1/2], Loss: 0.1320
# Epoch [1/2], Loss: 0.3397
# Epoch [1/2], Loss: 0.1506
# Epoch [1/2], Loss: 0.1952
# Epoch [1/2], Loss: 0.2167
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.0878
# Epoch [1/2], Loss: 0.0065
# Epoch [1/2], Loss: 0.0771
# Epoch [1/2], Loss: 0.1950
# Epoch [1/2], Loss: 0.0251
# Epoch [1/2], Loss: 0.0429
# Epoch [1/2], Loss: 0.1898
# Epoch [1/2], Loss: 0.0190
# Epoch [1/2], Loss: 0.0277
# Epoch [1/2], Loss: 0.0146
# Epoch [1/2], Loss: 0.2517
# Epoch [1/2], Loss: 0.0343
# Epoch [1/2], Loss: 0.0263
# Epoch [1/2], Loss: 0.0121
# Epoch [1/2], Loss: 0.0354
# Epoch [1/2], Loss: 0.0105
# Epoch [1/2], Loss: 0.0636
# Epoch [1/2], Loss: 0.0312
# Epoch [1/2], Loss: 0.0341
# Epoch [1/2], Loss: 0.0095
# Epoch [1/2], Loss: 0.0409
# Epoch [1/2], Loss: 0.0151
# Epoch [1/2], Loss: 0.1116
# Epoch [1/2], Loss: 0.0083
# Epoch [1/2], Loss: 0.0289
# Epoch [1/2], Loss: 0.0831
# Epoch [1/2], Loss: 0.0044
# Epoch [1/2], Loss: 0.3113
# Epoch [1/2], Loss: 0.0161
# Epoch [1/2], Loss: 0.0367
# Epoch [1/2], Loss: 0.0814
# Epoch [1/2], Loss: 0.0428
# Epoch [1/2], Loss: 0.0107
# Epoch [1/2], Loss: 0.0413
# Epoch [1/2], Loss: 0.0576
# Epoch [1/2], Loss: 0.1045
# Epoch [1/2], Loss: 0.0393
# Epoch [1/2], Loss: 0.0159
# Epoch [1/2], Loss: 0.0389
# Epoch [1/2], Loss: 0.0155
# Epoch [1/2], Loss: 0.1123
# Epoch [1/2], Loss: 0.0102
# Epoch [1/2], Loss: 0.0664
# Epoch [1/2], Loss: 0.0754
# Epoch [1/2], Loss: 0.0143
# Epoch [1/2], Loss: 0.0078
# Epoch [1/2], Loss: 0.0345
# Epoch [1/2], Loss: 0.0122
# Epoch [1/2], Loss: 0.0335
# Epoch [1/2], Loss: 0.0190
# Epoch [1/2], Loss: 0.0699
# Epoch [1/2], Loss: 0.0090
# Epoch [1/2], Loss: 0.1944
# Epoch [1/2], Loss: 0.0166
# Epoch [1/2], Loss: 0.0182
# Epoch [1/2], Loss: 0.0096
# Epoch [1/2], Loss: 0.0157
# Epoch [1/2], Loss: 0.2480
# Epoch [1/2], Loss: 0.0432
# Epoch [1/2], Loss: 0.0606
# Epoch [1/2], Loss: 0.0200
# Epoch [1/2], Loss: 0.1066
# Epoch [1/2], Loss: 0.1035
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.1689
# Epoch [1/2], Loss: 0.0108
# Epoch [1/2], Loss: 0.0053
# Epoch [1/2], Loss: 0.2049
# Epoch [1/2], Loss: 0.0482
# Epoch [1/2], Loss: 0.0037
# Epoch [1/2], Loss: 0.0038
# Epoch [1/2], Loss: 0.0206
# Epoch [1/2], Loss: 0.1663
# Epoch [1/2], Loss: 0.0459
# Epoch [1/2], Loss: 0.0303
# Epoch [1/2], Loss: 0.0130
# Epoch [1/2], Loss: 0.1859
# Epoch [1/2], Loss: 0.0081
# Epoch [1/2], Loss: 0.2903
# Epoch [1/2], Loss: 0.0179
# Epoch [1/2], Loss: 0.0346
# Epoch [1/2], Loss: 0.0104
# Epoch [1/2], Loss: 0.0262
# Epoch [1/2], Loss: 0.0384
# Epoch [1/2], Loss: 0.0192
# Epoch [1/2], Loss: 0.1495
# Epoch [1/2], Loss: 0.0169
# Epoch [1/2], Loss: 0.0622
# Epoch [1/2], Loss: 0.0068
# Epoch [1/2], Loss: 0.0042
# Epoch [1/2], Loss: 0.0145
# Epoch [1/2], Loss: 0.0311
# Epoch [1/2], Loss: 0.0057
# Epoch [1/2], Loss: 0.0148
# Epoch [1/2], Loss: 0.0145
# Epoch [1/2], Loss: 0.4514
# Epoch [1/2], Loss: 0.0047
# Epoch [1/2], Loss: 0.4300
# Epoch [1/2], Loss: 0.0231
# Epoch [1/2], Loss: 0.0273
# Epoch [1/2], Loss: 0.0866
# Epoch [1/2], Loss: 0.0176
# Epoch [1/2], Loss: 0.0142
# Epoch [1/2], Loss: 0.0072
# Epoch [1/2], Loss: 0.0255
# Epoch [1/2], Loss: 0.0189
# Epoch [1/2], Loss: 0.0274
# Epoch [1/2], Loss: 0.0431
# Epoch [1/2], Loss: 0.0141
# Epoch [1/2], Loss: 0.0340
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0145
# Epoch [1/2], Loss: 0.4239
# Epoch [1/2], Loss: 0.0225
# Epoch [1/2], Loss: 0.0107
# Epoch [1/2], Loss: 0.1528
# Epoch [1/2], Loss: 0.0062
# Epoch [1/2], Loss: 0.0126
# Epoch [1/2], Loss: 0.0177
# Epoch [1/2], Loss: 0.0109
# Epoch [1/2], Loss: 0.0058
# Epoch [1/2], Loss: 0.0063
# Epoch [1/2], Loss: 0.0302
# Epoch [1/2], Loss: 0.0066
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0315
# Epoch [1/2], Loss: 0.0070
# Epoch [1/2], Loss: 0.0161
# Epoch [1/2], Loss: 0.0170
# Epoch [1/2], Loss: 0.0301
# Epoch [1/2], Loss: 0.0042
# Epoch [1/2], Loss: 0.0356
# Epoch [1/2], Loss: 0.0925
# Epoch [1/2], Loss: 0.0049
# Epoch [1/2], Loss: 0.0233
# Epoch [1/2], Loss: 0.2329
# Epoch [1/2], Loss: 0.0207
# Epoch [1/2], Loss: 0.0095
# Epoch [1/2], Loss: 0.0122
# Epoch [1/2], Loss: 0.2525
# Epoch [1/2], Loss: 0.0077
# Epoch [1/2], Loss: 0.0216
# Epoch [1/2], Loss: 0.0060
# Epoch [1/2], Loss: 0.0456
# Epoch [1/2], Loss: 0.0200
# Epoch [1/2], Loss: 0.0434
# Epoch [1/2], Loss: 0.0292
# Epoch [1/2], Loss: 0.0137
# Epoch [1/2], Loss: 0.0176
# Epoch [1/2], Loss: 0.0400
# Epoch [1/2], Loss: 0.0635
# Epoch [1/2], Loss: 0.0096
# Epoch [1/2], Loss: 0.0092
# Epoch [1/2], Loss: 0.0028
# Epoch [1/2], Loss: 0.0063
# Epoch [1/2], Loss: 0.0157
# Epoch [1/2], Loss: 0.0084
# Epoch [1/2], Loss: 0.0088
# Epoch [1/2], Loss: 0.0059
# Epoch [1/2], Loss: 0.0082
# Epoch [1/2], Loss: 0.0321
# Epoch [1/2], Loss: 0.0037
# Epoch [1/2], Loss: 0.0041
# Epoch [1/2], Loss: 0.0034
# Epoch [1/2], Loss: 0.0863
# Epoch [1/2], Loss: 0.0357
# Epoch [1/2], Loss: 0.0068
# Epoch [1/2], Loss: 0.0025
# Epoch [1/2], Loss: 0.1248
# Epoch [1/2], Loss: 0.0110
# Epoch [1/2], Loss: 0.0069
# Epoch [1/2], Loss: 0.0039
# Epoch [1/2], Loss: 0.0095
# Epoch [1/2], Loss: 0.0222
# Epoch [1/2], Loss: 0.1858
# Epoch [1/2], Loss: 0.0178
# Epoch [1/2], Loss: 0.0515
# Epoch [1/2], Loss: 0.0057
# Epoch [1/2], Loss: 0.0175
# Epoch [1/2], Loss: 0.0125
# Epoch [1/2], Loss: 0.0227
# Epoch [1/2], Loss: 0.1003
# Epoch [1/2], Loss: 0.0243
# Epoch [1/2], Loss: 0.0102
# Epoch [1/2], Loss: 0.0032
# Epoch [1/2], Loss: 0.0219
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0105
# Epoch [1/2], Loss: 0.0095
# Epoch [1/2], Loss: 0.0026
# Epoch [1/2], Loss: 0.0164
# Epoch [1/2], Loss: 0.0047
# Epoch [1/2], Loss: 0.0384
# Epoch [1/2], Loss: 0.0030
# Epoch [1/2], Loss: 0.1833
# Epoch [1/2], Loss: 0.0040
# Epoch [1/2], Loss: 0.0156
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0219
# Epoch [1/2], Loss: 0.0131
# Epoch [1/2], Loss: 0.0050
# Epoch [1/2], Loss: 0.0126
# Epoch [1/2], Loss: 0.0040
# Epoch [1/2], Loss: 0.0073
# Epoch [1/2], Loss: 0.0391
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0254
# Epoch [1/2], Loss: 0.0174
# Epoch [1/2], Loss: 0.0360
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0048
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.0082
# Epoch [1/2], Loss: 0.0071
# Epoch [1/2], Loss: 0.0051
# Epoch [1/2], Loss: 0.0356
# Epoch [1/2], Loss: 0.0038
# Epoch [1/2], Loss: 0.1641
# Epoch [1/2], Loss: 0.0034
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0014
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0017
# Epoch [1/2], Loss: 0.1657
# Epoch [1/2], Loss: 0.0029
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.0079
# Epoch [1/2], Loss: 0.0066
# Epoch [1/2], Loss: 0.1009
# Epoch [1/2], Loss: 0.0341
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0039
# Epoch [1/2], Loss: 0.0214
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0048
# Epoch [1/2], Loss: 0.0162
# Epoch [1/2], Loss: 0.0107
# Epoch [1/2], Loss: 0.0438
# Epoch [1/2], Loss: 0.0026
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0041
# Epoch [1/2], Loss: 0.0038
# Epoch [1/2], Loss: 0.0884
# Epoch [1/2], Loss: 0.0030
# Epoch [1/2], Loss: 0.0053
# Epoch [1/2], Loss: 0.0422
# Epoch [1/2], Loss: 0.0781
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0052
# Epoch [1/2], Loss: 0.3182
# Epoch [1/2], Loss: 0.0108
# Epoch [1/2], Loss: 0.0489
# Epoch [1/2], Loss: 0.0138
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0054
# Epoch [1/2], Loss: 0.0058
# Epoch [1/2], Loss: 0.0032
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0800
# Epoch [1/2], Loss: 0.0028
# Epoch [1/2], Loss: 0.0052
# Epoch [1/2], Loss: 0.0065
# Epoch [1/2], Loss: 0.0175
# Epoch [1/2], Loss: 0.0248
# Epoch [1/2], Loss: 0.0062
# Epoch [1/2], Loss: 0.0084
# Epoch [1/2], Loss: 0.0046
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0090
# Epoch [1/2], Loss: 0.0894
# Epoch [1/2], Loss: 0.0121
# Epoch [1/2], Loss: 0.1363
# Epoch [1/2], Loss: 0.0237
# Epoch [1/2], Loss: 0.0040
# Epoch [1/2], Loss: 0.0052
# Epoch [1/2], Loss: 0.0127
# Epoch [1/2], Loss: 0.0288
# Epoch [1/2], Loss: 0.0404
# Epoch [1/2], Loss: 0.0037
# Epoch [1/2], Loss: 0.0044
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0201
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0159
# Epoch [1/2], Loss: 0.0103
# Epoch [1/2], Loss: 0.0187
# Epoch [1/2], Loss: 0.1108
# Epoch [1/2], Loss: 0.0320
# Epoch [1/2], Loss: 0.0040
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0020
# Epoch [1/2], Loss: 0.0041
# Epoch [1/2], Loss: 0.0119
# Epoch [1/2], Loss: 0.0215
# Epoch [1/2], Loss: 0.0053
# Epoch [1/2], Loss: 0.0069
# Epoch [1/2], Loss: 0.0143
# Epoch [1/2], Loss: 0.0082
# Epoch [1/2], Loss: 0.0146
# Epoch [1/2], Loss: 0.0119
# Epoch [1/2], Loss: 0.0137
# Epoch [1/2], Loss: 0.0045
# Epoch [1/2], Loss: 0.0189
# Epoch [1/2], Loss: 0.0052
# Epoch [1/2], Loss: 0.0464
# Epoch [1/2], Loss: 0.0041
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0062
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0019
# Epoch [1/2], Loss: 0.3206
# Epoch [1/2], Loss: 0.0031
# Epoch [1/2], Loss: 0.0224
# Epoch [1/2], Loss: 0.0528
# Epoch [1/2], Loss: 0.0204
# Epoch [1/2], Loss: 0.0516
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0307
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.0025
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.0069
# Epoch [1/2], Loss: 0.0109
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0017
# Epoch [1/2], Loss: 0.0032
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0109
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0493
# Epoch [1/2], Loss: 0.0053
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0029
# Epoch [1/2], Loss: 0.0089
# Epoch [1/2], Loss: 0.0931
# Epoch [1/2], Loss: 0.0087
# Epoch [1/2], Loss: 0.0079
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0031
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0039
# Epoch [1/2], Loss: 0.0068
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.1415
# Epoch [1/2], Loss: 0.0650
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0037
# Epoch [1/2], Loss: 0.0025
# Epoch [1/2], Loss: 0.0046
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.0034
# Epoch [1/2], Loss: 0.0153
# Epoch [1/2], Loss: 0.0031
# Epoch [1/2], Loss: 0.0049
# Epoch [1/2], Loss: 0.0049
# Epoch [1/2], Loss: 0.0032
# Epoch [1/2], Loss: 0.0367
# Epoch [1/2], Loss: 0.0127
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0046
# Epoch [1/2], Loss: 0.0056
# Epoch [1/2], Loss: 0.0037
# Epoch [1/2], Loss: 0.0076
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0027
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0083
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0130
# Epoch [1/2], Loss: 0.0050
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0020
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0029
# Epoch [1/2], Loss: 0.0032
# Epoch [1/2], Loss: 0.0026
# Epoch [1/2], Loss: 0.0017
# Epoch [1/2], Loss: 0.0078
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0036
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0029
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0022
# Epoch [1/2], Loss: 0.0460
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0152
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0401
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0023
# Epoch [1/2], Loss: 0.0044
# Epoch [1/2], Loss: 0.0085
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0072
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0124
# Epoch [1/2], Loss: 0.0043
# Epoch [1/2], Loss: 0.0048
# Epoch [1/2], Loss: 0.1283
# Epoch [1/2], Loss: 0.0057
# Epoch [1/2], Loss: 0.0522
# Epoch [1/2], Loss: 0.0050
# Epoch [1/2], Loss: 0.0030
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0089
# Epoch [1/2], Loss: 0.0002
# Epoch [1/2], Loss: 0.0133
# Epoch [1/2], Loss: 0.0049
# Epoch [1/2], Loss: 0.0372
# Epoch [1/2], Loss: 0.0119
# Epoch [1/2], Loss: 0.0144
# Epoch [1/2], Loss: 0.0042
# Epoch [1/2], Loss: 0.0014
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0038
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0810
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0044
# Epoch [1/2], Loss: 0.0454
# Epoch [1/2], Loss: 0.0408
# Epoch [1/2], Loss: 0.0028
# Epoch [1/2], Loss: 0.0028
# Epoch [1/2], Loss: 0.0031
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0023
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0022
# Epoch [1/2], Loss: 0.0033
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0046
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0186
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0032
# Epoch [1/2], Loss: 0.1443
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.0060
# Epoch [1/2], Loss: 0.0014
# Epoch [1/2], Loss: 0.0491
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0023
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0042
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.2120
# Epoch [1/2], Loss: 0.3379
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0043
# Epoch [1/2], Loss: 0.0163
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0031
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0300
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0020
# Epoch [1/2], Loss: 0.0334
# Epoch [1/2], Loss: 0.0085
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0178
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0043
# Epoch [1/2], Loss: 0.0052
# Epoch [1/2], Loss: 0.0048
# Epoch [1/2], Loss: 0.0187
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0026
# Epoch [1/2], Loss: 0.0094
# Epoch [1/2], Loss: 0.0047
# Epoch [1/2], Loss: 0.0099
# Epoch [1/2], Loss: 0.0437
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0060
# Epoch [1/2], Loss: 0.1530
# Epoch [1/2], Loss: 0.0030
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0126
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0054
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0989
# Epoch [1/2], Loss: 0.0101
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0025
# Epoch [1/2], Loss: 0.0109
# Epoch [1/2], Loss: 0.0098
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0118
# Epoch [1/2], Loss: 0.0039
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0002
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0739
# Epoch [1/2], Loss: 0.0082
# Epoch [1/2], Loss: 0.0028
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0016
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0114
# Epoch [1/2], Loss: 0.0059
# Epoch [1/2], Loss: 0.0043
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0130
# Epoch [1/2], Loss: 0.0062
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0045
# Epoch [1/2], Loss: 0.0134
# Epoch [1/2], Loss: 0.0538
# Epoch [1/2], Loss: 0.0019
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0104
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0136
# Epoch [1/2], Loss: 0.0209
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0017
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0020
# Epoch [1/2], Loss: 0.0029
# Epoch [1/2], Loss: 0.0081
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0131
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0136
# Epoch [1/2], Loss: 0.0038
# Epoch [1/2], Loss: 0.0071
# Epoch [1/2], Loss: 0.0037
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0039
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0031
# Epoch [1/2], Loss: 0.0098
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0036
# Epoch [1/2], Loss: 0.0049
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0025
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0002
# Epoch [1/2], Loss: 0.0802
# Epoch [1/2], Loss: 0.0022
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0030
# Epoch [1/2], Loss: 0.0019
# Epoch [1/2], Loss: 0.0258
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0018
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0021
# Epoch [1/2], Loss: 0.0011
# Epoch [1/2], Loss: 0.0191
# Epoch [1/2], Loss: 0.0884
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0119
# Epoch [1/2], Loss: 0.0025
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0050
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0008
# Epoch [1/2], Loss: 0.0002
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0213
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0780
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0009
# Epoch [1/2], Loss: 0.0015
# Epoch [1/2], Loss: 0.0027
# Epoch [1/2], Loss: 0.1798
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0043
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0152
# Epoch [1/2], Loss: 0.0012
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0110
# Epoch [1/2], Loss: 0.0317
# Epoch [1/2], Loss: 0.0001
# Epoch [1/2], Loss: 0.0010
# Epoch [1/2], Loss: 0.0100
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0002
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0076
# Epoch [1/2], Loss: 0.0040
# Epoch [1/2], Loss: 0.0006
# Epoch [1/2], Loss: 0.0093
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0007
# Epoch [1/2], Loss: 0.0024
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0003
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.0004
# Epoch [1/2], Loss: 0.0005
# Epoch [1/2], Loss: 0.0041
# Epoch [1/2], Loss: 0.0055
# Epoch [1/2], Loss: 0.0013
# Epoch [1/2], Loss: 0.0096
# Epoch [1/2], Loss: 0.0053
# Epoch [1/2], Loss: 0.0165
# Epoch [2/2], Loss: 0.0034
# Epoch [2/2], Loss: 0.3747
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0023
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0037
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0015
# Epoch [2/2], Loss: 0.0040
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0067
# Epoch [2/2], Loss: 0.0594
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0908
# Epoch [2/2], Loss: 0.0048
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0116
# Epoch [2/2], Loss: 0.0918
# Epoch [2/2], Loss: 0.0071
# Epoch [2/2], Loss: 0.0019
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0073
# Epoch [2/2], Loss: 0.0365
# Epoch [2/2], Loss: 0.0051
# Epoch [2/2], Loss: 0.0350
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0115
# Epoch [2/2], Loss: 0.0024
# Epoch [2/2], Loss: 0.0086
# Epoch [2/2], Loss: 0.0026
# Epoch [2/2], Loss: 0.0054
# Epoch [2/2], Loss: 0.0292
# Epoch [2/2], Loss: 0.0184
# Epoch [2/2], Loss: 0.0069
# Epoch [2/2], Loss: 0.0039
# Epoch [2/2], Loss: 0.0044
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0042
# Epoch [2/2], Loss: 0.0040
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0015
# Epoch [2/2], Loss: 0.0321
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0334
# Epoch [2/2], Loss: 0.0029
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0090
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0047
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0119
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0542
# Epoch [2/2], Loss: 0.0083
# Epoch [2/2], Loss: 0.0023
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0015
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0200
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0084
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0060
# Epoch [2/2], Loss: 0.0113
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0856
# Epoch [2/2], Loss: 0.1306
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.1599
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0205
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0099
# Epoch [2/2], Loss: 0.0106
# Epoch [2/2], Loss: 0.0045
# Epoch [2/2], Loss: 0.0056
# Epoch [2/2], Loss: 0.0443
# Epoch [2/2], Loss: 0.0450
# Epoch [2/2], Loss: 0.0055
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0284
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0472
# Epoch [2/2], Loss: 0.0041
# Epoch [2/2], Loss: 0.1427
# Epoch [2/2], Loss: 0.0114
# Epoch [2/2], Loss: 0.0024
# Epoch [2/2], Loss: 0.0087
# Epoch [2/2], Loss: 0.0052
# Epoch [2/2], Loss: 0.0580
# Epoch [2/2], Loss: 0.0069
# Epoch [2/2], Loss: 0.0295
# Epoch [2/2], Loss: 0.0075
# Epoch [2/2], Loss: 0.0057
# Epoch [2/2], Loss: 0.0069
# Epoch [2/2], Loss: 0.0286
# Epoch [2/2], Loss: 0.0016
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0675
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0043
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0015
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0108
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0089
# Epoch [2/2], Loss: 0.0581
# Epoch [2/2], Loss: 0.0015
# Epoch [2/2], Loss: 0.0513
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0554
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0090
# Epoch [2/2], Loss: 0.0118
# Epoch [2/2], Loss: 0.0022
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.1110
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0110
# Epoch [2/2], Loss: 0.0074
# Epoch [2/2], Loss: 0.0037
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0053
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0309
# Epoch [2/2], Loss: 0.0026
# Epoch [2/2], Loss: 0.0026
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0151
# Epoch [2/2], Loss: 0.0050
# Epoch [2/2], Loss: 0.0017
# Epoch [2/2], Loss: 0.0067
# Epoch [2/2], Loss: 0.0631
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0201
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0047
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0968
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0084
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.1939
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0923
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.1809
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0265
# Epoch [2/2], Loss: 0.0216
# Epoch [2/2], Loss: 0.0034
# Epoch [2/2], Loss: 0.0061
# Epoch [2/2], Loss: 0.0025
# Epoch [2/2], Loss: 0.0255
# Epoch [2/2], Loss: 0.0074
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0167
# Epoch [2/2], Loss: 0.0095
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0037
# Epoch [2/2], Loss: 0.1418
# Epoch [2/2], Loss: 0.0353
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0588
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0031
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0028
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0572
# Epoch [2/2], Loss: 0.1097
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0186
# Epoch [2/2], Loss: 0.0022
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0258
# Epoch [2/2], Loss: 0.0082
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0030
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0041
# Epoch [2/2], Loss: 0.0028
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0027
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0054
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0040
# Epoch [2/2], Loss: 0.0304
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0753
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0281
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0044
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0457
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0184
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0873
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0554
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0062
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0286
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0201
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0017
# Epoch [2/2], Loss: 0.0060
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0028
# Epoch [2/2], Loss: 0.0016
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0029
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0042
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0088
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.1034
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0015
# Epoch [2/2], Loss: 0.0043
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.1178
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0064
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0021
# Epoch [2/2], Loss: 0.0743
# Epoch [2/2], Loss: 0.0024
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0100
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0071
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.4941
# Epoch [2/2], Loss: 0.0047
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.1668
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0037
# Epoch [2/2], Loss: 0.0061
# Epoch [2/2], Loss: 0.0046
# Epoch [2/2], Loss: 0.0029
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0054
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0065
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0034
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0196
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0038
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0019
# Epoch [2/2], Loss: 0.0943
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0155
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0189
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0022
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0032
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0022
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0032
# Epoch [2/2], Loss: 0.0089
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0399
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0163
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0030
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0034
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0054
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0032
# Epoch [2/2], Loss: 0.0016
# Epoch [2/2], Loss: 0.0044
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0024
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.1654
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0017
# Epoch [2/2], Loss: 0.0035
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0101
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.2190
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0042
# Epoch [2/2], Loss: 0.0043
# Epoch [2/2], Loss: 0.0214
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0016
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0037
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.1148
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0056
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0103
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0016
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0021
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0024
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0107
# Epoch [2/2], Loss: 0.0058
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0019
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0061
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.3245
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.1078
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0046
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0173
# Epoch [2/2], Loss: 0.0037
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0016
# Epoch [2/2], Loss: 0.0084
# Epoch [2/2], Loss: 0.0099
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0125
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0052
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0856
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.3141
# Epoch [2/2], Loss: 0.0030
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0073
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0122
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0032
# Epoch [2/2], Loss: 0.0045
# Epoch [2/2], Loss: 0.0033
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0411
# Epoch [2/2], Loss: 0.0027
# Epoch [2/2], Loss: 0.0023
# Epoch [2/2], Loss: 0.0346
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0075
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0035
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0031
# Epoch [2/2], Loss: 0.0110
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0179
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0056
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0183
# Epoch [2/2], Loss: 0.0066
# Epoch [2/2], Loss: 0.0155
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0046
# Epoch [2/2], Loss: 0.0034
# Epoch [2/2], Loss: 0.0019
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0086
# Epoch [2/2], Loss: 0.0031
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0049
# Epoch [2/2], Loss: 0.0071
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0049
# Epoch [2/2], Loss: 0.0038
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0036
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0031
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0045
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0067
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0008
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0052
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0021
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0022
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0017
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0056
# Epoch [2/2], Loss: 0.0025
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0040
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0069
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0035
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0023
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0035
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0014
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0009
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0012
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0068
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0029
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0011
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0113
# Epoch [2/2], Loss: 0.0006
# Epoch [2/2], Loss: 0.0020
# Epoch [2/2], Loss: 0.0423
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0013
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0023
# Epoch [2/2], Loss: 0.0030
# Epoch [2/2], Loss: 0.0038
# Epoch [2/2], Loss: 0.0035
# Epoch [2/2], Loss: 0.0107
# Epoch [2/2], Loss: 0.0010
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0004
# Epoch [2/2], Loss: 0.0005
# Epoch [2/2], Loss: 0.0018
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0002
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0003
# Epoch [2/2], Loss: 0.0000
# Epoch [2/2], Loss: 0.0007
# Epoch [2/2], Loss: 0.0001
# Epoch [2/2], Loss: 0.0000

# %%
# student_model

from PIL import Image
from transformers import CLIPModel, CLIPConfig, AutoProcessor

image = Image.open("/home/ajeet/codework/datasets/train_clip/val/no_cell_phone/0_2873.jpg")
text = ["no cell phone", "a cell phone"]
# text = ["a cell phone", "no cell phone"]

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

inputs = processor(text=text, images=image, return_tensors="pt", padding=True)

with torch.no_grad():
    outputs = model(**inputs)

logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)
print(probs)
# Out:
# tensor([[1.2410e-06, 1.0000e+00]])

# %%
# student_model

from PIL import Image
from transformers import CLIPModel, CLIPConfig, AutoProcessor

image = Image.open("/home/ajeet/codework/datasets/train_clip/testing/no_cell_phones/0_2.jpg")
text = ["no cell phone", "a cell phone"]
# text = ["a cell phone", "no cell phone"]

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

inputs = processor(text=text, images=image, return_tensors="pt", padding=True)

with torch.no_grad():
    outputs = without_fine_tune(**inputs)

logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)
print(probs)
# Out:
# tensor([[0.8286, 0.1714]])

# %%
import os
import shutil

def copy_images(source_dir, destination_dir, num_images=10000):
    # Create destination directory if it does not exist
    os.makedirs(destination_dir, exist_ok=True)

    # Get all image files from the source directory
    images = [f for f in os.listdir(source_dir) if f.lower().endswith(('.jpg', '.jpeg'))]

    # Limit the number of images to copy
    images_to_copy = images[:14000]

    for image in images_to_copy:
        # Construct full file path
        src = os.path.join(source_dir, image)
        dst = os.path.join(destination_dir, image)
        
        # Copy the file
        shutil.copy2(src, dst)
        # print(f"Copied: {image}")

    print(f"Copied {len(images_to_copy)} images from {source_dir} to {destination_dir}.")


    for image in images[14000:]:
        # Construct full file path
        src = os.path.join("/home/ajeet/codework/datasets/Cellphone_train/train", image)
        dst = os.path.join("/home/ajeet/codework/datasets/train_clip/val/cell_phone", image)
        
        # Copy the file
        shutil.copy2(src, dst)
        print(f"Copied: {image}")

# Example usage
source_folder = '/home/ajeet/codework/datasets/Cellphone_train/train'  # Replace with your source folder path
destination_folder = '/home/ajeet/codework/datasets/train_clip/train/cell_phone'  # Replace with your destination folder path
copy_images(source_folder, destination_folder)
# Out:
# Copied 14000 images from /home/ajeet/codework/datasets/Cellphone_train/train to /home/ajeet/codework/datasets/train_clip/train/cell_phone.
# Copied: 23409_mob_jitter.jpg
# Copied: 26635_mob_poison.jpg
# Copied: 89441_2020-07-14_12263__mob_poison.jpg
# Copied: 71713_2020-06-10_459_.jpg
# Copied: 94883_2020-07-17_12329_.jpg
# Copied: 740_dec_bright.jpg
# Copied: 44334_2020-04-14_9222_.jpg
# Copied: 7125_mob_poison.jpg
# Copied: 48112_2020-04-22_9235__mob_jitter.jpg
# Copied: 26108_mob_poison.jpg
# Copied: 24508_mob_poison.jpg
# Copied: fti_Claire.Campbell@fti-acuity.com_136586_2020-08-21_14542__mob_poison.jpg
# Copied: 25568_mob_jitter.jpg
# Copied: 24511.jpg
# Copied: 96220_2020-07-20_17404__mob_jitter.jpg
# Copied: 96410_2020-07-20_13658__mob_poison.jpg
# Copied: 106740_2020-07-29_12830_.jpg
# Copied: 8220.jpg
# Copied: 26233_mob_jitter.jpg
# Copied: concentrix_dhivya.n@concentrix.com_111915_2020-08-03_22030_.jpg
# Copied: 26403_mob_poison.jpg
# Copied: 42661_2020-04-08_19367_.jpg
# Copied: 82198_2020-07-06_16183__mob_jitter.jpg
# Copied: 95927_2020-07-20_11__mob_poison.jpg
# Copied: 23423_mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_19002__mob_poison.jpg
# Copied: 95662_2020-07-19_2980__mob_jitter.jpg
# Copied: 26284_mob_poison.jpg
# Copied: 23482_mob_jitter.jpg
# Copied: 45282_2020-04-16_9452__mob_jitter.jpg
# Copied: 26994_mob_poison.jpg
# Copied: 10047_mob_jitter.jpg
# Copied: 24111.jpg
# Copied: 108184_2020-07-30_7762_.jpg
# Copied: 24375_mob_poison.jpg
# Copied: fti_Doreen.Nanda@fti-acuity.com_146092_2020-08-29_13135__mob_poison.jpg
# Copied: 25493_mob_poison.jpg
# Copied: 83332_2020-07-08_12725__mob_poison.jpg
# Copied: 13613_mob_poison.jpg
# Copied: 84004_2020-07-09_10401_.jpg
# Copied: 24293_mob_poison.jpg
# Copied: 513.jpg
# Copied: 90714_2020-07-15_17889__mob_poison.jpg
# Copied: 55658_2020-05-06_19286__mob_poison.jpg
# Copied: 24771.jpg
# Copied: 27559_mob_poison.jpg
# Copied: fti_Cristina.Bosmenier@fti-acuity.com_138875_2020-08-24_13816__mob_poison.jpg
# Copied: 26651_mob_jitter.jpg
# Copied: 16566_mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_140552_2020-08-25_19016_.jpg
# Copied: 748_dec_bright.jpg
# Copied: 8050.jpg
# Copied: 11518_mob_jitter.jpg
# Copied: 25046_mob_jitter.jpg
# Copied: 99109_2020-07-22_10464_.jpg
# Copied: Dania.Arencibia@fti-acuity.com_fti_consulting_proctordesk_hosted_7002__mob_poison.jpg
# Copied: 868.jpg
# Copied: fti_Daniel.Trieff@fti-acuity.com_132846_2020-08-19_17180__mob_poison.jpg
# Copied: 24947_mob_jitter.jpg
# Copied: 55658_2020-05-06_19233__mob_poison.jpg
# Copied: 23516_mob_jitter.jpg
# Copied: 87135_2020-07-13_3955__mob_jitter.jpg
# Copied: 24442_mob_poison.jpg
# Copied: 24447.jpg
# Copied: 27601_mob_jitter.jpg
# Copied: 84970_2020-07-10_4268_.jpg
# Copied: 743.jpg
# Copied: 55658_2020-05-06_19308__mob_poison.jpg
# Copied: 26570_mob_jitter.jpg
# Copied: 51713_2020-04-29_291_.jpg
# Copied: 25019_mob_poison.jpg
# Copied: 59071_2020-05-13_18200__mob_jitter.jpg
# Copied: 26603_mob_jitter.jpg
# Copied: 104001_2020-07-27_16250_.jpg
# Copied: 24069.jpg
# Copied: 25023_mob_poison.jpg
# Copied: Frank.Cai@fti-acuity.com_fti_consulting_proctordesk_hosted_11649__mob_jitter.jpg
# Copied: 44250_2020-04-14_9373_.jpg
# Copied: 89192_2020-07-14_10418__mob_jitter.jpg
# Copied: 24701_mob_jitter.jpg
# Copied: 21032.jpg
# Copied: 105342_2020-07-28_13089__mob_jitter.jpg
# Copied: 27644_mob_jitter.jpg
# Copied: 24442.jpg
# Copied: 42990_2020-04-10_19379__mob_poison.jpg
# Copied: 42986_2020-04-10_19378__mob_jitter.jpg
# Copied: 106947_2020-07-29_10486__mob_jitter.jpg
# Copied: Brad.Koplinski@fti-acuity.com_fti_consulting_proctordesk_hosted_10958__mob_jitter.jpg
# Copied: 1678_1969955_Mobile Camera.jpg
# Copied: 79320_2020-06-30_12106__mob_jitter.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18875_.jpg
# Copied: 84699_2020-07-10_17699__mob_poison.jpg
# Copied: 45418_2020-04-16_9696__mob_poison.jpg
# Copied: 87180_2020-07-13_14129__mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_19002__mob_jitter.jpg
# Copied: 25969_mob_poison.jpg
# Copied: 79983_2020-07-01_10053__mob_jitter.jpg
# Copied: 25732_mob_poison.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_131166_2020-08-18_14292_.jpg
# Copied: 80578_2020-07-02_12147_.jpg
# Copied: 47742_2020-04-21_9362__mob_poison.jpg
# Copied: 55658_2020-05-06_19236__mob_jitter.jpg
# Copied: 779.jpg
# Copied: 881_poison_aug.jpg
# Copied: 83196_2020-07-08_17249__mob_jitter.jpg
# Copied: 79976_2020-07-01_14549__mob_jitter.jpg
# Copied: 16957_mob_jitter.jpg
# Copied: 74288_2020-06-17_18220__mob_poison.jpg
# Copied: concentrix_stephin.thomas@concentrix.com_121517_2020-08-11_21530__mob_poison.jpg
# Copied: 860_jitter.jpg
# Copied: 24500_mob_jitter.jpg
# Copied: 25961.jpg
# Copied: 107033_2020-07-29_13343_.jpg
# Copied: 26084_mob_jitter.jpg
# Copied: 48997_2020-04-23_9332_.jpg
# Copied: 79992_2020-07-01_9263__mob_poison.jpg
# Copied: 93640_2020-07-17_4984__mob_jitter.jpg
# Copied: 13337.jpg
# Copied: 25127_mob_poison.jpg
# Copied: 1054_dec_bright.jpg
# Copied: 24145_mob_poison.jpg
# Copied: 27384_mob_poison.jpg
# Copied: 95927_2020-07-20_3__mob_jitter.jpg
# Copied: 12199_mob_jitter.jpg
# Copied: 46330_2020-04-18_9349__mob_poison.jpg
# Copied: fti_Benjamin.Hodges@fti-acuity.com_129730_2020-08-17_18885_.jpg
# Copied: 8354.jpg
# Copied: 25635.jpg
# Copied: fti_carolee.byrley@fti-acuity.com_132875_2020-08-19_14487__mob_poison.jpg
# Copied: 26253_mob_poison.jpg
# Copied: 88321_2020-07-14_7217__mob_poison.jpg
# Copied: Bijoux.Ngwanda@fti-acuity.com_fti_consulting_proctordesk_hosted_5465_.jpg
# Copied: 25448.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18876__mob_poison.jpg
# Copied: 25517_mob_jitter.jpg
# Copied: 8050_mob_jitter.jpg
# Copied: 89753_2020-07-14_10439_.jpg
# Copied: 83881_2020-07-09_17500__dec_bright.jpg
# Copied: 26480.jpg
# Copied: 59833_2020-05-14_17818__mob_poison.jpg
# Copied: 26170.jpg
# Copied: 73075_2020-06-14_994_.jpg
# Copied: 84730_2020-07-10_7281__mob_jitter.jpg
# Copied: 25004_mob_jitter.jpg
# Copied: 24728_mob_poison.jpg
# Copied: 9296_mob_jitter.jpg
# Copied: 92943_2020-07-16_10450_.jpg
# Copied: 87759_2020-07-13_13052__mob_jitter.jpg
# Copied: 83589_2020-07-08_1820__mob_jitter.jpg
# Copied: 82627_2020-07-07_14705__mob_jitter.jpg
# Copied: 95064_2020-07-17_13069_.jpg
# Copied: Emeka.Onwezi@fti-acuity.com_fti_consulting_proctordesk_hosted_2901__mob_poison.jpg
# Copied: 84779_2020-07-10_17595__mob_jitter.jpg
# Copied: 26782_mob_poison.jpg
# Copied: 24583_mob_poison.jpg
# Copied: 57929_2020-05-11_17901__mob_poison.jpg
# Copied: 55658_2020-05-06_19314__mob_jitter.jpg
# Copied: 17184_mob_jitter.jpg
# Copied: 1188_mob_jitter.jpg
# Copied: 25170_mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_142543_2020-08-26_19025_.jpg
# Copied: 25798.jpg
# Copied: fti_Christopher.Oliver@fti-acuity.com_133198_2020-08-19_12187__mob_jitter.jpg
# Copied: 26779_mob_poison.jpg
# Copied: 10626.jpg
# Copied: 105342_2020-07-28_13090__mob_poison.jpg
# Copied: 829_dec_bright.jpg
# Copied: 104873_2020-07-28_17752__mob_jitter.jpg
# Copied: 89228_2020-07-14_12316_.jpg
# Copied: 25920.jpg
# Copied: 85116_2020-07-10_13578__mob_jitter.jpg
# Copied: AliBadshaAnjalath_542614_mv_snap_17498_mob_jitter.jpg
# Copied: 26101_mob_jitter.jpg
# Copied: 96786_2020-07-20_10683_.jpg
# Copied: 96203_2020-07-20_8031__mob_jitter.jpg
# Copied: 24930.jpg
# Copied: fti_Daniel.Trieff@fti-acuity.com_131100_2020-08-18_17177__mob_poison.jpg
# Copied: 26495.jpg
# Copied: 25593_mob_jitter.jpg
# Copied: 24089_mob_poison.jpg
# Copied: concentrix_jin.mingyu@concentrix.com_119596_2020-08-09_21060_.jpg
# Copied: 24060_mob_jitter.jpg
# Copied: Ekade_592588_mv_snap_39122_mob_poison.jpg
# Copied: 13623_mob_jitter.jpg
# Copied: 79335_2020-06-30_16982__jitter.jpg
# Copied: darryl.toler@fti-acuity.com_fti_consulting_proctordesk_hosted_8940_.jpg
# Copied: 26616.jpg
# Copied: 24677_mob_poison.jpg
# Copied: 12199_mob_poison.jpg
# Copied: 92814_2020-07-16_14087__mob_poison.jpg
# Copied: 92170_2020-07-16_58_.jpg
# Copied: Emeka.Onwezi@fti-acuity.com_fti_consulting_proctordesk_hosted_2905_.jpg
# Copied: 80686_2020-07-03_17772__mob_jitter.jpg
# Copied: 83589_2020-07-08_1819__mob_jitter.jpg
# Copied: 95951_2020-07-20_68__mob_poison.jpg
# Copied: 25715.jpg
# Copied: 7488.jpg
# Copied: 897_mob_poison.jpg
# Copied: 72268_2020-06-11_465_.jpg
# Copied: 20984.jpg
# Copied: 26639.jpg
# Copied: 48997_2020-04-23_9333__mob_poison.jpg
# Copied: 102024_2020-07-24_13080__mob_jitter.jpg
# Copied: Emeka.Onwezi@fti-acuity.com_fti_consulting_proctordesk_hosted_2905__mob_poison.jpg
# Copied: 24084_mob_jitter.jpg
# Copied: 840_mob_jitter.jpg
# Copied: 79520_2020-06-30_9882__mob_poison.jpg
# Copied: 21637.jpg
# Copied: 85261_2020-07-10_13288__mob_poison.jpg
# Copied: 25824_mob_poison.jpg
# Copied: 44334_2020-04-14_9225__mob_jitter.jpg
# Copied: 93535_2020-07-17_1_.jpg
# Copied: 46028_2020-04-17_9613_.jpg
# Copied: 105985_2020-07-28_13616_.jpg
# Copied: 24820.jpg
# Copied: 97918_2020-07-21_13769_.jpg
# Copied: 72048_2020-06-11_19320_.jpg
# Copied: 1168.jpg
# Copied: 25795.jpg
# Copied: 44858_2020-04-15_9425__mob_poison.jpg
# Copied: 598698_169_2022-02-03_jitter.jpeg
# Copied: 94164_2020-07-17_10789__mob_jitter.jpg
# Copied: 84002_2020-07-09_17554__mob_poison.jpg
# Copied: 19761_mob_poison.jpg
# Copied: 18172.jpg
# Copied: 45156_2020-04-15_9806_.jpg
# Copied: 96804_2020-07-20_13866_.jpg
# Copied: 87314_2020-07-13_12052__mob_poison.jpg
# Copied: 95959_2020-07-20_19029__mob_poison.jpg
# Copied: 24205_mob_poison.jpg
# Copied: 50641_2020-04-27_247_.jpg
# Copied: concentrix_SinghR18@aetna.com_141422_2020-08-26_21175__mob_jitter.jpg
# Copied: 754_mob_poison.jpg
# Copied: 71233_2020-06-09_17844__mob_poison.jpg
# Copied: 752_dec_bright.jpg
# Copied: 25013_mob_poison.jpg
# Copied: 24166.jpg
# Copied: 10132.jpg
# Copied: 26570_mob_poison.jpg
# Copied: 26410.jpg
# Copied: 11349_mob_poison.jpg
# Copied: concentrix_naranga@aetna.com_118132_2020-08-07_21244__mob_poison.jpg
# Copied: 367_1531719_Mobile Camera.jpg
# Copied: 25659_mob_jitter.jpg
# Copied: 44211_2020-04-14_9217__mob_poison.jpg
# Copied: 17313_mob_jitter.jpg
# Copied: 9315_mob_jitter.jpg
# Copied: 108387_2020-07-30_13209__mob_poison.jpg
# Copied: 26087_mob_poison.jpg
# Copied: 26581_mob_poison.jpg
# Copied: 25931_mob_poison.jpg
# Copied: 807.jpg
# Copied: 27534_mob_jitter.jpg
# Copied: 23539_mob_jitter.jpg
# Copied: 84837_2020-07-10_6484__mob_poison.jpg
# Copied: 10805_mob_poison.jpg
# Copied: 20984_mob_jitter.jpg
# Copied: 97290_2020-07-21_43_.jpg
# Copied: 73108_2020-06-14_1266_.jpg
# Copied: concentrix_karthick.viswanathan@concentrix.com_111773_2020-08-03_21076__mob_poison.jpg
# Copied: 94719_2020-07-17_13326__mob_poison.jpg
# Copied: Ekade_592588_mv_snap_39096_mob_jitter.jpg
# Copied: 24555_mob_jitter.jpg
# Copied: 100743_2020-07-23_17417_.jpg
# Copied: 26509_mob_jitter.jpg
# Copied: 54873_2020-05-05_18273_.jpg
# Copied: 23440_mob_poison.jpg
# Copied: 24472_mob_poison.jpg
# Copied: 25476_mob_jitter.jpg
# Copied: 844_jitter.jpg
# Copied: 27233_mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_137273_2020-08-22_19007__mob_jitter.jpg
# Copied: 11291_mob_jitter.jpg
# Copied: fti_Charles.Oliver@fti-acuity.com_137289_2020-08-22_13852__mob_jitter.jpg
# Copied: 96513_2020-07-20_3354__mob_jitter.jpg
# Copied: 25660_mob_poison.jpg
# Copied: 83196_2020-07-08_17214__mob_poison.jpg
# Copied: 1048_mob_jitter.jpg
# Copied: 25661_mob_poison.jpg
# Copied: 98936_2020-07-22_7740__mob_jitter.jpg
# Copied: 71954_2020-06-11_490__mob_poison.jpg
# Copied: 58509_2020-05-12_19352_.jpg
# Copied: 903.jpg
# Copied: 27605_mob_jitter.jpg
# Copied: 98446_2020-07-21_14391_.jpg
# Copied: 94706_2020-07-17_10920__mob_poison.jpg
# Copied: AliBadshaAnjalath_542614_mv_snap_17500.jpg
# Copied: 27660.jpg
# Copied: 55658_2020-05-06_19260__mob_jitter.jpg
# Copied: 25212_mob_poison.jpg
# Copied: 25687.jpg
# Copied: 10526.jpg
# Copied: 80567_2020-07-02_14892__mob_jitter.jpg
# Copied: 25619.jpg
# Copied: 97643_2020-07-21_12296__mob_poison.jpg
# Copied: 101446_2020-07-24_17748_.jpg
# Copied: 27598.jpg
# Copied: 24915.jpg
# Copied: 24319_mob_poison.jpg
# Copied: 811_mob_jitter.jpg
# Copied: Ekade_592588_mv_snap_39094.jpg
# Copied: 24070_mob_poison.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137358_2020-08-22_18868__mob_poison.jpg
# Copied: 24366_mob_poison.jpg
# Copied: 26227_mob_poison.jpg
# Copied: 106872_2020-07-29_14191__mob_poison.jpg
# Copied: 26939.jpg
# Copied: 830.jpg
# Copied: 796_jitter.jpg
# Copied: 105419_2020-07-28_10944_.jpg
# Copied: 606766_132_2022-02-08_poison_aug.jpeg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18877_.jpg
# Copied: 25977.jpg
# Copied: 79861_2020-07-01_12111__mob_poison.jpg
# Copied: 24470_mob_poison.jpg
# Copied: 105534_2020-07-28_13208__mob_poison.jpg
# Copied: concentrix_li.tienan@concentrix.com_121578_2020-08-11_21065__mob_jitter.jpg
# Copied: 95837_2020-07-20_37__mob_jitter.jpg
# Copied: AliBadshaAnjalath_551068_mv_snap_17622.jpg
# Copied: 43400_2020-04-12_9370_.jpg
# Copied: 96426_2020-07-20_10923__mob_poison.jpg
# Copied: 922_dec_bright.jpg
# Copied: 1048_jitter.jpg
# Copied: 79494_2020-06-30_16167__mob_jitter.jpg
# Copied: 99315_2020-07-22_13770__mob_poison.jpg
# Copied: 48979_2020-04-23_9494_.jpg
# Copied: 26725.jpg
# Copied: 4220_mob_jitter.jpg
# Copied: 84002_2020-07-09_17566__mob_poison.jpg
# Copied: 680_poison_aug.jpg
# Copied: 12014_mob_poison.jpg
# Copied: 95959_2020-07-20_19029__mob_jitter.jpg
# Copied: 25708.jpg
# Copied: 71743_2020-06-10_462_.jpg
# Copied: 99162_2020-07-22_10425__mob_jitter.jpg
# Copied: 771_mob_poison.jpg
# Copied: 72269_2020-06-11_629__mob_jitter.jpg
# Copied: 43400_2020-04-12_9370__mob_jitter.jpg
# Copied: 47090_2020-04-20_9616__mob_poison.jpg
# Copied: 26700_mob_jitter.jpg
# Copied: 45743_2020-04-17_9465__mob_jitter.jpg
# Copied: 1192_1846059_Mobile Camera.jpg
# Copied: 95623_2020-07-19_84_.jpg
# Copied: 20034.jpg
# Copied: 91281_2020-07-15_9271__mob_jitter.jpg
# Copied: 42661_2020-04-08_19367__mob_poison.jpg
# Copied: 55658_2020-05-06_19302__mob_poison.jpg
# Copied: 27534_mob_poison.jpg
# Copied: 25564.jpg
# Copied: 72268_2020-06-11_466__mob_jitter.jpg
# Copied: 47542_2020-04-21_9874__mob_poison.jpg
# Copied: 862_dec_bright.jpg
# Copied: 88808_2020-07-14_17173__mob_poison.jpg
# Copied: 26131_mob_poison.jpg
# Copied: 25190_mob_poison.jpg
# Copied: 24363.jpg
# Copied: 73115_2020-06-14_1269__mob_poison.jpg
# Copied: 539_mob_poison.jpg
# Copied: 912_mob_poison.jpg
# Copied: 79861_2020-07-01_12123_.jpg
# Copied: 856_1737501_Mobile Camera.jpg
# Copied: 72268_2020-06-11_465__mob_poison.jpg
# Copied: 72222_2020-06-11_493_.jpg
# Copied: 26591_mob_jitter.jpg
# Copied: edwin.fragoso@fti-acuity.com_fti_consulting_proctordesk_hosted_3958_.jpg
# Copied: 58611_2020-05-12_17804_.jpg
# Copied: 55658_2020-05-06_19232__mob_poison.jpg
# Copied: 45148_2020-04-15_9683__mob_jitter.jpg
# Copied: 90327_2020-07-15_4982__mob_poison.jpg
# Copied: 24484.jpg
# Copied: 25592.jpg
# Copied: fti_Bonnie.Clements@fti-acuity.com_143621_2020-08-27_14060__mob_jitter.jpg
# Copied: 26059_mob_poison.jpg
# Copied: 85063_2020-07-10_3953_.jpg
# Copied: 58414_2020-05-12_17915_.jpg
# Copied: 1131_dec_bright.jpg
# Copied: Dennis.Donohue@fti-acuity.com_fti_consulting_proctordesk_hosted_3186__mob_jitter.jpg
# Copied: 87759_2020-07-13_13053__mob_poison.jpg
# Copied: 15526.jpg
# Copied: 23506_mob_poison.jpg
# Copied: 27697_mob_jitter.jpg
# Copied: 26501_mob_jitter.jpg
# Copied: 48911_2020-04-23_9366_.jpg
# Copied: 27517_mob_jitter.jpg
# Copied: 90336_2020-07-15_17875__mob_jitter.jpg
# Copied: 48911_2020-04-23_9366__mob_jitter.jpg
# Copied: 86689_2020-07-12_10969__mob_jitter.jpg
# Copied: fti_Chidiebere.Onukwugha@fti-acuity.com_129654_2020-08-17_18972_.jpg
# Copied: 26474_mob_jitter.jpg
# Copied: 72618_2020-06-12_499_.jpg
# Copied: angela.hsiao@fti-acuity.com_fti_consulting_proctordesk_hosted_19867_.jpg
# Copied: 1038.jpg
# Copied: 855_dec_bright.jpg
# Copied: 72268_2020-06-11_467_.jpg
# Copied: 44267_2020-04-14_9375__mob_poison.jpg
# Copied: 606784_104_2022-02-08_mob_jitter.jpeg
# Copied: 86392_2020-07-12_17741_.jpg
# Copied: 105461_2020-07-28_10481__mob_jitter.jpg
# Copied: 27609_mob_jitter.jpg
# Copied: 93170_2020-07-16_12275__mob_jitter.jpg
# Copied: 455_1567904_Mobile Camera.jpg
# Copied: 55658_2020-05-06_19292__mob_poison.jpg
# Copied: 94859_2020-07-17_13600__mob_poison.jpg
# Copied: 24557_mob_poison.jpg
# Copied: 15008_mob_jitter.jpg
# Copied: 45577_2020-04-16_226__mob_jitter.jpg
# Copied: 23574_mob_jitter.jpg
# Copied: 26359_mob_poison.jpg
# Copied: 25021.jpg
# Copied: 71235_2020-06-09_483__mob_jitter.jpg
# Copied: 3565_mob_jitter.jpg
# Copied: 25802_mob_poison.jpg
# Copied: 26368.jpg
# Copied: 92810_2020-07-16_12070__mob_poison.jpg
# Copied: 26954.jpg
# Copied: 26509_mob_poison.jpg
# Copied: 91557_2020-07-15_10707_.jpg
# Copied: fti_Christopher.Williams@fti-acuity.com_130038_2020-08-17_14975__mob_jitter.jpg
# Copied: concentrix_jin.mingyu@concentrix.com_119596_2020-08-09_21060__mob_poison.jpg
# Copied: 8704.jpg
# Copied: 75937_2020-06-21_1193_.jpg
# Copied: 27681.jpg
# Copied: fti_Cynthia.Park@fti-acuity.com_137476_2020-08-22_12249_.jpg
# Copied: 87759_2020-07-13_13056__mob_poison.jpg
# Copied: 79861_2020-07-01_12121__mob_poison.jpg
# Copied: 11539.jpg
# Copied: 82373_2020-07-06_10255__mob_jitter.jpg
# Copied: 3541_mob_poison.jpg
# Copied: 94740_2020-07-17_13120__mob_jitter.jpg
# Copied: 98029_2020-07-21_12746_.jpg
# Copied: 26584.jpg
# Copied: 24992.jpg
# Copied: 830_mob_jitter.jpg
# Copied: 24519.jpg
# Copied: 101573_2020-07-24_19056_.jpg
# Copied: 46028_2020-04-17_9613__mob_poison.jpg
# Copied: Christopher.Oliver@fti-acuity.com_fti_consulting_proctordesk_hosted_15054__mob_jitter.jpg
# Copied: 73805_2020-06-16_18216_.jpg
# Copied: 25619_mob_poison.jpg
# Copied: 55658_2020-05-06_19255__mob_jitter.jpg
# Copied: 25767_mob_jitter.jpg
# Copied: 27324.jpg
# Copied: 45472_2020-04-16_9506__mob_jitter.jpg
# Copied: 105558_2020-07-28_12452_.jpg
# Copied: 27655_mob_jitter.jpg
# Copied: 26857_mob_poison.jpg
# Copied: 86206_2020-07-11_10414__mob_poison.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_129434_2020-08-17_18843__mob_poison.jpg
# Copied: fti_Doreen.Nanda@fti-acuity.com_143829_2020-08-27_13100_.jpg
# Copied: Bijoux.Ngwanda@fti-acuity.com_fti_consulting_proctordesk_hosted_5466__mob_poison.jpg
# Copied: 753_mob_jitter.jpg
# Copied: 26512_mob_poison.jpg
# Copied: 27682_mob_jitter.jpg
# Copied: 26850_mob_jitter.jpg
# Copied: 26303.jpg
# Copied: 868_jitter.jpg
# Copied: 55658_2020-05-06_19297_.jpg
# Copied: 27049_mob_jitter.jpg
# Copied: 24802_mob_poison.jpg
# Copied: 26396.jpg
# Copied: 82336_2020-07-06_10501_.jpg
# Copied: 25765_mob_poison.jpg
# Copied: 103774_2020-07-27_10430__mob_poison.jpg
# Copied: 50865_2020-04-27_121_.jpg
# Copied: 27656.jpg
# Copied: 92644_2020-07-16_13068__mob_jitter.jpg
# Copied: 80750_2020-07-03_17775_.jpg
# Copied: 83881_2020-07-09_17498__mob_poison.jpg
# Copied: 19362_mob_poison.jpg
# Copied: 26637_mob_poison.jpg
# Copied: 25110_mob_poison.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18874_.jpg
# Copied: 25536_mob_poison.jpg
# Copied: fti_Charles.Oliver@fti-acuity.com_137289_2020-08-22_13853_.jpg
# Copied: 1127_mob_jitter.jpg
# Copied: 27000.jpg
# Copied: 27548_mob_poison.jpg
# Copied: 88526_2020-07-14_17354__mob_poison.jpg
# Copied: 76007_2020-06-21_982__mob_poison.jpg
# Copied: 24793.jpg
# Copied: 26405.jpg
# Copied: 97624_2020-07-21_10815__mob_jitter.jpg
# Copied: 80326_2020-07-02_11927__mob_jitter.jpg
# Copied: 23572.jpg
# Copied: 25841_mob_jitter.jpg
# Copied: 24139_mob_poison.jpg
# Copied: 26029_mob_jitter.jpg
# Copied: 106947_2020-07-29_10490__mob_poison.jpg
# Copied: 105594_2020-07-28_11358_.jpg
# Copied: 21666_mob_poison.jpg
# Copied: 867_mob_poison.jpg
# Copied: fti_Anthony.Carducci@fti-acuity.com_147212_2020-08-31_12956__mob_poison.jpg
# Copied: 26301_mob_jitter.jpg
# Copied: 55658_2020-05-06_19276_.jpg
# Copied: 26470_mob_jitter.jpg
# Copied: 83196_2020-07-08_17236__mob_jitter.jpg
# Copied: 87417_2020-07-13_13740_.jpg
# Copied: 23503.jpg
# Copied: 24284_mob_poison.jpg
# Copied: 23486_mob_poison.jpg
# Copied: 71239_2020-06-09_17846__mob_poison.jpg
# Copied: 27137_mob_jitter.jpg
# Copied: 16820_mob_poison.jpg
# Copied: 83881_2020-07-09_17499__mob_poison.jpg
# Copied: 45731_2020-04-17_9462__mob_jitter.jpg
# Copied: 809_mob_jitter.jpg
# Copied: 23464_mob_poison.jpg
# Copied: 91281_2020-07-15_9271_.jpg
# Copied: 24916.jpg
# Copied: fti_Alejandro.Echevarria@fti-acuity.com_142278_2020-08-26_13719__mob_poison.jpg
# Copied: 83758_2020-07-08_11122_.jpg
# Copied: 794_poison_aug.jpg
# Copied: 27341_mob_jitter.jpg
# Copied: 91817_2020-07-16_17743_.jpg
# Copied: 529.jpg
# Copied: 90728_2020-07-15_12894__mob_poison.jpg
# Copied: 27407.jpg
# Copied: 23520_mob_poison.jpg
# Copied: 96474_2020-07-20_48__mob_poison.jpg
# Copied: 24065.jpg
# Copied: 14290.jpg
# Copied: 20444_mob_jitter.jpg
# Copied: 84004_2020-07-09_10398_.jpg
# Copied: 25640_mob_jitter.jpg
# Copied: 84002_2020-07-09_17564__mob_jitter.jpg
# Copied: 83239_2020-07-08_6453__mob_poison.jpg
# Copied: 24459.jpg
# Copied: 71709_2020-06-10_9260_.jpg
# Copied: 1099_jitter.jpg
# Copied: 23582_mob_poison.jpg
# Copied: 26684_mob_poison.jpg
# Copied: 49526_2020-04-24_240_.jpg
# Copied: 1084.jpg
# Copied: 25098_mob_poison.jpg
# Copied: 68928_2020-06-04_18555__mob_poison.jpg
# Copied: 7956_mob_jitter.jpg
# Copied: 90169_2020-07-15_18886__mob_jitter.jpg
# Copied: 100097_2020-07-23_18141_.jpg
# Copied: 776_jitter.jpg
# Copied: 803_poison_aug.jpg
# Copied: 27544_mob_poison.jpg
# Copied: 801_dec_bright.jpg
# Copied: 23539_mob_poison.jpg
# Copied: 26228.jpg
# Copied: 5128.jpg
# Copied: 26240_mob_poison.jpg
# Copied: B R_629173_mv_snap_6106_mob_poison.jpg
# Copied: 45276_2020-04-16_9226_.jpg
# Copied: 24869_mob_jitter.jpg
# Copied: 11086.jpg
# Copied: 1338_1894144_Mobile Camera.jpg
# Copied: 90714_2020-07-15_17888__mob_jitter.jpg
# Copied: 85458_2020-07-10_13581__mob_jitter.jpg
# Copied: 93832_2020-07-17_9283__mob_poison.jpg
# Copied: 8233_mob_poison.jpg
# Copied: 26127.jpg
# Copied: concentrix_kanut.wandee@concentrix.com_119365_2020-08-08_21752__mob_poison.jpg
# Copied: 25903.jpg
# Copied: 101911_2020-07-24_10428_.jpg
# Copied: 27688_mob_poison.jpg
# Copied: 25338_mob_poison.jpg
# Copied: 25003_mob_poison.jpg
# Copied: 1146.jpg
# Copied: 27696_mob_poison.jpg
# Copied: 21653.jpg
# Copied: 21003.jpg
# Copied: 79935_2020-07-01_16989__jitter.jpg
# Copied: 25499_mob_jitter.jpg
# Copied: 26617_mob_poison.jpg
# Copied: 58833_2020-05-12_17942__mob_jitter.jpg
# Copied: 85268_2020-07-10_10834_.jpg
# Copied: 83196_2020-07-08_17194__mob_jitter.jpg
# Copied: 25648_mob_jitter.jpg
# Copied: 26219_mob_jitter.jpg
# Copied: 7488_mob_jitter.jpg
# Copied: 96220_2020-07-20_17405__mob_jitter.jpg
# Copied: fti_Cynthia.Park@fti-acuity.com_137476_2020-08-22_12249__mob_poison.jpg
# Copied: 1199_dec_bright.jpg
# Copied: 23588_mob_poison.jpg
# Copied: 96390_2020-07-20_13072_.jpg
# Copied: 23490_mob_poison.jpg
# Copied: 26813_mob_poison.jpg
# Copied: 26702_mob_poison.jpg
# Copied: 23456.jpg
# Copied: 24670.jpg
# Copied: 1037.jpg
# Copied: 45385_2020-04-16_9866__mob_jitter.jpg
# Copied: 106956_2020-07-29_9975_.jpg
# Copied: 11308_mob_jitter.jpg
# Copied: 12155.jpg
# Copied: 24413.jpg
# Copied: 98029_2020-07-21_12747__mob_poison.jpg
# Copied: 84333_2020-07-09_13213__mob_jitter.jpg
# Copied: 3615_mob_jitter.jpg
# Copied: 90889_2020-07-15_12059__mob_poison.jpg
# Copied: 12431.jpg
# Copied: 25089.jpg
# Copied: 16482_mob_jitter.jpg
# Copied: 91320_2020-07-15_19342__mob_poison.jpg
# Copied: 25055_mob_jitter.jpg
# Copied: 604470_45_2022-02-08.jpeg
# Copied: 26208_mob_poison.jpg
# Copied: 23613_mob_jitter.jpg
# Copied: 24760_mob_poison.jpg
# Copied: 25965_mob_poison.jpg
# Copied: 79320_2020-06-30_12104__mob_poison.jpg
# Copied: 5671_mob_poison.jpg
# Copied: 25584_mob_jitter.jpg
# Copied: 26021_mob_jitter.jpg
# Copied: fti_Doreen.Nanda@fti-acuity.com_145362_2020-08-28_13123_.jpg
# Copied: 45142_2020-04-15_9805_.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_127914_2020-08-15_18823__mob_poison.jpg
# Copied: 55658_2020-05-06_19300_.jpg
# Copied: 87785_2020-07-13_10971_.jpg
# Copied: 71954_2020-06-11_489_.jpg
# Copied: 26361.jpg
# Copied: 24767_mob_poison.jpg
# Copied: 1677_1969955_Mobile Camera.jpg
# Copied: 26137_mob_jitter.jpg
# Copied: concentrix_sahud1@aetna.com_135735_2020-08-21_21102__mob_jitter.jpg
# Copied: 48931_2020-04-23_9432__mob_poison.jpg
# Copied: 71239_2020-06-09_17845__mob_poison.jpg
# Copied: 7374_mob_jitter.jpg
# Copied: 82670_2020-07-07_11860__mob_poison.jpg
# Copied: 106432_2020-07-29_16963__mob_poison.jpg
# Copied: 96514_2020-07-20_39__mob_jitter.jpg
# Copied: 71283_2020-06-09_622__mob_poison.jpg
# Copied: 772_mob_poison.jpg
# Copied: 73150_2020-06-14_998__mob_jitter.jpg
# Copied: 5535_mob_jitter.jpg
# Copied: 81079_2020-07-04_18798_.jpg
# Copied: 24118_mob_jitter.jpg
# Copied: 23507_mob_poison.jpg
# Copied: 27671_mob_jitter.jpg
# Copied: 20971_mob_jitter.jpg
# Copied: fti_Anthony.Carducci@fti-acuity.com_132775_2020-08-19_12950__mob_poison.jpg
# Copied: 26555_mob_jitter.jpg
# Copied: 843.jpg
# Copied: 27282_mob_jitter.jpg
# Copied: 25670_mob_jitter.jpg
# Copied: 11518_mob_poison.jpg
# Copied: 26147_mob_jitter.jpg
# Copied: 23519.jpg
# Copied: 27741_mob_poison.jpg
# Copied: 91377_2020-07-15_13593__mob_poison.jpg
# Copied: 59_mob_jitter.jpg
# Copied: 27200_mob_poison.jpg
# Copied: 90457_2020-07-15_8424__mob_jitter.jpg
# Copied: 24407_mob_poison.jpg
# Copied: 680_mob_poison.jpg
# Copied: concentrix_kanut.wandee@concentrix.com_119365_2020-08-08_21752_.jpg
# Copied: 82834_2020-07-07_12976_.jpg
# Copied: 26318_mob_poison.jpg
# Copied: 25017_mob_jitter.jpg
# Copied: 26221_mob_jitter.jpg
# Copied: 773_jitter.jpg
# Copied: 82709_2020-07-07_12037_.jpg
# Copied: 82670_2020-07-07_11862__mob_jitter.jpg
# Copied: fti_Cheryl.Buttone@fti-acuity.com_143620_2020-08-27_14177__mob_jitter.jpg
# Copied: 83196_2020-07-08_17199__mob_poison.jpg
# Copied: 87785_2020-07-13_10970__mob_jitter.jpg
# Copied: 55658_2020-05-06_19257_.jpg
# Copied: AliBadshaAnjalath_555741_mv_snap_17729_mob_jitter.jpg
# Copied: 12236_mob_poison.jpg
# Copied: 24339_mob_poison.jpg
# Copied: 65706_2020-05-28_9257_.jpg
# Copied: 73805_2020-06-16_18214__mob_jitter.jpg
# Copied: 7965.jpg
# Copied: 9036_mob_jitter.jpg
# Copied: 85273_2020-07-10_6589__mob_jitter.jpg
# Copied: 23564.jpg
# Copied: 51651_2020-04-29_19219_.jpg
# Copied: 24461.jpg
# Copied: 23485.jpg
# Copied: 107277_2020-07-29_10321_.jpg
# Copied: concentrix_jin.mingyu@concentrix.com_119596_2020-08-09_21059_.jpg
# Copied: 95927_2020-07-20_10__mob_jitter.jpg
# Copied: 23514_mob_poison.jpg
# Copied: 85458_2020-07-10_13583__mob_poison.jpg
# Copied: 15160_mob_poison.jpg
# Copied: 96220_2020-07-20_17409__mob_poison.jpg
# Copied: 97736_2020-07-21_14170_.jpg
# Copied: 522_poison_aug.jpg
# Copied: 9576_mob_jitter.jpg
# Copied: 804_mob_jitter.jpg
# Copied: 24472_mob_jitter.jpg
# Copied: Aaron.Michel@fti-acuity.com_fti_consulting_proctordesk_hosted_14741__mob_poison.jpg
# Copied: 16784_mob_poison.jpg
# Copied: 11450.jpg
# Copied: 43943_2020-04-14_9837__mob_poison.jpg
# Copied: 3561_mob_jitter.jpg
# Copied: 61745_2020-05-18_17826_.jpg
# Copied: 24959_mob_poison.jpg
# Copied: 51659_2020-04-29_135_.jpg
# Copied: 803_mob_jitter.jpg
# Copied: 601301_166_2022-02-04_mob_poison.jpeg
# Copied: 74288_2020-06-17_18219_.jpg
# Copied: 717_1663110_Mobile Camera.jpg
# Copied: 25091.jpg
# Copied: 82627_2020-07-07_14707__mob_poison.jpg
# Copied: 24596_mob_poison.jpg
# Copied: 83196_2020-07-08_17184__mob_jitter.jpg
# Copied: 23520.jpg
# Copied: 741_poison_aug.jpg
# Copied: 26562_mob_jitter.jpg
# Copied: 26495_mob_poison.jpg
# Copied: 96261_2020-07-20_10807__mob_jitter.jpg
# Copied: 83196_2020-07-08_17186__mob_poison.jpg
# Copied: 84779_2020-07-10_17623__mob_poison.jpg
# Copied: 80656_2020-07-03_9266_.jpg
# Copied: 26526.jpg
# Copied: 19495.jpg
# Copied: 104638_2020-07-27_11367__mob_poison.jpg
# Copied: 4114.jpg
# Copied: 75937_2020-06-21_1194__mob_jitter.jpg
# Copied: 27788_mob_jitter.jpg
# Copied: 45168_2020-04-15_9590__mob_poison.jpg
# Copied: 83332_2020-07-08_12723__mob_poison.jpg
# Copied: 822_mob_poison.jpg
# Copied: 23400.jpg
# Copied: 100671_2020-07-23_16248__mob_jitter.jpg
# Copied: 12145_mob_poison.jpg
# Copied: 45884_2020-04-17_9718__mob_jitter.jpg
# Copied: 857.jpg
# Copied: 26475_mob_jitter.jpg
# Copied: 25166_mob_jitter.jpg
# Copied: 26200_mob_poison.jpg
# Copied: 26196.jpg
# Copied: 49121_2020-04-23_9246_.jpg
# Copied: 27564_mob_poison.jpg
# Copied: 11302_mob_poison.jpg
# Copied: 1760_1986799_Mobile Camera.jpg
# Copied: 94164_2020-07-17_10789_.jpg
# Copied: 24450_mob_poison.jpg
# Copied: 26717_mob_jitter.jpg
# Copied: 864.jpg
# Copied: 96513_2020-07-20_3354__mob_poison.jpg
# Copied: 24690_mob_jitter.jpg
# Copied: 100817_2020-07-23_14405__mob_poison.jpg
# Copied: 85458_2020-07-10_13585_.jpg
# Copied: 108439_2020-07-30_12462_.jpg
# Copied: 26016_mob_poison.jpg
# Copied: 108320_2020-07-30_14481__mob_jitter.jpg
# Copied: 849_jitter.jpg
# Copied: 97404_2020-07-21_4992__mob_jitter.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_131153_2020-08-18_18848_.jpg
# Copied: 95875_2020-07-20_46_.jpg
# Copied: 72089_2020-06-11_19322__mob_poison.jpg
# Copied: 23985.jpg
# Copied: 904_dec_bright.jpg
# Copied: 27629.jpg
# Copied: 91189_2020-07-15_19332_.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_18988__mob_jitter.jpg
# Copied: 94781_2020-07-17_12073_.jpg
# Copied: 108441_2020-07-30_15796__mob_poison.jpg
# Copied: 24546.jpg
# Copied: 26222.jpg
# Copied: 25765_mob_jitter.jpg
# Copied: 72013_2020-06-11_533_.jpg
# Copied: 20660_mob_jitter.jpg
# Copied: 45282_2020-04-16_9455__mob_jitter.jpg
# Copied: 27604_mob_jitter.jpg
# Copied: 914_mob_poison.jpg
# Copied: 55658_2020-05-06_19312__mob_jitter.jpg
# Copied: 45946_2020-04-17_114_.jpg
# Copied: 26176.jpg
# Copied: 45277_2020-04-16_9427__mob_jitter.jpg
# Copied: 94706_2020-07-17_10922__mob_jitter.jpg
# Copied: 82140_2020-07-06_11850__mob_jitter.jpg
# Copied: 25099_mob_jitter.jpg
# Copied: 84779_2020-07-10_17588__mob_jitter.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_131166_2020-08-18_14294__mob_poison.jpg
# Copied: 9919_mob_poison.jpg
# Copied: 45884_2020-04-17_9717__mob_poison.jpg
# Copied: fti_Cristina.Bosmenier@fti-acuity.com_128721_2020-08-17_13788__mob_jitter.jpg
# Copied: 92228_2020-07-16_3763__mob_jitter.jpg
# Copied: 83196_2020-07-08_17220_.jpg
# Copied: 44886_2020-04-15_9864__mob_jitter.jpg
# Copied: 26468_mob_jitter.jpg
# Copied: 8574_mob_jitter.jpg
# Copied: 25676_mob_poison.jpg
# Copied: 896_mob_poison.jpg
# Copied: 26778_mob_jitter.jpg
# Copied: 10424_mob_poison.jpg
# Copied: 79347_2020-06-30_12877_.jpg
# Copied: 24914.jpg
# Copied: 48288_2020-04-22_233_.jpg
# Copied: 659_dec_bright.jpg
# Copied: 106740_2020-07-29_12830__mob_poison.jpg
# Copied: 8025_mob_jitter.jpg
# Copied: 49526_2020-04-24_244_.jpg
# Copied: 96261_2020-07-20_10804_.jpg
# Copied: 23423_mob_poison.jpg
# Copied: 26684.jpg
# Copied: fti_Benjamin.Hodges@fti-acuity.com_132957_2020-08-19_18889__mob_jitter.jpg
# Copied: 25573_mob_jitter.jpg
# Copied: 27168_mob_poison.jpg
# Copied: 25651.jpg
# Copied: 26273_mob_jitter.jpg
# Copied: 25441_mob_poison.jpg
# Copied: 103907_2020-07-27_13085__mob_jitter.jpg
# Copied: 7815.jpg
# Copied: 84854_2020-07-10_2412__mob_jitter.jpg
# Copied: 103488_2020-07-27_19177__mob_jitter.jpg
# Copied: 44309_2020-04-14_9652_.jpg
# Copied: 3587_mob_jitter.jpg
# Copied: 44858_2020-04-15_9424_.jpg
# Copied: 13390_mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_19003__mob_poison.jpg
# Copied: 835.jpg
# Copied: 90813_2020-07-15_8029__mob_poison.jpg
# Copied: 24521_mob_jitter.jpg
# Copied: 23511_mob_poison.jpg
# Copied: 51713_2020-04-29_299__mob_jitter.jpg
# Copied: 51352_2020-04-28_133__mob_poison.jpg
# Copied: 26195_mob_jitter.jpg
# Copied: 58608_2020-05-12_17797__mob_jitter.jpg
# Copied: 16.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_142543_2020-08-26_19026__mob_poison.jpg
# Copied: 15185_mob_poison.jpg
# Copied: 26485_mob_jitter.jpg
# Copied: 9899.jpg
# Copied: 26237_mob_jitter.jpg
# Copied: 21437.jpg
# Copied: 26722.jpg
# Copied: 26364_mob_jitter.jpg
# Copied: 826_poison_aug.jpg
# Copied: 26115.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_129426_2020-08-17_14279__mob_poison.jpg
# Copied: 84734_2020-07-10_3127_.jpg
# Copied: 103466_2020-07-27_18822_.jpg
# Copied: 8381_mob_poison.jpg
# Copied: 759_jitter.jpg
# Copied: 52292_2020-04-30_105__mob_jitter.jpg
# Copied: 24941.jpg
# Copied: fti_Claire.Campbell@fti-acuity.com_134706_2020-08-20_14536__mob_poison.jpg
# Copied: 18597_mob_jitter.jpg
# Copied: 80696_2020-07-03_9276__mob_jitter.jpg
# Copied: 83196_2020-07-08_17202_.jpg
# Copied: 21107_mob_jitter.jpg
# Copied: 90954_2020-07-15_15683__mob_jitter.jpg
# Copied: 24837_mob_jitter.jpg
# Copied: 106432_2020-07-29_16963__mob_jitter.jpg
# Copied: 19582_mob_poison.jpg
# Copied: 26062_mob_jitter.jpg
# Copied: 27645_mob_jitter.jpg
# Copied: 57929_2020-05-11_17901_.jpg
# Copied: 99109_2020-07-22_10465_.jpg
# Copied: 26061.jpg
# Copied: 27339_mob_poison.jpg
# Copied: 25090.jpg
# Copied: 26134.jpg
# Copied: 93525_2020-07-17_22__mob_jitter.jpg
# Copied: 83261_2020-07-08_9277_.jpg
# Copied: 44303_2020-04-14_9434__mob_poison.jpg
# Copied: 11085_mob_poison.jpg
# Copied: 94859_2020-07-17_13599__mob_jitter.jpg
# Copied: 51728_2020-04-29_97_.jpg
# Copied: 24189_mob_jitter.jpg
# Copied: fti_Andrew.Bresalier@fti-acuity.com_132436_2020-08-19_19038__mob_jitter.jpg
# Copied: 4174_mob_jitter.jpg
# Copied: 24317_mob_jitter.jpg
# Copied: 809.jpg
# Copied: 26330_mob_jitter.jpg
# Copied: 26569.jpg
# Copied: 93832_2020-07-17_9282_.jpg
# Copied: 51318_2020-04-28_278__mob_poison.jpg
# Copied: 105893_2020-07-28_14341__mob_poison.jpg
# Copied: 84779_2020-07-10_17601__mob_jitter.jpg
# Copied: 100655_2020-07-23_8037__mob_poison.jpg
# Copied: 25042_mob_poison.jpg
# Copied: 42986_2020-04-10_19378_.jpg
# Copied: 99162_2020-07-22_10425__mob_poison.jpg
# Copied: 51713_2020-04-29_290_.jpg
# Copied: 26170_mob_jitter.jpg
# Copied: 84002_2020-07-09_17551__mob_jitter.jpg
# Copied: 11450_mob_poison.jpg
# Copied: 101537_2020-07-24_17646__mob_poison.jpg
# Copied: 25688_mob_jitter.jpg
# Copied: 87180_2020-07-13_14131__mob_poison.jpg
# Copied: 48393_2020-04-22_9321_.jpg
# Copied: 108983_2020-07-30_12303_.jpg
# Copied: 26538_mob_poison.jpg
# Copied: 25667_mob_poison.jpg
# Copied: 26435_mob_poison.jpg
# Copied: 24450.jpg
# Copied: 26234_mob_poison.jpg
# Copied: Ekade_592588_mv_snap_39106_mob_poison.jpg
# Copied: 88526_2020-07-14_17341__mob_jitter.jpg
# Copied: 26566_mob_poison.jpg
# Copied: 84779_2020-07-10_17583__mob_jitter.jpg
# Copied: 24792.jpg
# Copied: fti_Chidiebere.Onukwugha@fti-acuity.com_129654_2020-08-17_18972__mob_poison.jpg
# Copied: 105558_2020-07-28_12449__mob_jitter.jpg
# Copied: 71637_2020-06-10_17847__mob_jitter.jpg
# Copied: 799_jitter.jpg
# Copied: 95404_2020-07-18_19028__mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_137273_2020-08-22_19006__mob_poison.jpg
# Copied: 89463_2020-07-14_13743__mob_jitter.jpg
# Copied: 105551_2020-07-28_16972__mob_poison.jpg
# Copied: 23512.jpg
# Copied: 1199_mob_poison.jpg
# Copied: 83488_2020-07-08_12042__mob_poison.jpg
# Copied: 85349_2020-07-10_13796__mob_poison.jpg
# Copied: 99370_2020-07-22_11140_.jpg
# Copied: 84779_2020-07-10_17630__mob_poison.jpg
# Copied: 27324_mob_jitter.jpg
# Copied: fti_Christopher.Oliver@fti-acuity.com_133198_2020-08-19_12186__mob_poison.jpg
# Copied: 897_dec_bright.jpg
# Copied: 46330_2020-04-18_9346_.jpg
# Copied: 5954_mob_jitter.jpg
# Copied: 95402_2020-07-18_18900_.jpg
# Copied: 89192_2020-07-14_10419_.jpg
# Copied: 24112_mob_jitter.jpg
# Copied: 24529.jpg
# Copied: 107424_2020-07-29_10831_.jpg
# Copied: 92383_2020-07-16_3921__mob_jitter.jpg
# Copied: 96532_2020-07-20_10007_.jpg
# Copied: 85261_2020-07-10_13287__mob_jitter.jpg
# Copied: 828_mob_poison.jpg
# Copied: 46913_2020-04-20_9830__mob_poison.jpg
# Copied: 24284.jpg
# Copied: 25823.jpg
# Copied: 23496_mob_jitter.jpg
# Copied: 96869_2020-07-20_12290__mob_jitter.jpg
# Copied: 5129_mob_jitter.jpg
# Copied: 23479_mob_jitter.jpg
# Copied: 83196_2020-07-08_17250__mob_poison.jpg
# Copied: 95252_2020-07-17_12076_.jpg
# Copied: 26846_mob_jitter.jpg
# Copied: 26184_mob_jitter.jpg
# Copied: 44906_2020-04-15_223__mob_jitter.jpg
# Copied: 12074.jpg
# Copied: 23555_mob_poison.jpg
# Copied: 24270_mob_jitter.jpg
# Copied: 26413_mob_jitter.jpg
# Copied: 532_dec_bright.jpg
# Copied: 25745_mob_poison.jpg
# Copied: 8837_mob_poison.jpg
# Copied: 912_mob_jitter.jpg
# Copied: 25690.jpg
# Copied: 55658_2020-05-06_19293_.jpg
# Copied: 26349_mob_jitter.jpg
# Copied: 74052_2020-06-16_17850__mob_poison.jpg
# Copied: 82187_2020-07-06_12850__mob_poison.jpg
# Copied: 24119.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_127914_2020-08-15_18825__mob_poison.jpg
# Copied: 24107.jpg
# Copied: 84004_2020-07-09_10405__mob_jitter.jpg
# Copied: fti_Bijoux.Ngwanda@fti-acuity.com_129773_2020-08-17_14868_.jpg
# Copied: 100097_2020-07-23_18141__mob_jitter.jpg
# Copied: 50637_2020-04-27_117_.jpg
# Copied: 79335_2020-06-30_16982__poison_aug.jpg
# Copied: 94796_2020-07-17_11108__mob_jitter.jpg
# Copied: 84970_2020-07-10_4268__mob_jitter.jpg
# Copied: 25593_mob_poison.jpg
# Copied: 25884_mob_jitter.jpg
# Copied: 55658_2020-05-06_19267__mob_jitter.jpg
# Copied: 681_dec_bright.jpg
# Copied: 98056_2020-07-21_13247_.jpg
# Copied: 20901.jpg
# Copied: 24915_mob_jitter.jpg
# Copied: 83589_2020-07-08_1821__mob_jitter.jpg
# Copied: 95927_2020-07-20_7__mob_jitter.jpg
# Copied: 84703_2020-07-10_4950__mob_poison.jpg
# Copied: 55658_2020-05-06_19270__mob_jitter.jpg
# Copied: 26365.jpg
# Copied: 26580_mob_poison.jpg
# Copied: 25012_mob_poison.jpg
# Copied: 25950_mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_141789_2020-08-26_19018__mob_jitter.jpg
# Copied: 91817_2020-07-16_17743__mob_jitter.jpg
# Copied: 25770.jpg
# Copied: 46330_2020-04-18_9343__mob_poison.jpg
# Copied: 96220_2020-07-20_17407__mob_jitter.jpg
# Copied: 854_mob_jitter.jpg
# Copied: 104873_2020-07-28_17752__mob_poison.jpg
# Copied: 70886_2020-06-08_521__mob_poison.jpg
# Copied: 23526.jpg
# Copied: 97918_2020-07-21_13766__mob_poison.jpg
# Copied: 45156_2020-04-15_9807_.jpg
# Copied: fti_Anastasiya.Sack@fti-acuity.com_147287_2020-08-31_13189__mob_jitter.jpg
# Copied: 12146.jpg
# Copied: 26477_mob_jitter.jpg
# Copied: 90777_2020-07-15_12791__mob_jitter.jpg
# Copied: 85314_2020-07-10_7006__mob_poison.jpg
# Copied: 45889_2020-04-17_9309__mob_jitter.jpg
# Copied: 44888_2020-04-15_9381__mob_jitter.jpg
# Copied: 94790_2020-07-17_14165_.jpg
# Copied: 108324_2020-07-30_17426_.jpg
# Copied: 1205_1852969_Mobile Camera.jpg
# Copied: 90856_2020-07-15_11769__mob_jitter.jpg
# Copied: 27297_mob_jitter.jpg
# Copied: 44886_2020-04-15_9864__jitter.jpg
# Copied: 91104_2020-07-15_2605__mob_poison.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_129426_2020-08-17_14274__mob_poison.jpg
# Copied: 106872_2020-07-29_14185_.jpg
# Copied: 16125.jpg
# Copied: 4220.jpg
# Copied: 25737_mob_jitter.jpg
# Copied: 23410_mob_jitter.jpg
# Copied: 55658_2020-05-06_19263__mob_poison.jpg
# Copied: 27599.jpg
# Copied: 15480_mob_poison.jpg
# Copied: 84779_2020-07-10_17614__mob_poison.jpg
# Copied: 20899_mob_jitter.jpg
# Copied: 27592_mob_jitter.jpg
# Copied: 24921.jpg
# Copied: 27527_mob_poison.jpg
# Copied: 95927_2020-07-20_16__mob_jitter.jpg
# Copied: 25460_mob_jitter.jpg
# Copied: 23409.jpg
# Copied: 23412_mob_jitter.jpg
# Copied: 905_poison_aug.jpg
# Copied: 72269_2020-06-11_629_.jpg
# Copied: 95875_2020-07-20_46__mob_jitter.jpg
# Copied: 24458.jpg
# Copied: fti_Cristina.Bosmenier@fti-acuity.com_138875_2020-08-24_13817_.jpg
# Copied: 82140_2020-07-06_11846__mob_jitter.jpg
# Copied: 12130_mob_poison.jpg
# Copied: 24816_mob_poison.jpg
# Copied: 24493_mob_poison.jpg
# Copied: 26259_mob_poison.jpg
# Copied: 18172_mob_jitter.jpg
# Copied: concentrix_naranga@aetna.com_118132_2020-08-07_21244_.jpg
# Copied: concentrix_patchanok.yangtisan@concentrix.com_110597_2020-08-01_21592__mob_jitter.jpg
# Copied: 23555_mob_jitter.jpg
# Copied: 23373_mob_jitter.jpg
# Copied: 23465.jpg
# Copied: 46315_2020-04-18_9396__mob_poison.jpg
# Copied: 26556_mob_jitter.jpg
# Copied: 59071_2020-05-13_18190__mob_jitter.jpg
# Copied: 108571_2020-07-30_10498__mob_poison.jpg
# Copied: concentrix_SinghR18@aetna.com_123101_2020-08-12_21166__mob_poison.jpg
# Copied: 51350_2020-04-28_95__mob_jitter.jpg
# Copied: 23483.jpg
# Copied: 26486_mob_poison.jpg
# Copied: 44250_2020-04-14_9371__mob_poison.jpg
# Copied: 26102.jpg
# Copied: 108419_2020-07-30_14196__mob_poison.jpg
# Copied: 79335_2020-06-30_16982__mob_poison.jpg
# Copied: 26316_mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_142543_2020-08-26_19027__mob_poison.jpg
# Copied: 8635.jpg
# Copied: 17390_mob_jitter.jpg
# Copied: 10804_mob_poison.jpg
# Copied: 26629_mob_jitter.jpg
# Copied: 23394.jpg
# Copied: 84874_2020-07-10_2607_.jpg
# Copied: 83196_2020-07-08_17196__mob_poison.jpg
# Copied: 73150_2020-06-14_998_.jpg
# Copied: 24454_mob_poison.jpg
# Copied: fti_Ellery.Karl@fti-acuity.com_130907_2020-08-18_11564__mob_jitter.jpg
# Copied: 25718_mob_jitter.jpg
# Copied: concentrix_naranga@aetna.com_130570_2020-08-18_21263__mob_poison.jpg
# Copied: 96869_2020-07-20_12292__mob_poison.jpg
# Copied: 1101_poison_aug.jpg
# Copied: 103466_2020-07-27_18821__mob_poison.jpg
# Copied: 24030_mob_poison.jpg
# Copied: 818_poison_aug.jpg
# Copied: 893_dec_bright.jpg
# Copied: concentrix_sahud1@aetna.com_116501_2020-08-06_21089__mob_poison.jpg
# Copied: 80318_2020-07-02_12133__mob_poison.jpg
# Copied: 84002_2020-07-09_17559__mob_poison.jpg
# Copied: 94944_2020-07-17_13537__mob_jitter.jpg
# Copied: 42949_2020-04-10_19375__mob_poison.jpg
# Copied: 84002_2020-07-09_17562__mob_jitter.jpg
# Copied: fti_Charles.Oliver@fti-acuity.com_147005_2020-08-31_13866__mob_jitter.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18878__mob_jitter.jpg
# Copied: 25671_mob_jitter.jpg
# Copied: 84699_2020-07-10_17699_.jpg
# Copied: AliBadshaAnjalath_542614_mv_snap_17490_mob_poison.jpg
# Copied: 24113.jpg
# Copied: 24071_mob_poison.jpg
# Copied: 26180.jpg
# Copied: 825_dec_bright.jpg
# Copied: 27650_mob_jitter.jpg
# Copied: 89192_2020-07-14_10417__mob_poison.jpg
# Copied: 71699_2020-06-10_487__mob_jitter.jpg
# Copied: 26260_mob_jitter.jpg
# Copied: 26485_mob_poison.jpg
# Copied: 25187.jpg
# Copied: 10019_mob_jitter.jpg
# Copied: 859.jpg
# Copied: 84729_2020-07-10_8143__mob_jitter.jpg
# Copied: 790_dec_bright.jpg
# Copied: 27283_mob_poison.jpg
# Copied: fti_carolee.byrley@fti-acuity.com_139533_2020-08-25_14496__mob_jitter.jpg
# Copied: 84779_2020-07-10_17594__mob_jitter.jpg
# Copied: 25855_mob_poison.jpg
# Copied: 97890_2020-07-21_10847__mob_jitter.jpg
# Copied: 896_dec_bright.jpg
# Copied: 96857_2020-07-20_52__mob_jitter.jpg
# Copied: 103850_2020-07-27_10856_.jpg
# Copied: 83954_2020-07-09_17056_.jpg
# Copied: 91425_2020-07-15_14160__mob_jitter.jpg
# Copied: fti_Cristina.Bosmenier@fti-acuity.com_137072_2020-08-24_13808_.jpg
# Copied: 11405.jpg
# Copied: 25020_mob_poison.jpg
# Copied: 26115_mob_poison.jpg
# Copied: 90632_2020-07-15_8521__mob_jitter.jpg
# Copied: concentrix_SinghR18@aetna.com_123101_2020-08-12_21168__mob_jitter.jpg
# Copied: 51113_2020-04-28_91_.jpg
# Copied: 26028.jpg
# Copied: 103471_2020-07-27_17750_.jpg
# Copied: 84779_2020-07-10_17589__mob_jitter.jpg
# Copied: 13285_mob_poison.jpg
# Copied: 26618_jitter.jpg
# Copied: 13009_mob_jitter.jpg
# Copied: 106841_2020-07-29_14375__mob_jitter.jpg
# Copied: 100655_2020-07-23_8041_.jpg
# Copied: 14864_mob_poison.jpg
# Copied: 80686_2020-07-03_17771_.jpg
# Copied: 1236_1866383_Mobile Camera.jpg
# Copied: 13668_mob_poison.jpg
# Copied: 105461_2020-07-28_10483__mob_jitter.jpg
# Copied: concentrix_rtilao+agent@globe.com.ph_117263_2020-08-06_21590__mob_jitter.jpg
# Copied: 17359.jpg
# Copied: 43160_2020-04-11_19387_.jpg
# Copied: 105342_2020-07-28_13089__mob_poison.jpg
# Copied: 16652_mob_jitter.jpg
# Copied: 71713_2020-06-10_461_.jpg
# Copied: 21438.jpg
# Copied: 98936_2020-07-22_7740_.jpg
# Copied: 23501_mob_poison.jpg
# Copied: 25070_mob_jitter.jpg
# Copied: 27678_mob_poison.jpg
# Copied: 100445_2020-07-23_10850__mob_jitter.jpg
# Copied: 73150_2020-06-14_996__mob_poison.jpg
# Copied: 27653_mob_poison.jpg
# Copied: 5535.jpg
# Copied: 25858.jpg
# Copied: 87435_2020-07-13_13729_.jpg
# Copied: 25116_mob_poison.jpg
# Copied: 44303_2020-04-14_9440_.jpg
# Copied: fti_Allan.Kobel@fti-acuity.com_144901_2020-08-28_16144__mob_poison.jpg
# Copied: 1132_dec_bright.jpg
# Copied: 95927_2020-07-20_15__mob_poison.jpg
# Copied: fti_Benjamin.Hodges@fti-acuity.com_134703_2020-08-20_18895_.jpg
# Copied: 25676_mob_jitter.jpg
# Copied: 4926_mob_poison.jpg
# Copied: 761.jpg
# Copied: 84779_2020-07-10_17606_.jpg
# Copied: 47090_2020-04-20_9617__mob_jitter.jpg
# Copied: 27187_mob_jitter.jpg
# Copied: 1285_1871980_Mobile Camera.jpg
# Copied: 56302_2020-05-07_17939_.jpg
# Copied: 895_jitter.jpg
# Copied: 94164_2020-07-17_10788__mob_poison.jpg
# Copied: 80567_2020-07-02_14891__mob_poison.jpg
# Copied: 26156.jpg
# Copied: 26684_mob_jitter.jpg
# Copied: 24440.jpg
# Copied: 603031_153_2022-02-06_jitter.jpeg
# Copied: 1131_jitter.jpg
# Copied: 24227_mob_poison.jpg
# Copied: 10132_mob_poison.jpg
# Copied: 58882_2020-05-12_17807__mob_poison.jpg
# Copied: 26626.jpg
# Copied: 55658_2020-05-06_19264__mob_jitter.jpg
# Copied: 16652_mob_poison.jpg
# Copied: fti_Anastasiya.Sack@fti-acuity.com_147287_2020-08-31_13189__mob_poison.jpg
# Copied: 24998_mob_jitter.jpg
# Copied: 92863_2020-07-16_10935__mob_poison.jpg
# Copied: 23429_mob_jitter.jpg
# Copied: 13038_mob_poison.jpg
# Copied: 25165_mob_poison.jpg
# Copied: 9475_mob_jitter.jpg
# Copied: 86478_2020-07-12_3786_.jpg
# Copied: 74288_2020-06-17_18219__mob_poison.jpg
# Copied: 24079.jpg
# Copied: 48288_2020-04-22_231__mob_jitter.jpg
# Copied: 27019_mob_jitter.jpg
# Copied: 792_dec_bright.jpg
# Copied: 27295_mob_poison.jpg
# Copied: 23417_mob_poison.jpg
# Copied: 27024.jpg
# Copied: 44334_2020-04-14_9222__mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_142543_2020-08-26_19024_.jpg
# Copied: 6428_mob_poison.jpg
# Copied: 51130_2020-04-28_274_.jpg
# Copied: 27789.jpg
# Copied: 612073_51_2022-02-10_poison_aug.jpeg
# Copied: 25746.jpg
# Copied: 768_mob_poison.jpg
# Copied: 23393.jpg
# Copied: 878_jitter.jpg
# Copied: 44725_2020-04-15_9863_.jpg
# Copied: 26122_mob_poison.jpg
# Copied: 27248_mob_poison.jpg
# Copied: 686.jpg
# Copied: concentrix_d.manisha@concentrix.com_111330_2020-08-02_21999_.jpg
# Copied: 86472_2020-07-12_348__mob_poison.jpg
# Copied: 749_mob_poison.jpg
# Copied: 94164_2020-07-17_10790__mob_jitter.jpg
# Copied: 1084_mob_poison.jpg
# Copied: 83196_2020-07-08_17205__mob_poison.jpg
# Copied: 759_mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_18991_.jpg
# Copied: 83589_2020-07-08_1823__mob_poison.jpg
# Copied: 24545_mob_poison.jpg
# Copied: fti_Darryl.Toler@fti-acuity.com_134580_2020-08-20_11959_.jpg
# Copied: 83391_2020-07-08_15199__mob_jitter.jpg
# Copied: 99630_2020-07-22_12416__mob_jitter.jpg
# Copied: 26766_mob_jitter.jpg
# Copied: 25218_mob_jitter.jpg
# Copied: 24431_mob_jitter.jpg
# Copied: 27642_mob_poison.jpg
# Copied: 26396_mob_poison.jpg
# Copied: 106645_2020-07-29_12367_.jpg
# Copied: 83196_2020-07-08_17244__mob_poison.jpg
# Copied: 23385_mob_jitter.jpg
# Copied: Dania.Arencibia@fti-acuity.com_fti_consulting_proctordesk_hosted_7002__mob_jitter.jpg
# Copied: 898_jitter.jpg
# Copied: 27606.jpg
# Copied: 25625_mob_poison.jpg
# Copied: 23514_mob_jitter.jpg
# Copied: 83196_2020-07-08_17239__mob_jitter.jpg
# Copied: 25935_mob_jitter.jpg
# Copied: 14215_mob_jitter.jpg
# Copied: 45159_2020-04-15_9686__mob_jitter.jpg
# Copied: 46330_2020-04-18_9353__mob_jitter.jpg
# Copied: 26397_mob_poison.jpg
# Copied: 1044.jpg
# Copied: 43556_2020-04-13_9851_.jpg
# Copied: 24458_mob_jitter.jpg
# Copied: 105558_2020-07-28_12451_.jpg
# Copied: 26232_mob_poison.jpg
# Copied: 71713_2020-06-10_461__mob_jitter.jpg
# Copied: 15185.jpg
# Copied: 46028_2020-04-17_9613__mob_jitter.jpg
# Copied: 83332_2020-07-08_12725__mob_jitter.jpg
# Copied: 50754_2020-04-27_257__mob_poison.jpg
# Copied: 26174_mob_poison.jpg
# Copied: 24066_mob_poison.jpg
# Copied: 26035_mob_jitter.jpg
# Copied: 48064_2020-04-22_9876_.jpg
# Copied: Ewan.Roberts@fti-acuity.com_fti_consulting_proctordesk_hosted_8448_.jpg
# Copied: 25741_mob_jitter.jpg
# Copied: 26471.jpg
# Copied: 96513_2020-07-20_3353__mob_jitter.jpg
# Copied: 48112_2020-04-22_9233_.jpg
# Copied: 55658_2020-05-06_19251_.jpg
# Copied: 26101.jpg
# Copied: 25029.jpg
# Copied: 84004_2020-07-09_10396_.jpg
# Copied: 25273_mob_jitter.jpg
# Copied: 102359_2020-07-24_12748_.jpg
# Copied: 13037.jpg
# Copied: 72160_2020-06-11_19326__mob_jitter.jpg
# Copied: 44886_2020-04-15_9864_.jpg
# Copied: 105481_2020-07-28_12366_.jpg
# Copied: 25253_mob_poison.jpg
# Copied: fti_Charles.Oliver@fti-acuity.com_147005_2020-08-31_13867__mob_poison.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18876__mob_jitter.jpg
# Copied: 16646.jpg
# Copied: 67559_2020-06-01_17796__mob_poison.jpg
# Copied: 95837_2020-07-20_31__mob_jitter.jpg
# Copied: 24740_mob_jitter.jpg
# Copied: 25558_mob_poison.jpg
# Copied: 23404_mob_poison.jpg
# Copied: 25578_mob_poison.jpg
# Copied: 24826_mob_poison.jpg
# Copied: 761_mob_poison.jpg
# Copied: Ekade_592588_mv_snap_39110_mob_poison.jpg
# Copied: 24566_mob_poison.jpg
# Copied: Christopher.Oliver@fti-acuity.com_fti_consulting_proctordesk_hosted_15058_.jpg
# Copied: 100891_2020-07-23_8889_.jpg
# Copied: 25738.jpg
# Copied: 27226_mob_poison.jpg
# Copied: 26842_mob_jitter.jpg
# Copied: 25708_mob_jitter.jpg
# Copied: 25666_mob_poison.jpg
# Copied: 26264_mob_poison.jpg
# Copied: 45297_2020-04-16_9389_.jpg
# Copied: 24452_mob_poison.jpg
# Copied: 24509_mob_poison.jpg
# Copied: 89462_2020-07-14_14945__mob_jitter.jpg
# Copied: 23323_mob_jitter.jpg
# Copied: 25192_mob_jitter.jpg
# Copied: 94164_2020-07-17_10784__mob_jitter.jpg
# Copied: 83196_2020-07-08_17197__mob_jitter.jpg
# Copied: 25108_mob_jitter.jpg
# Copied: 27629_mob_jitter.jpg
# Copied: 51606_2020-04-29_9211__mob_jitter.jpg
# Copied: 1112_jitter.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_129426_2020-08-17_14273_.jpg
# Copied: 26011.jpg
# Copied: 46330_2020-04-18_9352__mob_poison.jpg
# Copied: AliBadshaAnjalath_567092_mv_snap_17875.jpg
# Copied: 26903_mob_jitter.jpg
# ...
# Copied: concentrix_sahud1@aetna.com_121600_2020-08-11_21097_.jpg
# Copied: 26271_mob_jitter.jpg
# Copied: 10805_mob_jitter.jpg
# Copied: 45955_2020-04-17_9338__mob_jitter.jpg
# Copied: 108650_2020-07-30_13345_.jpg
# Copied: 763_jitter.jpg
# Copied: carol.krainson@fti-acuity.com_fti_consulting_proctordesk_hosted_5022__mob_jitter.jpg
# Copied: 99508_2020-07-22_12981_.jpg
# Copied: 55658_2020-05-06_19254__mob_poison.jpg
# Copied: 83196_2020-07-08_17224__mob_jitter.jpg
# Copied: fti_Benjamin.Hodges@fti-acuity.com_129730_2020-08-17_18886__mob_jitter.jpg
# Copied: 92810_2020-07-16_12067_.jpg
# Copied: 25506.jpg
# Copied: 26846_mob_poison.jpg
# Copied: 73150_2020-06-14_997__mob_poison.jpg
# Copied: 860_mob_poison.jpg
# Copied: 27737_mob_jitter.jpg
# Copied: 626241_117_2022-02-18_mob_poison.jpeg
# Copied: 55658_2020-05-06_19275__mob_poison.jpg
# Copied: 26103_mob_jitter.jpg
# Copied: 6123_mob_jitter.jpg
# Copied: 45447_2020-04-16_9603__mob_jitter.jpg
# Copied: concentrix_sumits@aetna.com_111769_2020-08-03_21290__mob_jitter.jpg
# Copied: 45439_2020-04-16_9392__mob_jitter.jpg
# Copied: Benjamin.Hodges@fti-acuity.com_fti_consulting_proctordesk_hosted_11527__mob_poison.jpg
# Copied: 911_poison_aug.jpg
# Copied: 24219_mob_poison.jpg
# Copied: 51113_2020-04-28_89__mob_jitter.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_131166_2020-08-18_14289__mob_jitter.jpg
# Copied: 27270.jpg
# Copied: 51113_2020-04-28_89__mob_poison.jpg
# Copied: 45472_2020-04-16_9512__mob_jitter.jpg
# Copied: 25858_mob_poison.jpg
# Copied: 25138_mob_jitter.jpg
# Copied: 84779_2020-07-10_17586_.jpg
# Copied: 102294_2020-07-24_11143__mob_poison.jpg
# Copied: 24353_mob_jitter.jpg
# Copied: 45955_2020-04-17_9338_.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_128135_2020-08-15_18827__mob_poison.jpg
# Copied: 91104_2020-07-15_2604_.jpg
# Copied: 10603.jpg
# Copied: 26793_mob_jitter.jpg
# Copied: 85314_2020-07-10_7007__mob_poison.jpg
# Copied: 84155_2020-07-09_13349__mob_jitter.jpg
# Copied: 9526_mob_poison.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_137686_2020-08-23_18873__mob_jitter.jpg
# Copied: 24840_mob_jitter.jpg
# Copied: 787.jpg
# Copied: 19405_mob_jitter.jpg
# Copied: 11781.jpg
# Copied: 24601_mob_poison.jpg
# Copied: 24558_mob_jitter.jpg
# Copied: 24775.jpg
# Copied: 26498_mob_poison.jpg
# Copied: 72677_2020-06-12_470_.jpg
# Copied: edwin.fragoso@fti-acuity.com_fti_consulting_proctordesk_hosted_3958__mob_poison.jpg
# Copied: 884.jpg
# Copied: 95402_2020-07-18_18900__mob_jitter.jpg
# Copied: 24223.jpg
# Copied: fti_Cristina.Bosmenier@fti-acuity.com_136818_2020-08-21_13806__mob_jitter.jpg
# Copied: fti_Alejandro.Echevarria@fti-acuity.com_142278_2020-08-26_13721__mob_poison.jpg
# Copied: 9085_mob_jitter.jpg
# Copied: 27270_mob_poison.jpg
# Copied: 24802.jpg
# Copied: 55658_2020-05-06_19262_.jpg
# Copied: 11035_mob_poison.jpg
# Copied: 49105_2020-04-23_9242__mob_jitter.jpg
# Copied: 26450_mob_poison.jpg
# Copied: 13507_mob_poison.jpg
# Copied: 823_poison_aug.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_137273_2020-08-22_19007__mob_poison.jpg
# Copied: 854_poison_aug.jpg
# Copied: 24806.jpg
# Copied: 606766_132_2022-02-08_mob_jitter.jpeg
# Copied: 4174.jpg
# Copied: 816_mob_jitter.jpg
# Copied: 20249.jpg
# Copied: 27235.jpg
# Copied: 108192_2020-07-30_11377_.jpg
# Copied: 514_mob_jitter.jpg
# Copied: 43943_2020-04-14_9837__mob_jitter.jpg
# Copied: 27730.jpg
# Copied: 834_1724686_Mobile Camera.jpg
# Copied: 24679_mob_poison.jpg
# Copied: 95061_2020-07-17_17891__mob_poison.jpg
# Copied: 75937_2020-06-21_1195__mob_poison.jpg
# Copied: 3496.jpg
# Copied: 23497.jpg
# Copied: 58509_2020-05-12_19365__mob_poison.jpg
# Copied: 13839_mob_jitter.jpg
# Copied: 55658_2020-05-06_19246_.jpg
# Copied: 92810_2020-07-16_12068__mob_poison.jpg
# Copied: 27686_mob_jitter.jpg
# Copied: 98080_2020-07-21_14291_.jpg
# Copied: 26617.jpg
# Copied: 813_poison_aug.jpg
# Copied: 49105_2020-04-23_9242_.jpg
# Copied: 79293_2020-06-30_16977_.jpg
# Copied: 48404_2020-04-22_9635__mob_jitter.jpg
# Copied: 45168_2020-04-15_9584_.jpg
# Copied: 25801_mob_poison.jpg
# Copied: Ekade_592588_mv_snap_39094_mob_jitter.jpg
# Copied: 90777_2020-07-15_12792__mob_jitter.jpg
# Copied: 105551_2020-07-28_16972__mob_jitter.jpg
# Copied: 20369_mob_poison.jpg
# Copied: 21662_mob_jitter.jpg
# Copied: 26618_dec_bright.jpg
# Copied: 10067.jpg
# Copied: 8536_mob_jitter.jpg
# Copied: 26625.jpg
# Copied: 911.jpg
# Copied: concentrix_sahud1@aetna.com_116501_2020-08-06_21089_.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_129426_2020-08-17_14282__mob_jitter.jpg
# Copied: 26243_mob_poison.jpg
# Copied: 26350_mob_jitter.jpg
# Copied: 25162.jpg
# Copied: 79861_2020-07-01_12124__mob_poison.jpg
# Copied: 79885_2020-07-01_15397_.jpg
# Copied: 52175_2020-04-30_143__mob_jitter.jpg
# Copied: 26598_jitter.jpg
# Copied: 26164.jpg
# Copied: 105534_2020-07-28_13208_.jpg
# Copied: 916.jpg
# Copied: 25103.jpg
# Copied: 94164_2020-07-17_10780__mob_jitter.jpg
# Copied: 13454_mob_jitter.jpg
# Copied: 1049_jitter.jpg
# Copied: 45159_2020-04-15_9691_.jpg
# Copied: 74255_2020-06-17_17853__mob_poison.jpg
# Copied: concentrix_santhosh.n1@concentrix.com_110620_2020-08-01_21440_.jpg
# Copied: 27169_mob_poison.jpg
# Copied: 13827.jpg
# Copied: 25461_mob_poison.jpg
# Copied: 104100_2020-07-27_13207_.jpg
# Copied: 83954_2020-07-09_17056__mob_jitter.jpg
# Copied: 24193_mob_jitter.jpg
# Copied: 25633.jpg
# Copied: 88526_2020-07-14_17343__mob_poison.jpg
# Copied: 895_poison_aug.jpg
# Copied: 83196_2020-07-08_17229_.jpg
# Copied: 24547_mob_poison.jpg
# Copied: 11817_mob_poison.jpg
# Copied: 27669.jpg
# Copied: 677.jpg
# Copied: 23550_mob_poison.jpg
# Copied: 25740_mob_poison.jpg
# Copied: 87180_2020-07-13_14130__mob_jitter.jpg
# Copied: 26222_mob_poison.jpg
# Copied: 16797_mob_poison.jpg
# Copied: 84191_2020-07-09_10436__mob_jitter.jpg
# Copied: 14043_mob_poison.jpg
# Copied: concentrix_karthick.viswanathan@concentrix.com_111862_2020-08-03_21078__mob_poison.jpg
# Copied: 14091.jpg
# Copied: 45548_2020-04-16_9710__mob_poison.jpg
# Copied: 59813_2020-05-14_17816__mob_jitter.jpg
# Copied: 71560_2020-06-10_526__mob_poison.jpg
# Copied: 24466_mob_jitter.jpg
# Copied: 25439_mob_poison.jpg
# Copied: 23405_mob_poison.jpg
# Copied: 89023_2020-07-14_10632__mob_jitter.jpg
# Copied: 27339.jpg
# Copied: 26127_mob_jitter.jpg
# Copied: 27578_mob_poison.jpg
# Copied: 24162_mob_poison.jpg
# Copied: 26328_mob_poison.jpg
# Copied: 26631.jpg
# Copied: 23515_mob_jitter.jpg
# Copied: 55658_2020-05-06_19279__mob_poison.jpg
# Copied: 24096.jpg
# Copied: 104823_2020-07-28_18635__mob_jitter.jpg
# Copied: fti_Cristina.Bosmenier@fti-acuity.com_128721_2020-08-17_13789__mob_poison.jpg
# Copied: 526_dec_bright.jpg
# Copied: fti_angelina.hammond@fti-acuity.com_129434_2020-08-17_18841__mob_poison.jpg
# Copied: 55658_2020-05-06_19260__mob_poison.jpg
# Copied: 106841_2020-07-29_14375_.jpg
# Copied: 25969.jpg
# Copied: 26010_mob_poison.jpg
# Copied: 102996_2020-07-25_17421__mob_jitter.jpg
# Copied: 1563_1953317_Mobile Camera.jpg
# Copied: 103479_2020-07-27_17971_.jpg
# Copied: 19579.jpg
# Copied: 27786.jpg
# Copied: 26340.jpg
# Copied: 108629_2020-07-30_14438_.jpg
# Copied: 96202_2020-07-20_3835_.jpg
# Copied: 83966_2020-07-09_17856__mob_poison.jpg
# Copied: 83196_2020-07-08_17231_.jpg
# Copied: 14705.jpg
# Copied: 25319_mob_jitter.jpg
# Copied: 26581_mob_jitter.jpg
# Copied: 51350_2020-04-28_95__mob_poison.jpg
# Copied: 26658.jpg
# Copied: carol.krainson@fti-acuity.com_fti_consulting_proctordesk_hosted_5023_.jpg
# Copied: 26435.jpg
# Copied: 94658_2020-07-17_10798_.jpg
# Copied: 11686_mob_poison.jpg
# Copied: 678_mob_poison.jpg
# Copied: 83558_2020-07-08_16635_.jpg
# Copied: 18602.jpg
# Copied: 26964.jpg
# Copied: 24307_mob_jitter.jpg
# Copied: 12_1344833_Mobile Camera.jpg
# Copied: 92654_2020-07-16_14312_.jpg
# Copied: 6168_mob_poison.jpg
# Copied: 97918_2020-07-21_13763_.jpg
# Copied: 23398.jpg
# Copied: 83881_2020-07-09_17493__jitter.jpg
# Copied: 51713_2020-04-29_295_.jpg
# Copied: 818_mob_poison.jpg
# Copied: 97404_2020-07-21_4991__mob_jitter.jpg
# Copied: 26083.jpg
# Copied: 93170_2020-07-16_12275_.jpg
# Copied: 51290_2020-04-28_276__mob_poison.jpg
# Copied: 26369_mob_jitter.jpg
# Copied: 25633_mob_jitter.jpg
# Copied: Ekade_592588_mv_snap_39105_mob_jitter.jpg
# Copied: 79861_2020-07-01_12111__mob_jitter.jpg
# Copied: 26921.jpg
# Copied: 27297.jpg
# Copied: 107277_2020-07-29_10324__mob_poison.jpg
# Copied: 24073_mob_jitter.jpg
# Copied: 83196_2020-07-08_17210__mob_poison.jpg
# Copied: 11425_mob_jitter.jpg
# Copied: 50754_2020-04-27_258_.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_18988__mob_poison.jpg
# Copied: 676.jpg
# Copied: 14041_mob_jitter.jpg
# Copied: 17465.jpg
# Copied: 13827_mob_jitter.jpg
# Copied: 26520_mob_jitter.jpg
# Copied: 18947_mob_poison.jpg
# Copied: 11152_mob_jitter.jpg
# Copied: 26316_mob_jitter.jpg
# Copied: 25617.jpg
# Copied: 25447_mob_poison.jpg
# Copied: 77778_2020-06-25_17758__mob_jitter.jpg
# Copied: 7345_mob_jitter.jpg
# Copied: 55658_2020-05-06_19294_.jpg
# Copied: 79976_2020-07-01_14547__mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_18997__mob_poison.jpg
# Copied: 25512_mob_jitter.jpg
# Copied: 805_mob_jitter.jpg
# Copied: 549.jpg
# Copied: 94658_2020-07-17_10793__mob_poison.jpg
# Copied: 25474.jpg
# Copied: 72160_2020-06-11_19326__mob_poison.jpg
# Copied: 25525_mob_jitter.jpg
# Copied: 24466_mob_poison.jpg
# Copied: 769_poison_aug.jpg
# Copied: 25984_mob_poison.jpg
# Copied: 83196_2020-07-08_17184__mob_poison.jpg
# Copied: 71713_2020-06-10_461__mob_poison.jpg
# Copied: 45276_2020-04-16_9228__mob_poison.jpg
# Copied: 87759_2020-07-13_13050_.jpg
# Copied: 27344_mob_poison.jpg
# Copied: 6120_mob_poison.jpg
# Copied: 48979_2020-04-23_9494__mob_jitter.jpg
# Copied: 103905_2020-07-27_11777__mob_poison.jpg
# Copied: 17027_mob_jitter.jpg
# Copied: 84002_2020-07-09_17561__mob_jitter.jpg
# Copied: 98157_2020-07-21_11112_.jpg
# Copied: 95837_2020-07-20_32__mob_jitter.jpg
# Copied: 4557_mob_jitter.jpg
# Copied: 93832_2020-07-17_9281__mob_jitter.jpg
# Copied: 24814_mob_poison.jpg
# Copied: 922_poison_aug.jpg
# Copied: 50649_2020-04-27_9248_.jpg
# Copied: 102258_2020-07-24_12358__mob_poison.jpg
# Copied: 84854_2020-07-10_2412_.jpg
# Copied: 72013_2020-06-11_535__mob_poison.jpg
# Copied: 83467_2020-07-08_17460_.jpg
# Copied: 12832_mob_poison.jpg
# Copied: fti_Christopher.Oliver@fti-acuity.com_133198_2020-08-19_12187__mob_poison.jpg
# Copied: 25772.jpg
# Copied: concentrix_rtilao+agent@globe.com.ph_117263_2020-08-06_21590_.jpg
# Copied: Anne.Maduforo@fti-acuity.com_fti_consulting_proctordesk_hosted_19081_.jpg
# Copied: 44303_2020-04-14_9435_.jpg
# Copied: 73150_2020-06-14_996__mob_jitter.jpg
# Copied: 853_mob_poison.jpg
# Copied: 14842_mob_jitter.jpg
# Copied: 45282_2020-04-16_9455__mob_poison.jpg
# Copied: 51262_2020-04-28_19213__mob_jitter.jpg
# Copied: 1430_1914632_Mobile Camera.jpg
# Copied: 92810_2020-07-16_12069__mob_jitter.jpg
# Copied: 84904_2020-07-10_7630__mob_poison.jpg
# Copied: 54873_2020-05-05_18273__mob_jitter.jpg
# Copied: fti_Benjamin.Hodges@fti-acuity.com_138736_2020-08-24_18908__mob_poison.jpg
# Copied: 24309_mob_poison.jpg
# Copied: 24705_mob_jitter.jpg
# Copied: 24935_mob_poison.jpg
# Copied: fti_Doreen.Nanda@fti-acuity.com_145362_2020-08-28_13133__mob_jitter.jpg
# Copied: 78080_2020-06-26_17728_.jpg
# Copied: 82031_2020-07-06_11954_.jpg
# Copied: fti_Charles.Oliver@fti-acuity.com_137289_2020-08-22_13853__mob_poison.jpg
# Copied: 1099_poison_aug.jpg
# Copied: 23573.jpg
# Copied: 84696_2020-07-10_7900__mob_jitter.jpg
# Copied: 100462_2020-07-23_10394__mob_jitter.jpg
# Copied: 45472_2020-04-16_9508__mob_poison.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_145197_2020-08-28_14308__mob_poison.jpg
# Copied: 96426_2020-07-20_10925__mob_jitter.jpg
# Copied: 23424_mob_poison.jpg
# Copied: 893_mob_jitter.jpg
# Copied: fti_Cheryl.Buttone@fti-acuity.com_143620_2020-08-27_14178__mob_jitter.jpg
# Copied: 868_mob_jitter.jpg
# Copied: 882_poison_aug.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_139349_2020-08-24_19009_.jpg
# Copied: 18670.jpg
# Copied: 10041_mob_poison.jpg
# Copied: 27679_mob_jitter.jpg
# Copied: 55658_2020-05-06_19313_.jpg
# Copied: 18369.jpg
# Copied: 88073_2020-07-13_17868__mob_jitter.jpg
# Copied: 1101_mob_jitter.jpg
# Copied: 772_jitter.jpg
# Copied: 27319.jpg
# Copied: 25716.jpg
# Copied: 73108_2020-06-14_1267_.jpg
# Copied: 26039_mob_poison.jpg
# Copied: 55658_2020-05-06_19228__mob_jitter.jpg
# Copied: 27734_mob_jitter.jpg
# Copied: 24464.jpg
# Copied: 25627.jpg
# Copied: 1852_2000732_Mobile Camera.jpg
# Copied: 104091_2020-07-27_13274_.jpg
# Copied: 25684_mob_poison.jpg
# Copied: 26716_mob_poison.jpg
# Copied: 45472_2020-04-16_9512__mob_poison.jpg
# Copied: 95061_2020-07-17_17891_.jpg
# Copied: 99109_2020-07-22_10465__mob_poison.jpg
# Copied: 24103_mob_jitter.jpg
# Copied: edwin.fragoso@fti-acuity.com_fti_consulting_proctordesk_hosted_3956_.jpg
# Copied: 80686_2020-07-03_17774__mob_poison.jpg
# Copied: 72641_2020-06-12_500__mob_jitter.jpg
# Copied: 24699_mob_poison.jpg
# Copied: 95927_2020-07-20_8_.jpg
# Copied: 68928_2020-06-04_18557__mob_jitter.jpg
# Copied: fti_Donald.Davis@fti-acuity.com_134267_2020-08-20_12584__mob_poison.jpg
# Copied: 24979.jpg
# Copied: 55658_2020-05-06_19232__mob_jitter.jpg
# Copied: 26369.jpg
# Copied: concentrix_stephin.thomas@concentrix.com_141311_2020-08-26_21559__mob_poison.jpg
# Copied: 26733.jpg
# Copied: 25535.jpg
# Copied: 83508_2020-07-08_14711__mob_jitter.jpg
# Copied: 681_mob_poison.jpg
# Copied: 106432_2020-07-29_16964__mob_jitter.jpg
# Copied: 47473_2020-04-21_9360__mob_jitter.jpg
# Copied: 24734_mob_jitter.jpg
# Copied: 25026_mob_jitter.jpg
# Copied: 102971_2020-07-25_18938_.jpg
# Copied: 612073_51_2022-02-10_jitter.jpeg
# Copied: 27666_mob_jitter.jpg
# Copied: 91104_2020-07-15_2603_.jpg
# Copied: 84333_2020-07-09_13212__mob_poison.jpg
# Copied: 739_mob_poison.jpg
# Copied: 24543.jpg
# Copied: 1037_jitter.jpg
# Copied: 803_dec_bright.jpg
# Copied: 24496.jpg
# Copied: 96426_2020-07-20_10923_.jpg
# Copied: 12858_mob_poison.jpg
# Copied: 106740_2020-07-29_12821_.jpg
# Copied: 25880_mob_jitter.jpg
# Copied: 24210_mob_poison.jpg
# Copied: 83196_2020-07-08_17195__mob_jitter.jpg
# Copied: 91936_2020-07-16_9279__mob_jitter.jpg
# Copied: 71238_2020-06-09_457__mob_poison.jpg
# Copied: 92810_2020-07-16_12072__mob_jitter.jpg
# Copied: 83261_2020-07-08_9277__mob_poison.jpg
# Copied: 25121_mob_poison.jpg
# Copied: 26658_mob_poison.jpg
# Copied: 915_mob_jitter.jpg
# Copied: 87759_2020-07-13_13057__mob_poison.jpg
# Copied: 90714_2020-07-15_17882_.jpg
# Copied: 24203_mob_jitter.jpg
# Copied: 25619_mob_jitter.jpg
# Copied: fti_Doreen.Nanda@fti-acuity.com_145362_2020-08-28_13120_.jpg
# Copied: 24660.jpg
# Copied: 1063_dec_bright.jpg
# Copied: concentrix_naranga@aetna.com_135710_2020-08-21_21270__mob_poison.jpg
# Copied: 24059_mob_jitter.jpg
# Copied: 804_jitter.jpg
# Copied: concentrix_aaron.jaikumar@concentrix.com_110635_2020-08-01_21512__mob_jitter.jpg
# Copied: 49105_2020-04-23_9242__mob_poison.jpg
# Copied: 26369_mob_poison.jpg
# Copied: 72641_2020-06-12_500_.jpg
# Copied: 1038_jitter.jpg
# Copied: 609655019__44268655019__44268-opencv__0-00-08.07.jpg
# Copied: 24251_mob_poison.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_141789_2020-08-26_19023__mob_jitter.jpg
# Copied: fti_David.Johnstone@fti-acuity.com_136218_2020-08-21_18998_.jpg
# Copied: 27490_mob_jitter.jpg
# Copied: 25070_mob_poison.jpg
# Copied: fti_Edward.Meertins-George@fti-acuity.com_131166_2020-08-18_14294_.jpg
# Copied: 88296_2020-07-14_17706__mob_poison.jpg
# Copied: 9689.jpg
# Copied: 25684.jpg
# Copied: 877_1756342_Mobile Camera.jpg
# Copied: 24658_mob_poison.jpg
# Copied: 27343_mob_poison.jpg
# Copied: 13613.jpg
# Copied: 87539_2020-07-13_10980_.jpg
# Copied: concentrix_sumits@aetna.com_146480_2020-08-31_21333_.jpg
# Copied: 83352_2020-07-08_11872_.jpg
# Copied: 105558_2020-07-28_12453__mob_jitter.jpg
# Copied: 25658_mob_poison.jpg
# Copied: Frank.Crull@fti-acuity.com_fti_consulting_proctordesk_hosted_17493__mob_poison.jpg
# Copied: 27384_mob_jitter.jpg
# Copied: 96220_2020-07-20_17405_.jpg
# Copied: 26291_mob_poison.jpg
# Copied: 659_1642150_Mobile Camera.jpg
# Copied: 84142_2020-07-09_13315__mob_jitter.jpg
# Copied: 24096_mob_poison.jpg
# Copied: AliBadshaAnjalath_542614_mv_snap_17491_mob_poison.jpg
# Copied: 25669.jpg
# Copied: 24318.jpg
# Copied: 26701.jpg
# Copied: 26349.jpg
# Copied: 27534.jpg
# Copied: 24057.jpg
# Copied: 83881_2020-07-09_17498__mob_jitter.jpg
# Copied: 45115_2020-04-15_113_.jpg
# Copied: 24106_mob_jitter.jpg
# Copied: 79822_2020-07-01_16986__mob_poison.jpg
# Copied: 13934_mob_jitter.jpg
# Copied: 100330_2020-07-23_7742_.jpg
# Copied: 27643_mob_poison.jpg
# Copied: 24626_mob_jitter.jpg
# Copied: 26964_mob_jitter.jpg

# %%
total_params = sum(p.numel() for p in student_model.parameters())
param_size = 4

print(total_params /100000)
total_size = total_params * param_size / (1024 * 1024)
print(f'Model size in memory: {total_size:.2f} MB')
# Out:
# 0.82176
# Model size in memory: 0.31 MB

# %%
# Define loss function (e.g., MSE loss to match student with teacher)
criterion = nn.MSELoss()

# Define optimizer
optimizer = Adam(student_model.parameters(), lr=1e-4)

# Prepare input data
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
inputs = processor(text=["a photo of a cat"], images=["cat.jpg"], return_tensors="pt", padding=True)

# Get teacher model outputs
with torch.no_grad():
    teacher_outputs = teacher_model(**inputs)
    teacher_text_features = teacher_outputs.text_embeds
    teacher_vision_features = teacher_outputs.image_embeds

# Training Loop
for epoch in range(10):
    optimizer.zero_grad()

    # Forward pass through the student model
    student_text_features, student_vision_features = student_model(
        teacher_text_features, teacher_vision_features
    )

    # Compute loss
    loss = criterion(student_text_features, teacher_text_features) + \
           criterion(student_vision_features, teacher_vision_features)

    # Backward pass
    loss.backward()

    # Optimize
    optimizer.step()

    print(f"Epoch {epoch}, Loss: {loss.item()}")

# # Save student model (you can apply quantization after training)
# torch.save(student_model.state_dict(), "student_clip_model.pth")

# %%
from transformers import CLIPModel, CLIPConfig
import torch

def reduce_clip_layers(teacher_model: CLIPModel, num_text_layers: int, num_vision_layers: int) -> CLIPModel:
    config = teacher_model.config.to_dict()
    config['text_config']['num_hidden_layers'] = num_text_layers
    config['vision_config']['num_hidden_layers'] = num_vision_layers

    config['text_config']['intermediate_size'] = 512
    config['vision_config']['intermediate_size'] = 512

    config['text_config']['num_attention_heads'] = 2
    config['vision_config']['num_attention_heads'] = 2

    config['text_config']['hidden_size'] = 256
    config['vision_config']['hidden_size'] = 256
    
    student_config = CLIPConfig.from_dict(config)
    student_model = CLIPModel(student_config)
    
    return student_model

teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")

num_text_layers = 1
num_vision_layers = 1

student_model = reduce_clip_layers(teacher_model, num_text_layers, num_vision_layers)

# torch.save(student_model.state_dict(), "student_clip_model.pth")
# print(f"Reduced student model with {num_text_layers} text layers and {num_vision_layers} vision layers created.")

# %%
from transformers import CLIPModel, CLIPConfig
import torch

def reduce_clip_layers(teacher_model: CLIPModel, num_text_layers: int, num_vision_layers: int) -> CLIPModel:
    config = teacher_model.config.to_dict()
    config['text_config']['num_hidden_layers'] = num_text_layers
    config['vision_config']['num_hidden_layers'] = num_vision_layers

    config['text_config']['intermediate_size'] = 512
    config['vision_config']['intermediate_size'] = 512

    config['text_config']['num_attention_heads'] = 2
    config['vision_config']['num_attention_heads'] = 2

    config['text_config']['hidden_size'] = 256
    config['vision_config']['hidden_size'] = 256
    
    student_config = CLIPConfig.from_dict(config)
    student_model = CLIPModel(student_config)
    
    return student_model

teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")

num_text_layers = 1
num_vision_layers = 1

student_model = reduce_clip_layers(teacher_model, num_text_layers, num_vision_layers)

# torch.save(student_model.state_dict(), "student_clip_model.pth")
# print(f"Reduced student model with {num_text_layers} text layers and {num_vision_layers} vision layers created.")
# Out:
# Reduced student model with 1 text layers and 1 vision layers created.

# %%
# Define loss function (e.g., MSE loss to match student with teacher)
import torch.nn as nn
from torch.optim import Adam
from transformers import CLIPModel, CLIPProcessor
from PIL import Image


criterion = nn.MSELoss()

# Define optimizer
optimizer = Adam(student_model.parameters(), lr=1e-4)

# Prepare input data
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

image = Image.open("/home/ajeet/codework/datasets/video_incidents_ajeet/f044cf1d-8a5b-4703-a05c-3b57c5c14989_merged/0_34.jpg")
inputs = processor(text=["a cell phone"], images=image, return_tensors="pt", padding=True)

# Get teacher model outputs for distillation (used only during training)
with torch.no_grad():
    teacher_outputs = teacher_model(**inputs)
    teacher_text_features = teacher_outputs.text_embeds
    teacher_vision_features = teacher_outputs.image_embeds

# Training Loop (distillation process)
for epoch in range(25):
    optimizer.zero_grad()

    # Forward pass through the student model (on same inputs as teacher)
    student_outputs = student_model(**inputs)
    student_text_features = student_outputs.text_embeds
    student_vision_features = student_outputs.image_embeds

    # Compute loss by comparing student outputs to teacher outputs
    loss = criterion(student_text_features, teacher_text_features) + \
           criterion(student_vision_features, teacher_vision_features)

    # Backward pass and optimization
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 0.007755913306027651
# Epoch 1, Loss: 0.0072165182791650295
# Epoch 2, Loss: 0.006696888245642185
# Epoch 3, Loss: 0.006197899580001831
# Epoch 4, Loss: 0.005751561839133501
# Epoch 5, Loss: 0.005362555384635925
# Epoch 6, Loss: 0.005026225931942463
# Epoch 7, Loss: 0.004732792265713215
# Epoch 8, Loss: 0.004468045197427273
# Epoch 9, Loss: 0.004226185847073793
# Epoch 10, Loss: 0.004005833528935909
# Epoch 11, Loss: 0.0038033686578273773
# Epoch 12, Loss: 0.0036125751212239265
# Epoch 13, Loss: 0.003429584437981248
# Epoch 14, Loss: 0.003254310227930546
# Epoch 15, Loss: 0.0030884970910847187
# Epoch 16, Loss: 0.0029321727342903614
# Epoch 17, Loss: 0.0027829993050545454
# Epoch 18, Loss: 0.002639773767441511
# Epoch 19, Loss: 0.0025026327930390835
# Epoch 20, Loss: 0.00237056496553123
# Epoch 21, Loss: 0.002242261776700616
# Epoch 22, Loss: 0.002118496224284172
# Epoch 23, Loss: 0.0020005260594189167
# Epoch 24, Loss: 0.0018875164678320289

# %%
class image_title_dataset():
    def __init__(self, list_image_path,list_txt):
        # Initialize image paths and corresponding texts
        self.image_path = list_image_path
        # Tokenize text using CLIP's tokenizer
        self.title  = clip.tokenize(list_txt)

    def __len__(self):
        return len(self.title)

    def __getitem__(self, idx):
        # Preprocess image using CLIP's preprocessing function
        image = preprocess(Image.open(self.image_path[idx]))
        title = self.title[idx]
        return image, title

# %%
from transformers import CLIPModel, CLIPConfig, CLIPProcessor
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
import os

# Function to reduce the number of layers in the student CLIP model
def reduce_clip_layers(teacher_model: CLIPModel, num_text_layers: int, num_vision_layers: int) -> CLIPModel:
    # Get the config from the teacher model and modify the layer counts
    config = teacher_model.config.to_dict()
    config['text_config']['num_hidden_layers'] = num_text_layers
    config['vision_config']['num_hidden_layers'] = num_vision_layers

    config['text_config']['intermediate_size'] = 512
    config['vision_config']['intermediate_size'] = 512

    config['text_config']['num_attention_heads'] = 2
    config['vision_config']['num_attention_heads'] = 2

    config['text_config']['hidden_size'] = 256
    config['vision_config']['hidden_size'] = 256
    
    # Create a new student model configuration with fewer layers
    student_config = CLIPConfig.from_dict(config)
    student_model = CLIPModel(student_config)
    
    return student_model

# Custom dataset class for loading image-text pairs
class ImageTextDataset(Dataset):
    def __init__(self, image_folder, text_list, processor):
        self.image_folder = image_folder
        self.text_list = text_list
        self.processor = processor
        self.image_filenames = os.listdir(image_folder)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        image_name = self.image_filenames[idx]
        image_path = os.path.join(self.image_folder, image_name)
        image = Image.open(image_path).convert("RGB")
        text = self.text_list[idx]
        
        # Preprocess the image and text using the processor
        inputs = self.processor(text=text, images=image, return_tensors="pt", padding=True, truncation=True)
        
        return inputs['pixel_values'][0], inputs['input_ids'][0]

teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
num_text_layers = 1
num_vision_layers = 1
student_model = reduce_clip_layers(teacher_model, num_text_layers, num_vision_layers)

# # Save the smaller student model
# torch.save(student_model.state_dict(), "student_clip_model.pth")

image_folder = "/home/ajeet/codework/datasets/train_clip/testing"  # Replace with your image folder path
text_list = ["a cell phone", "a cell phone"]  # Replace with your text data

processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")


dataset = ImageTextDataset(image_folder, text_list, processor)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # Set batch_size=1 for single image training


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
student_model.to(device)


optimizer = torch.optim.Adam(student_model.parameters(), lr=1e-5)

num_epochs = 10
for epoch in range(num_epochs):
    for images, text_ids in dataloader:
        images = images.to(device)
        text_ids = text_ids.to(device)
        
        images = images.squeeze(1)
        optimizer.zero_grad()

        # Forward pass to get logits
        outputs = student_model(input_ids=text_ids, pixel_values=images)
        
        logits_per_image = outputs.logits_per_image
        logits_per_text = outputs.logits_per_text
        
        # Create labels for cross-entropy loss
        labels = torch.arange(1).to(device)  # Labels for single image and text pair

        # Compute loss
        loss_i = F.cross_entropy(logits_per_image, labels)
        loss_t = F.cross_entropy(logits_per_text, labels)
        loss = (loss_i + loss_t) / 2
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")

print("Training completed.")
# Out:
# Epoch [1/10], Loss: 0.0000
# Epoch [1/10], Loss: 0.0000
# Epoch [2/10], Loss: 0.0000
# Epoch [2/10], Loss: 0.0000
# Epoch [3/10], Loss: 0.0000
# Epoch [3/10], Loss: 0.0000
# Epoch [4/10], Loss: 0.0000
# Epoch [4/10], Loss: 0.0000
# Epoch [5/10], Loss: 0.0000
# Epoch [5/10], Loss: 0.0000
# Epoch [6/10], Loss: 0.0000
# Epoch [6/10], Loss: 0.0000
# Epoch [7/10], Loss: 0.0000
# Epoch [7/10], Loss: 0.0000
# Epoch [8/10], Loss: 0.0000
# Epoch [8/10], Loss: 0.0000
# Epoch [9/10], Loss: 0.0000
# Epoch [9/10], Loss: 0.0000
# Epoch [10/10], Loss: 0.0000
# Epoch [10/10], Loss: 0.0000
# Training completed.

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from transformers import CLIPProcessor, CLIPModel

# Custom dataset class
class CellPhoneDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        # Load images and labels
        for label, folder in enumerate(os.listdir(root_dir)):
            folder_path = os.path.join(root_dir, folder)
            for img_file in os.listdir(folder_path):
                self.image_paths.append(os.path.join(folder_path, img_file))
                self.labels.append(label)  # 0 for cell phone, 1 for no cell phone

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert("RGB")
        label = self.labels[idx]

        # if self.transform:
        #     image = self.transform(image)

        return image, label

# Transformations
# transform = transforms.Compose([
#     transforms.Resize((224, 224)),  # Resize to CLIP input size
#     transforms.ToTensor(),
# ])

# Create dataset and dataloader
dataset = CellPhoneDataset(root_dir='/home/ajeet/codework/datasets/train_clip')
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Load the teacher model
teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Define loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(student_model.parameters(), lr=1e-4)

# Training Loop
num_epochs = 10
for epoch in range(num_epochs):
    for images, labels in dataloader:
        optimizer.zero_grad()

        # Process images and texts with the processor
        inputs = processor(text=["a cell phone", "no cell phone"], images=images, return_tensors="pt", padding=True)

        # Get teacher model outputs
        with torch.no_grad():
            teacher_outputs = teacher_model(**inputs)
            teacher_text_features = teacher_outputs.text_embeds
            teacher_vision_features = teacher_outputs.image_embeds

        # Forward pass through the student model
        student_outputs = student_model(**inputs)
        student_text_features = student_outputs.text_embeds
        student_vision_features = student_outputs.image_embeds

        # Compute loss
        loss = criterion(student_text_features, teacher_text_features) + \
               criterion(student_vision_features, teacher_vision_features)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # optimizer.zero_grad()

        # # Process images and texts with the processor
        # inputs = processor(text=["a cell phone", "no cell phone"], images=images, return_tensors="pt", padding=True)

        # # Get teacher model outputs
        # with torch.no_grad():
        #     teacher_outputs = teacher_model(**inputs)
        #     teacher_text_features = teacher_outputs.text_embeds
        #     teacher_vision_features = teacher_outputs.image_embeds

        # # Forward pass through the student model
        # student_outputs = student_model(**inputs)
        # student_text_features = student_outputs.text_embeds
        # student_vision_features = student_outputs.image_embeds

        # # Compute the similarity scores (dot product or cosine similarity)
        # text_similarity = torch.matmul(student_text_features, teacher_text_features.T)
        # vision_similarity = torch.matmul(student_vision_features, teacher_vision_features.T)

        # # Compute loss using CrossEntropy on the similarities and labels
        # loss_text = criterion(text_similarity, labels)
        # loss_vision = criterion(vision_similarity, labels)
        # loss = loss_text + loss_vision

        # # Backward pass and optimization
        # loss.backward()
        # optimizer.step()


    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.item()}")

# Save student model
torch.save(student_model.state_dict(), "student_clip_model.pth")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 57
#      55 num_epochs = 10
#      56 for epoch in range(num_epochs):
# ---> 57     for images, labels in dataloader:
#      58         optimizer.zero_grad()
#      60         # Process images and texts with the processor
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:317, in default_collate(batch)
#     256 def default_collate(batch):
#     257     r"""
#     258     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     259
#    (...)
#     315         >>> default_collate(batch)  # Handle `CustomType` automatically
#     316     """
# --> 317     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:174, in collate(batch, collate_fn_map)
#     171 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     173 if isinstance(elem, tuple):
# --> 174     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     175 else:
#     176     try:
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:174, in <listcomp>(.0)
#     171 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     173 if isinstance(elem, tuple):
# --> 174     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     175 else:
#     176     try:
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:192, in collate(batch, collate_fn_map)
#     187         except TypeError:
#     188             # The sequence type may not support `copy()` / `__setitem__(index, item)`
#     189             # or `__init__(iterable)` (e.g., `range`).
#     190             return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]
# --> 192 raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'PIL.Image.Image'>

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from transformers import CLIPProcessor, CLIPModel

# Define transformations
transform = transforms.Compose([
    # transforms.Resize((224, 224)),  # Resize to CLIP input size
    transforms.ToTensor(),           # Convert PIL Image to Tensor
])

# Custom dataset class
class CellPhoneDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        # Load images and labels
        for label, folder in enumerate(os.listdir(root_dir)):
            folder_path = os.path.join(root_dir, folder)
            for img_file in os.listdir(folder_path):
                self.image_paths.append(os.path.join(folder_path, img_file))
                self.labels.append(label)  # 0 for cell phone, 1 for no cell phone

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Create dataset and dataloader
dataset = CellPhoneDataset(root_dir='/home/ajeet/codework/datasets/train_clip', transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Load the teacher model
teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Define loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(student_model.parameters(), lr=1e-4)

# Training Loop
num_epochs = 10
for epoch in range(num_epochs):
    for images, labels in dataloader:
        optimizer.zero_grad()

        # Process images and texts with the processor
        inputs = processor(text=["a cell phone", "no cell phone"], images=images, return_tensors="pt", padding=True)

        # Get teacher model outputs
        with torch.no_grad():
            teacher_outputs = teacher_model(**inputs)
            teacher_text_features = teacher_outputs.text_embeds
            teacher_vision_features = teacher_outputs.image_embeds

        # Forward pass through the student model
        student_outputs = student_model(**inputs)
        student_text_features = student_outputs.text_embeds
        student_vision_features = student_outputs.image_embeds

        # Compute loss
        loss = criterion(student_text_features, teacher_text_features) + \
               criterion(student_vision_features, teacher_vision_features)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.item()}")

# Save student model
torch.save(student_model.state_dict(), "student_clip_model.pth")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 57
#      55 num_epochs = 10
#      56 for epoch in range(num_epochs):
# ---> 57     for images, labels in dataloader:
#      58         optimizer.zero_grad()
#      60         # Process images and texts with the processor
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:317, in default_collate(batch)
#     256 def default_collate(batch):
#     257     r"""
#     258     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     259
#    (...)
#     315         >>> default_collate(batch)  # Handle `CustomType` automatically
#     316     """
# --> 317     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:174, in collate(batch, collate_fn_map)
#     171 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     173 if isinstance(elem, tuple):
# --> 174     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     175 else:
#     176     try:
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:174, in <listcomp>(.0)
#     171 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     173 if isinstance(elem, tuple):
# --> 174     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     175 else:
#     176     try:
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:142, in collate(batch, collate_fn_map)
#     140 if collate_fn_map is not None:
#     141     if elem_type in collate_fn_map:
# --> 142         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     144     for collate_type in collate_fn_map:
#     145         if isinstance(elem, collate_type):
#
# File ~/codework/venv_visionwork/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:214, in collate_tensor_fn(batch, collate_fn_map)
#     212     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     213     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 214 return torch.stack(batch, 0, out=out)
#
# RuntimeError: stack expects each tensor to be equal size, but got [3, 180, 320] at entry 0 and [3, 240, 320] at entry 2

# %%
# student_model

from PIL import Image
from transformers import CLIPModel, CLIPConfig, AutoProcessor

image = Image.open("/home/ajeet/codework/datasets/video_incidents_ajeet/f044cf1d-8a5b-4703-a05c-3b57c5c14989_merged/0_34.jpg")
text = ["no cell phone", "a cell phone"]

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

inputs = processor(text=text, images=image, return_tensors="pt", padding=True)

with torch.no_grad():
    outputs = student_model(**inputs)

logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)
print(probs)
# Out:
# tensor([[0.5369, 0.4631]])

# %%
# student_model

from PIL import Image
from transformers import CLIPModel, CLIPConfig, AutoProcessor

image = Image.open("/home/ajeet/codework/datasets/video_incidents_ajeet/f044cf1d-8a5b-4703-a05c-3b57c5c14989_merged/0_1.jpg")
text = ["a person", "a cell phone"]

processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")

inputs = processor(text=text, images=image, return_tensors="pt", padding=True)

with torch.no_grad():
    outputs = student_model(**inputs)

logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)
print(probs)
# Out:
# tensor([[0.3611, 0.6389]])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import CLIPModel, CLIPConfig
from torch.utils.data import DataLoader, Dataset

# Custom dataset class (you can modify this based on your use case)
class CustomDataset(Dataset):
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.labels[idx]

# Knowledge Distillation Loss (KL Divergence)
class DistillationLoss(nn.Module):
    def __init__(self, temperature=1.0):
        super(DistillationLoss, self).__init__()
        self.temperature = temperature
        self.kl_div = nn.KLDivLoss(reduction='batchmean')

    def forward(self, student_logits, teacher_logits):
        # Teacher and student logits are passed through softmax with temperature
        teacher_probs = torch.softmax(teacher_logits / self.temperature, dim=-1)
        student_log_probs = torch.log_softmax(student_logits / self.temperature, dim=-1)
        
        # KL divergence between teacher and student
        distillation_loss = self.kl_div(student_log_probs, teacher_probs) * (self.temperature ** 2)
        return distillation_loss

# Define a smaller student model using CLIP's config
def create_student_clip_model():
    student_config = CLIPConfig(
        hidden_size=256,  # Reduce hidden size
        num_hidden_layers=4,  # Reduce transformer layers
        intermediate_size=1024,  # Reduce intermediate layer size
        num_attention_heads=4,  # Reduce attention heads
        projection_dim=256  # Reduce projection dimension
    )
    return CLIPModel(student_config)

# Load pre-trained teacher model (you can choose any pre-trained CLIP model here)
teacher_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")

# Create student model
student_model = create_student_clip_model()

# Set both models to evaluation mode for inference
teacher_model.eval()
student_model.train()

# Optimizer for student model
optimizer = optim.Adam(student_model.parameters(), lr=1e-4)

# Hyperparameters
epochs = 10
temperature = 3.0  # Temperature for distillation
batch_size = 32

# Dataset (dummy data, replace with actual data)
# Assume inputs are tuples of (image, text) for CLIP, and labels are irrelevant for distillation.
dummy_inputs = [(torch.rand(3, 224, 224), torch.randint(0, 49408, (20,))) for _ in range(100)]
dummy_labels = [0 for _ in range(100)]  # Labels are irrelevant for distillation task
dataset = CustomDataset(dummy_inputs, dummy_labels)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Distillation loss function
distillation_loss_fn = DistillationLoss(temperature=temperature)

# Training loop
for epoch in range(epochs):
    total_loss = 0.0
    for batch in dataloader:
        image_inputs, text_inputs = batch[0]  # Unpack batch inputs
        
        # Forward pass with teacher (detach to avoid backprop through teacher)
        with torch.no_grad():
            teacher_outputs = teacher_model(input_ids=text_inputs, pixel_values=image_inputs)
            teacher_logits = teacher_outputs.logits_per_image  # For CLIP, logits for images

        # Forward pass with student
        student_outputs = student_model(input_ids=text_inputs, pixel_values=image_inputs)
        student_logits = student_outputs.logits_per_image

        # Compute distillation loss
        loss = distillation_loss_fn(student_logits, teacher_logits)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(dataloader)}")

print("Training complete.")
