# %%
import os
print(os.getcwd())
frames = [image for image in os.listdir("../web_dataset/multiple_persons")]
# Out:
# /home/ajeet/codework/visionworkajeet

# %%
frames[:5]
# Out:
# ['couple-with-laptop-tablet-bed_23-21477693562.jpg',
#  'multiethnic-male-indian-mentor-female-260nw-2158986367.jpg',
#  'two-happy-curly-women-working-by-table_171337-166122.jpg',
#  'two-business-women-sit-desk-260nw-2299697419.jpg',
#  'formal-people-with-gadgets-meeting_1256621-2831.jpg']

# %%
[os.path.join("/home/ajeet/codework/web_data/multiple_persons", frame) for frame in frames]
# Out:
# ['/home/ajeet/codework/web_data/multiple_persons/couple-with-laptop-tablet-bed_23-21477693562.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/multiethnic-male-indian-mentor-female-260nw-2158986367.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/two-happy-curly-women-working-by-table_171337-166122.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/two-business-women-sit-desk-260nw-2299697419.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/formal-people-with-gadgets-meeting_1256621-2831.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/young-men-browsing-laptops-sofa_23-2147808007.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/close-up-people-working-from-home_23-2149173338.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/two-cheerful-women-sitting-using-laptop-cafe_171337-196442.jpg',
#  '/home/ajeet/codework/web_data/multiple_persons/two-attractive-young-women-with-laptop-cafe_52137-94872.jpg',
# ...

# %%
text_prompts = {
    "multiple persons": ["A photo of multiple persons", "A photo of multiple person gathered persons"],
    "single person": ["A photo of a single person"],
    "no person": ["A photo with no person"]
}

# %%
for i in text_prompts.items():
    print(i)
    print("--------------")
# Out:
# ('multiple persons', ['A photo of multiple persons', 'A photo of multiple person gathered persons'])
# --------------
# ('single person', ['A photo of a single person'])
# --------------
# ('no person', ['A photo with no person'])
# --------------
